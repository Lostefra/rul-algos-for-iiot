# %% [markdown]
# # Testing

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {5, 10, 15, 20} (aka 0.5, 1, 1.5, 2 seconds)
margin = 5

# %% [markdown]
# ## Import libraries and define utility functions

# %%
import pandas as pd
import numpy as np
import sys
import random
import pickle
from time import time
from sklearn.preprocessing import StandardScaler
from math import floor
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# %%
mean = lambda l: sum(l) / len(l)

def describe(l, n_quantiles=10, list_quantiles=None):
    print(f'Min={min(l):.4}, Max={max(l):.4}, Avg={mean(l):.4}, Tot={len(l)}')
    if list_quantiles is None:
        list_quantiles = [e / n_quantiles for e in range(1, n_quantiles)]
    for q in list_quantiles:
        print(q, ":", round(np.quantile(l, q), 3))
    return min(l), max(l), mean(l), len(l)

# %% [markdown]
# #### Set up global variables

# %%
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
timings = []
timings_net = []

# %%
min_time = 0.00001
models_path = "models_" + str(margin) + "/"
results_path = "results_" + str(margin) + "/"
threshold_path = "threshold_" + str(margin) + "/"
seeds = [100]

# %%
w5_features_no_diff = [
 'Gz_mean_w5',
 'Ax_mean_w5',
 'Ay_mean_w5',
 'Gz_std_w5',
 'Ax_std_w5',
 'Ay_std_w5',
 'Gz_min_w5',
 'Ax_min_w5',
 'Ay_min_w5',
 'Gz_max_w5',
 'Ax_max_w5',
 'Ay_max_w5'
]

w5_features_diff = [
 'differencing_Gz_mean_w5',
 'differencing_Ax_mean_w5',
 'differencing_Ay_mean_w5',
 'differencing_Gz_std_w5',
 'differencing_Ax_std_w5',
 'differencing_Ay_std_w5',
 'differencing_Gz_min_w5',
 'differencing_Ax_min_w5',
 'differencing_Ay_min_w5',
 'differencing_Gz_max_w5',
 'differencing_Ax_max_w5',
 'differencing_Ay_max_w5',
]

w10_features_no_diff = [
 'Gz_mean_w10',
 'Ax_mean_w10',
 'Ay_mean_w10',
 'Gz_std_w10',
 'Ax_std_w10',
 'Ay_std_w10',
 'Gz_min_w10',
 'Ax_min_w10',
 'Ay_min_w10',
 'Gz_max_w10',
 'Ax_max_w10',
 'Ay_max_w10'
]

w10_features_diff = [
 'differencing_Gz_mean_w10',
 'differencing_Ax_mean_w10',
 'differencing_Ay_mean_w10',
 'differencing_Gz_std_w10',
 'differencing_Ax_std_w10',
 'differencing_Ay_std_w10',
 'differencing_Gz_min_w10',
 'differencing_Ax_min_w10',
 'differencing_Ay_min_w10',
 'differencing_Gz_max_w10',
 'differencing_Ax_max_w10',
 'differencing_Ay_max_w10'
]

w15_features_no_diff = [
 'Gz_mean_w15',
 'Ax_mean_w15',
 'Ay_mean_w15',
 'Gz_std_w15',
 'Ax_std_w15',
 'Ay_std_w15',
 'Gz_min_w15',
 'Ax_min_w15',
 'Ay_min_w15',
 'Gz_max_w15',
 'Ax_max_w15',
 'Ay_max_w15'
]

w15_features_diff = [
 'differencing_Gz_mean_w15',
 'differencing_Ax_mean_w15',
 'differencing_Ay_mean_w15',
 'differencing_Gz_std_w15',
 'differencing_Ax_std_w15',
 'differencing_Ay_std_w15',
 'differencing_Gz_min_w15',
 'differencing_Ax_min_w15',
 'differencing_Ay_min_w15',
 'differencing_Gz_max_w15',
 'differencing_Ax_max_w15',
 'differencing_Ay_max_w15'
]

w20_features_no_diff = [
 'Gz_mean_w20',
 'Ax_mean_w20',
 'Ay_mean_w20',
 'Gz_std_w20',
 'Ax_std_w20',
 'Ay_std_w20',
 'Gz_min_w20',
 'Ax_min_w20',
 'Ay_min_w20',
 'Gz_max_w20',
 'Ax_max_w20',
 'Ay_max_w20'
]

w20_features_diff = [
 'differencing_Gz_mean_w20',
 'differencing_Ax_mean_w20',
 'differencing_Ay_mean_w20',
 'differencing_Gz_std_w20',
 'differencing_Ax_std_w20',
 'differencing_Ay_std_w20',
 'differencing_Gz_min_w20',
 'differencing_Ax_min_w20',
 'differencing_Ay_min_w20',
 'differencing_Gz_max_w20',
 'differencing_Ax_max_w20',
 'differencing_Ay_max_w20',
]

features = {
    "all_features": w5_features_no_diff + w10_features_no_diff + w15_features_no_diff + w20_features_no_diff + w5_features_diff + w10_features_diff + w15_features_diff + w20_features_diff + ['label'], 
    "w5_features": w5_features_no_diff + w5_features_diff + ['label'], 
    "w10_features": w10_features_no_diff + w10_features_diff + ['label'], 
    "w15_features": w15_features_no_diff + w15_features_diff + ['label'], 
    "w20_features": w20_features_no_diff + w20_features_diff + ['label'], 
    "no_diff_features": w5_features_no_diff + w10_features_no_diff + w15_features_no_diff + w20_features_no_diff + ['label'], 
    "diff_features": w5_features_diff + w10_features_diff + w15_features_diff + w20_features_diff + ['label']
}

# %% [markdown]
# #### Set up global variables

# %%
f_headers = r'data/headers.txt'
f_acc = r'data/test-raw/dataset_acc.csv'
f_pos = r'data/test-raw/dataset_pos.csv'
f_labels = r'data/test-raw/labels.csv'

# %% [markdown]
# #### Load utilities

# %%
with open('data/utils/scaler_' + str(margin) + '.bin', 'rb') as handle:
    scaler = pickle.load(handle)
with open('data/utils/fixed_orient_' + str(margin) + '.bin', 'rb') as handle:
    fixed_orient = pickle.load(handle)
with open('data/utils/fixed_pos_' + str(margin) + '.bin', 'rb') as handle:
    fixed_pos = pickle.load(handle)
with open('data/utils/differencing_dict_' + str(margin) + '.bin', 'rb') as handle:
    differencing_dict = pickle.load(handle)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.1 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Raw data import

# %%
with open(f_headers) as f_headers:
    col_acc = f_headers.readline()[:-1].split(",")
    col_pos = f_headers.readline()[:-1].split(",")
    col_lab = f_headers.readline().split(",")

# %%
acc_df = pd.read_csv(f_acc, names=col_acc)
pos_df = pd.read_csv(f_pos, names=col_pos)
lab_df = pd.read_csv(f_labels, names=col_lab)

# %% [markdown]
# #### Raw data inspection

# %%
print(f'The dataset contains {len(acc_df)} samples')
acc_df.head()
# Out:
# The dataset contains 49979 samples
#       time_server     time_client     Gz      Ax      Ay
# 0 1651503005.5170 1651176129.8823 0.0687 -2.0750 -0.1953
# 1 1651503005.6167 1651176129.9824 0.0687 -2.4170 -0.6104
# 2 1651503005.7167 1651176130.0825 0.0687 -1.5870 -0.0244
# 3 1651503005.8166 1651176130.1828 0.0687 -2.0260 -0.9766
# 4 1651503005.9165 1651176130.2830 0.0763 -2.0020 -0.6104

# %%
print(f'The dataset contains {len(pos_df)} samples')
pos_df.head()
# Out:
# The dataset contains 25338 samples
#       time_server    POSx    POSy  orient
# 0 1651505818.5333 31.7187 29.1164 52.2161
# 1 1651505818.6358 31.7321 29.1264 54.4788
# 2 1651505818.7355 31.7467 29.1363 56.8535
# 3 1651505818.8354 31.7617 29.1457 59.1696
# 4 1651505818.9354 31.7762 29.1632 61.2057

# %%
print(f'The dataset contains {len(lab_df)} samples')
lab_df.head()
# Out:
# The dataset contains 26 samples
#       time_server label
# 0 1651505990.9049     s
# 1 1651506204.2696     f
# 2 1651506232.7222     s
# 3 1651506368.3697     f
# 4 1651506397.5757     s

# %% [markdown]
# ## Data merge

# %%
def find_nearest(array, value, return_index=True):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    if return_index:
        return array[idx], idx
    else:
        return array[idx]

def merge_data(acc, pos, lab):
    
    delta = 0.05
    merged_data = []
    disalignments = []
    
    for i_lab in range(len(lab) - 1):
        if lab.loc[i_lab, "label"] == "s":
            start = lab.loc[i_lab, "time_server"]
            end = lab.loc[i_lab + 1, "time_server"]
            curr_acc = acc[(acc["time_server"] > start - delta) & (acc["time_server"] < end + delta)]
            curr_pos = pos[(pos["time_server"] > start - delta) & (pos["time_server"] < end + delta)]
            
            for i_acc in range(len(curr_acc)):
                curr_data_acc = curr_acc.iloc[i_acc]
                curr_time = curr_data_acc["time_server"]
                curr_data_acc = curr_data_acc.tolist()
                nearest, i_nearest = find_nearest(curr_pos["time_server"].to_numpy(), curr_time)
                disalignments.append(np.abs(curr_time - nearest))
                curr_data_pos = curr_pos.iloc[i_nearest].tolist()
                merged_data.append(curr_data_acc + curr_data_pos + [len(curr_acc) - 1 - i_acc])
                
            print(f'The {int(i_lab / 2 + 1)}° lap lasts for approx. {len(curr_acc) / 10} seconds')
        
    return merged_data, disalignments

# %%
merged_data, time_disalignments = merge_data(acc_df, pos_df, lab_df)
# Out:
# The 1° lap lasts for approx. 210.1 seconds
# The 2° lap lasts for approx. 133.3 seconds
# The 3° lap lasts for approx. 106.3 seconds
# The 4° lap lasts for approx. 135.8 seconds
# The 5° lap lasts for approx. 95.7 seconds
# The 6° lap lasts for approx. 99.7 seconds
# The 7° lap lasts for approx. 96.8 seconds
# The 8° lap lasts for approx. 96.7 seconds
# The 9° lap lasts for approx. 95.4 seconds
# The 10° lap lasts for approx. 135.3 seconds
# The 11° lap lasts for approx. 93.4 seconds
# The 12° lap lasts for approx. 94.7 seconds
# The 13° lap lasts for approx. 24.3 seconds

# %%
raw_df = pd.DataFrame(merged_data, columns=col_acc+["time_server_pos"]+col_pos[1:]+["label"])
raw_df
# Out:
#           time_server     time_client      Gz       Ax      Ay  \
# 0     1651505990.8958 1651179115.2670 -0.4809   0.8057 -1.8550
# 1     1651505990.9959 1651179115.3674 -0.4427  -3.9060  1.9530
# 2     1651505991.0459 1651179115.4177 -0.4809  -2.2460 -1.8310
# 3     1651505991.1959 1651179115.5682 -0.3511  -1.3430 -5.4930
# 4     1651505991.2958 1651179115.6688 -0.2901  -0.0732 -1.8310
# ...               ...             ...     ...      ...     ...
# 14170 1651508387.1363 1651181511.5192 -0.0611 -11.8200 -5.1510
# 14171 1651508387.2367 1651181511.6195  0.1145  -3.5640 -5.9330
# 14172 1651508387.3365 1651181511.7200 -0.0229 -29.0300 -6.2740
# 14173 1651508387.4366 1651181511.8204 -0.4275 -31.3700 -1.8310
# 14174 1651508387.5465 1651181511.9208 -0.6260 -26.4200  1.8070
#
#        time_server_pos    POSx    POSy    orient  label
# 0      1651505990.9168 31.4612 20.5103   -4.5177   2100
# 1      1651505991.0180 31.4529 20.6053   -5.4122   2099
# 2      1651505991.0180 31.4529 20.6053   -5.4122   2098
# 3      1651505991.2230 31.4423 20.7088   -6.1759   2097
# 4      1651505991.3341 31.4336 20.7628   -6.1412   2096
# ...                ...     ...     ...       ...    ...
# 14170  1651508387.0684 31.1923 26.9123 -155.9550      4
# 14171  1651508387.2108 31.1323 26.7749 -156.3772      3
# 14172  1651508387.3132 31.1065 26.7159 -156.3608      2
# 14173  1651508387.4155 31.0975 26.6952 -156.4760      1
# 14174  1651508387.5182 31.0989 26.6961 -156.5710      0
#
# [14175 rows x 10 columns]

# %%
n_sample_test_set = len(raw_df)

# %%
min_td, max_td, mean_td, len_td = describe(time_disalignments, list_quantiles=[.5, .9, .99, .999])
# Out:
# Min=3.099e-06, Max=2.52, Avg=0.04078, Tot=14175
# 0.5 : 0.037
# 0.9 : 0.049
# 0.99 : 0.148
# 0.999 : 1.815

# %%
print(f'On average, we have wait {mean_td:.4f} to merge acc e pos information')
# Out:
# On average, we have wait 0.0408 to merge acc e pos information

# %%
timings.append({"name": "merge_time", "time": mean_td})

# %% [markdown]
# ## Data processing

# %%
useful_columns_raw = ["Gz", "Ax", "Ay", 'POSx', 'POSy', 'orient', "label"]

# %%
start = time()
raw_df_reduced = raw_df[useful_columns_raw]
end = (time() - start) / n_sample_test_set
print(f"Executed in {end} seconds")
if end < min_time:
    print("EXECUTION TIME NEGLIGIBLE")
else:
    timings.append({"name": "filter0_time", "time": end})
# Out:
# Executed in 4.9752533120453044e-08 seconds
# EXECUTION TIME NEGLIGIBLE

# %%
# THIS OPERATION IS NOT PERFORMED AT INFERENCE TIME
df_split = []
fault_indexes = raw_df_reduced.index[raw_df_reduced["label"] == 0].tolist() # list of indexes representing faults
        
previous = 0
for fi in fault_indexes:
    df_split.append(raw_df_reduced.iloc[previous:fi+1, :])
    previous = fi + 1

# %%
# THIS OPERATION IS NOT PERFORMED AT INFERENCE TIME
print(f'There are {len(df_split)} faults, hence {len(df_split)} datasets.')
for i, df_tmp in enumerate(df_split):
    print(i, df_tmp.shape)
# Out:
# There are 13 faults, hence 13 datasets.
# 0 (2101, 7)
# 1 (1333, 7)
# 2 (1063, 7)
# 3 (1358, 7)
# 4 (957, 7)
# 5 (997, 7)
# 6 (968, 7)
# 35  0.3893  4.3700   2.3680 31.2313 23.7549  0.7299   2065
# 36  0.4046 -2.4170   6.7380 31.2274 23.8707  0.7147   2064
# 37  0.4656  1.3920  10.3800 31.2292 23.9906  1.0203   2063
# 38  0.3435 -2.6860   6.4700 31.2292 23.9906  1.0203   2062
# 39  0.3740  1.9530  -2.3440 31.2216 24.2202  1.3097   2061

# %% [markdown]
# ## Features creation

# %%
w_lens = [5, 10, 15, 20]

# %%
new_dfs = []
lag_features = []
first = True

for temps in df_split:
    curr_w_len_data = []
    curr_n_sample_test_set = len(temps)
    for w_len in w_lens:
        
        if first:
            start = time()
            
        means = temps.rolling(w_len).mean()

        if first:
            end = (time() - start) / curr_n_sample_test_set
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings.append({"name": f"lag_mean_{w_len}", "time": end})
        
        cols = [t + "_mean_w" + str(w_len) for t in temps.columns]
        means.columns = cols 
        curr_w_len_data.append(means)
        if first:
            lag_features.append(cols)
            
        if first:
            start = time()
        
        stds = temps.rolling(w_len).std()
        
        if first:
            end = (time() - start) / curr_n_sample_test_set
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings.append({"name": f"lag_std_{w_len}", "time": end})
        
        cols = [t + "_std_w" + str(w_len) for t in temps.columns]
        stds.columns = cols
        curr_w_len_data.append(stds)
        if first:
            lag_features.append(cols)
            
        if first:
            start = time()

        mins = temps.rolling(w_len).min()
        
        if first:
            end = (time() - start) / curr_n_sample_test_set
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings.append({"name": f"lag_min_{w_len}", "time": end})
        
        cols = [t + "_min_w" + str(w_len) for t in temps.columns]
        mins.columns = cols
        curr_w_len_data.append(mins)
        if first:
            lag_features.append(cols)
            
        if first:
            start = time()

        maxs = temps.rolling(w_len).max()
        
        if first:
            end = (time() - start) / curr_n_sample_test_set
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings.append({"name": f"lag_max_{w_len}", "time": end})
        
        cols = [t + "_max_w" + str(w_len) for t in temps.columns]
        maxs.columns = cols
        curr_w_len_data.append(maxs)
        if first:
            lag_features.append(cols)

    if first:
        start = time()        
    
    temps_diff = temps - temps.shift(1)
    
    if first:
        end = (time() - start) / curr_n_sample_test_set
        print(f"Executed in {end} seconds")
        if end < min_time:
            print("EXECUTION TIME NEGLIGIBLE")
        else:
            timings.append({"name": f"lag_diff_{w_len}", "time": end})
    
    temps_diff.columns = [t + "_diff" for t in temps.columns]

    df_with_nan = pd.concat([temps, temps_diff] + curr_w_len_data, axis=1)
    df_curr = df_with_nan.dropna()

    new_dfs.append(df_curr)
    
    first = False

df_new_features = new_dfs[0]
for to_concat in new_dfs[1:]:
    df_new_features = pd.concat([df_new_features, to_concat])
    
lag_features = [e for nested_lag_features in lag_features for e in nested_lag_features 
                if not e.startswith("POS") and not e.startswith("orient") and not e.startswith("label")]
# Out:
# Executed in 1.4787912368774414e-05 seconds
# Executed in 1.4907121658325195e-05 seconds
# Executed in 8.58306884765625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 8.469820022583007e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.450181007385254e-05 seconds
# Executed in 1.245737075805664e-05 seconds
# Executed in 9.638071060180663e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.0967254638671875e-05 seconds
# Executed in 1.0657310485839844e-05 seconds
# Executed in 1.220703125e-05 seconds
# Executed in 8.130073547363282e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.0216236114501953e-05 seconds
# Executed in 1.081228256225586e-05 seconds
# Executed in 1.3375282287597657e-05 seconds
# Executed in 9.500980377197266e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.0579824447631836e-05 seconds
# Executed in 8.529424667358398e-06 seconds
# EXECUTION TIME NEGLIGIBLE

# %%
point_features = ['Gz', 'Ax', 'Ay', 'Gz_diff', 
                  'Ax_diff', 'Ay_diff']
differencing_features = point_features + lag_features
new_features = differencing_features + ['POSx', 'POSy', 'orient', 'label']
df_new_features = df_new_features[new_features]
df_new_features = df_new_features.reset_index(drop=True)

# %%
processed_df_n_samples = len(df_new_features)

# %%
df_new_features.head()
# Out:
#       Gz      Ax      Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  Ax_mean_w5  \
# 0 0.5573  3.5640 -0.2930  -0.0381   6.1760   0.4150      0.5786      0.4101
# 1 0.4198 -0.6836  1.5140  -0.1375  -4.2476   1.8070      0.5496      0.6982
# 2 0.3588  7.3970  3.7840  -0.0610   8.0806   2.2700      0.5069      2.3729
# 3 0.5191  3.0270  1.6360   0.1603  -4.3700  -2.1480      0.4901      2.1385
# 4 0.6031  3.1010  4.1750   0.0840   0.0740   2.5390      0.4916      3.2811
#
#    Ay_mean_w5  Gz_std_w5  ...  Gz_min_w20  Ax_min_w20  Ay_min_w20  Gz_max_w20  \
# 0      2.4854     0.0198  ...     -0.4809     -3.9060     -5.4930      0.6031
# 1      1.4112     0.0748  ...     -0.4809     -3.9060     -5.4930      0.6031
# 2      1.7334     0.1108  ...     -0.4809     -3.3940     -5.4930      0.6031
# 3      1.1866     0.0983  ...     -0.3511     -3.3940     -5.4930      0.6031
# 4      2.1632     0.1004  ...     -0.2901     -3.3940     -4.3460      0.6031
#
#    Ax_max_w20  Ay_max_w20    POSx    POSy  orient  label
# 0      4.1990      6.8850 31.3119 21.9529 -3.7765   2081
# 1      4.1990      6.8850 31.3032 22.0414 -4.0979   2080
# 2      7.3970      6.8850 31.2962 22.1430 -3.8150   2079
# 3      7.3970      6.8850 31.2894 22.2473 -3.5266   2078
# 4      7.3970      6.8850 31.2765 22.3468 -3.2053   2077
#
# [5 rows x 58 columns]

# %%
df_new_features.describe()
# Out:
#            Gz      Ax       Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  \
# count 21.0000 21.0000  21.0000  21.0000  21.0000  21.0000     21.0000
# mean   0.5165  0.3183   1.0197  -0.0105   0.2174  -0.0779      0.5360
# std    0.1284  5.3193   4.9735   0.0976   7.6971   5.9218      0.0847
# min    0.3435 -9.5210 -10.3300  -0.1679 -22.6020 -14.5050      0.3939
# 25%    0.4046 -2.4170  -1.9530  -0.0992  -4.2476  -3.4670      0.4901
# 50%    0.5115 -0.6836   1.6360   0.0153   0.2930   0.4150      0.5496
# 75%    0.6183  3.1010   4.1750   0.0610   5.3220   3.6420      0.6046
# max    0.7481 15.6200  10.3800   0.1603  12.5190  12.1850      0.6657
#
#        Ax_mean_w5  Ay_mean_w5  Gz_std_w5  ...  Gz_min_w20  Ax_min_w20  \
# count     21.0000     21.0000    21.0000  ...     21.0000     21.0000
# mean       0.2987      0.8671     0.0881  ...      0.0607     -7.2147
# std        2.6388      2.4142     0.0367  ...      0.3180      2.5860
# min       -4.0186     -3.4228     0.0198  ...     -0.4809     -9.5210
# 25%       -2.1874     -0.7178     0.0616  ...     -0.1298     -9.5210
# 50%        0.4101      0.2834     0.0848  ...      0.1450     -6.9820
# 75%        2.1385      1.7920     0.1108  ...      0.3588     -3.9060
# max        5.6923      6.3582     0.1537  ...      0.3588     -3.3940
#
#        Ay_min_w20  Gz_max_w20  Ax_max_w20  Ay_max_w20    POSx    POSy  orient  \
# count     21.0000     21.0000     21.0000     21.0000 21.0000 21.0000 21.0000
# mean      -9.1237      0.7136     13.3576      7.3401 31.2538 23.0327 -1.1752
# std        2.2230      0.0633      4.2204      1.2831  0.0280  0.6975  1.7778
# min      -10.3300      0.6031      4.1990      6.1040 31.2216 21.9529 -4.0979
# 25%      -10.3300      0.7481     15.6200      6.8850 31.2312 22.4588 -2.7459
# 50%      -10.3300      0.7481     15.6200      6.8850 31.2429 23.0479 -0.9338
# 75%      -10.3300      0.7481     15.6200      6.8850 31.2707 23.5184  0.3247
# max       -4.3460      0.7481     15.6200     10.3800 31.3119 24.2202  1.3097
#
#           label
# count   21.0000
# mean  2071.0000
# std      6.2048
# min   2061.0000
# 25%   2066.0000
# 50%   2071.0000
# 75%   2076.0000
# max   2081.0000
#
# [8 rows x 58 columns]

# %%
df_new_features.columns.tolist()
# Out:
# ['Gz',
#  'Ax',
#  'Ay',
#  'Gz_diff',
#  'Ax_diff',
#  'Ay_diff',
#  'Gz_mean_w5',
#  'Ax_mean_w5',
#  'Ay_mean_w5',
#  'Gz_std_w5',
#  'Ax_std_w5',
#  'Ay_std_w5',
#  'Gz_min_w5',
#  'Ax_min_w5',
#  'Ay_min_w5',
#  'Gz_max_w5',
#  'Ax_max_w5',
#  'Ay_max_w5',
#  'Gz_mean_w10',
#  'Ax_mean_w10',
#  'Ay_mean_w10',
#  'Gz_std_w10',
#  'Ax_std_w10',
#  'Ay_std_w10',
#  'Gz_min_w10',
#  'Ax_min_w10',
#  'Ay_min_w10',
#  'Gz_max_w10',
#  'Ax_max_w10',
#  'Ay_max_w10',
#  'Gz_mean_w15',
#  'Ax_mean_w15',
#  'Ay_mean_w15',
#  'Gz_std_w15',
#  'Ax_std_w15',
#  'Ay_std_w15',
#  'Gz_min_w15',
#  'Ax_min_w15',
#  'Ay_min_w15',
#  'Gz_max_w15',
#  'Ax_max_w15',
#  'Ay_max_w15',
#  'Gz_mean_w20',
#  'Ax_mean_w20',
#  'Ay_mean_w20',
#  'Gz_std_w20',
#  'Ax_std_w20',
#  'Ay_std_w20',
#  'Gz_min_w20',
#  'Ax_min_w20',
#  'Ay_min_w20',
#  'Gz_max_w20',
#  'Ax_max_w20',
#  'Ay_max_w20',
#  'POSx',
#  'POSy',
#  'orient',
#  'label']

# %% [markdown]
# ## Handling seasonality with differencing over position and orientation

# %%
# THIS OPERATION IS NOT PERFORMED AT INFERENCE TIME
df_new_features["orient_discr"] = pd.Series([1 if (orient > fixed_orient[0][0] and orient < fixed_orient[0][1]) 
                                             else -1 if (orient < fixed_orient[1][0] or orient > fixed_orient[1][1]) 
                                             else 0 for orient in df_new_features["orient"]])
df_new_features["POSy_discr"] = pd.Series([find_nearest(fixed_pos, curr_pos, return_index=False) 
                                           for curr_pos in df_new_features["POSy"]])

# %%
df_new_features.head()
# Out:
#       Gz      Ax      Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  Ax_mean_w5  \
# 0 0.5573  3.5640 -0.2930  -0.0381   6.1760   0.4150      0.5786      0.4101
# 1 0.4198 -0.6836  1.5140  -0.1375  -4.2476   1.8070      0.5496      0.6982
# 2 0.3588  7.3970  3.7840  -0.0610   8.0806   2.2700      0.5069      2.3729
# 3 0.5191  3.0270  1.6360   0.1603  -4.3700  -2.1480      0.4901      2.1385
# 4 0.6031  3.1010  4.1750   0.0840   0.0740   2.5390      0.4916      3.2811
#
#    Ay_mean_w5  Gz_std_w5  ...  Ay_min_w20  Gz_max_w20  Ax_max_w20  Ay_max_w20  \
# 0      2.4854     0.0198  ...     -5.4930      0.6031      4.1990      6.8850
# 1      1.4112     0.0748  ...     -5.4930      0.6031      4.1990      6.8850
# 2      1.7334     0.1108  ...     -5.4930      0.6031      7.3970      6.8850
# 3      1.1866     0.0983  ...     -5.4930      0.6031      7.3970      6.8850
# 4      2.1632     0.1004  ...     -4.3460      0.6031      7.3970      6.8850
#
#      POSx    POSy  orient  label  orient_discr  POSy_discr
# 0 31.3119 21.9529 -3.7765   2081             1     22.0000
# 1 31.3032 22.0414 -4.0979   2080             1     22.0000
# 2 31.2962 22.1430 -3.8150   2079             1     22.1000
# 3 31.2894 22.2473 -3.5266   2078             1     22.2000
# 4 31.2765 22.3468 -3.2053   2077             1     22.3000
#
# [5 rows x 60 columns]

# %%
differencing_list = {feature: [] for feature in differencing_features}
all_keys = list(differencing_dict["Gz"].keys())

first = True

for _, row in df_new_features.iterrows():
    
    for feature in differencing_features:
        
        if first:
            start = time()
        
        try:
            differencing_list[feature].append(row[feature] - differencing_dict[feature][(row["orient_discr"], row["POSy_discr"])])
        # KeyError: some of the positions in the test set are not available in the training set
        except KeyError:
            same_orient = [e for e in all_keys if e[0] == row["orient_discr"]]
            closest_so = 9999
            for so in same_orient:
                if abs(so[1] - row["POSy_discr"]) < closest_so:
                    best_so = so
            differencing_list[feature].append(row[feature] - differencing_dict[feature][best_so])
    
        if first:
            end = (time() - start)  # just for one row, no division by "processed_df_n_samples" needed
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings.append({"name": "differencing_" + feature, "time": end})
            
    first = False
                       
for feature in differencing_features:
    df_new_features["differencing_" + feature] = pd.Series(differencing_list[feature])

df_new_features.head()
# Out:
# Executed in 1.7881393432617188e-05 seconds
# Executed in 9.775161743164062e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 5.9604644775390625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.0013580322265625e-05 seconds
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.198883056640625e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.67572021484375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.4373016357421875e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 6.9141387939453125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
#       Gz      Ax      Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  Ax_mean_w5  \
# 0 0.5573  3.5640 -0.2930  -0.0381   6.1760   0.4150      0.5786      0.4101
# 1 0.4198 -0.6836  1.5140  -0.1375  -4.2476   1.8070      0.5496      0.6982
# 2 0.3588  7.3970  3.7840  -0.0610   8.0806   2.2700      0.5069      2.3729
# 3 0.5191  3.0270  1.6360   0.1603  -4.3700  -2.1480      0.4901      2.1385
# 4 0.6031  3.1010  4.1750   0.0840   0.0740   2.5390      0.4916      3.2811
#
#    Ay_mean_w5  Gz_std_w5  ...  differencing_Ay_mean_w20  \
# 0      2.4854     0.0198  ...                   12.4785
# 1      1.4112     0.0748  ...                   12.6469
# 2      1.7334     0.1108  ...                   12.7689
# 3      1.1866     0.0983  ...                   12.9595
# 4      2.1632     0.1004  ...                   13.4665
#
#    differencing_Gz_std_w20  differencing_Ax_std_w20  differencing_Ay_std_w20  \
# 0                   0.0206                  -0.3517                  -1.1179
# 1                  -0.0001                  -0.3609                  -1.1238
# 2                  -0.0219                   0.0468                  -1.1842
# 3                  -0.0419                  -0.0521                  -1.4446
# 4                  -0.0413                  -0.0282                  -1.8361
#
#    differencing_Gz_min_w20  differencing_Ax_min_w20  differencing_Ay_min_w20  \
# 0                   0.0027                 -14.4887                  15.0739
# 1                   0.0027                 -14.4887                  15.0739
# 2                  -0.0015                 -13.9005                  15.4786
# 3                   0.1084                 -13.7198                  15.9500
# 4                   0.0881                 -13.7711                  17.4649
#
#    differencing_Gz_max_w20  differencing_Ax_max_w20  differencing_Ay_max_w20
# 0                  -0.4015                 -16.8227                  11.4140
# 1                  -0.4015                 -16.8227                  11.4140
# 2                  -0.3870                 -13.5096                  11.5254
# 3                  -0.3729                 -13.7971                  10.6884
# 4                  -0.3345                 -13.6622                  10.5459
#
# [5 rows x 114 columns]

# %%
df_new_features.columns
# Out:
# Index(['Gz', 'Ax', 'Ay', 'Gz_diff', 'Ax_diff', 'Ay_diff', 'Gz_mean_w5',
#        'Ax_mean_w5', 'Ay_mean_w5', 'Gz_std_w5',
#        ...
#        'differencing_Ay_mean_w20', 'differencing_Gz_std_w20',
#        'differencing_Ax_std_w20', 'differencing_Ay_std_w20',
#        'differencing_Gz_min_w20', 'differencing_Ax_min_w20',
#        'differencing_Ay_min_w20', 'differencing_Gz_max_w20',
#        'differencing_Ax_max_w20', 'differencing_Ay_max_w20'],
#       dtype='object', length=114)

# %%
timings
# Out:
# [{'name': 'merge_time', 'time': 0.04078222986251589},
#  {'name': 'lag_mean_5', 'time': 1.4787912368774414e-05},
#  {'name': 'lag_std_5', 'time': 1.4907121658325195e-05},
#  {'name': 'lag_mean_10', 'time': 1.450181007385254e-05},
#  {'name': 'lag_std_10', 'time': 1.245737075805664e-05},
#  {'name': 'lag_max_10', 'time': 1.0967254638671875e-05},
#  {'name': 'lag_mean_15', 'time': 1.0657310485839844e-05},
#  {'name': 'lag_std_15', 'time': 1.220703125e-05},
#  {'name': 'lag_max_15', 'time': 1.0216236114501953e-05},
#  {'name': 'lag_mean_20', 'time': 1.081228256225586e-05},
#  {'name': 'lag_std_20', 'time': 1.3375282287597657e-05},
#  {'name': 'lag_max_20', 'time': 1.0579824447631836e-05},
#  {'name': 'differencing_Gz', 'time': 1.7881393432617188e-05},
#  {'name': 'differencing_Ay_diff', 'time': 1.0013580322265625e-05}]

# %% [markdown]
# ## Features scaling

# %%
start = time()
df = pd.DataFrame(scaler.transform(df_new_features), 
                  columns=list(df_new_features.columns))
df = df.drop(columns=["label", 'orient_discr','POSy_discr'])
df["orient_discr"] = df_new_features["orient_discr"]
df["POSy_discr"] = df_new_features["POSy_discr"]
df["label"] = df_new_features["label"]
end = (time() - start)  / processed_df_n_samples
print(f"Executed in {end} seconds")
if end < min_time:
    print("EXECUTION TIME NEGLIGIBLE")
else:
    timings.append({"name": "scaler", "time": end})
df
# Out:
# Executed in 0.00014641171409970238 seconds
#         Gz      Ax     Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  Ax_mean_w5  \
# 0  -0.1934 -2.2683 2.7542  -0.0889   1.4190   0.0704     -0.1857     -4.3607
# 1  -0.2664 -3.2769 3.1463  -0.3202  -0.9684   0.3066     -0.2014     -4.2621
# 2  -0.2987 -1.3582 3.6389  -0.1422   1.8552   0.3852     -0.2246     -3.6892
# 3  -0.2137 -2.3959 3.1728   0.3729  -0.9964  -0.3645     -0.2337     -3.7694
# 4  -0.1691 -2.3783 3.7237   0.1953   0.0214   0.4309     -0.2328     -3.3785
# 5  -0.0922  0.5943 0.5763   0.3372   2.8717  -2.4612     -0.2122     -2.5536
# 6  -0.1448 -4.7724 3.2203  -0.2311  -5.1721   2.0676     -0.1874     -2.9846
# 7  -0.1125 -3.5087 2.3940   0.1418   1.2234  -0.6461     -0.1494     -3.6042
# 8  -0.1611 -3.4392 3.3793  -0.2134   0.0716   0.7706     -0.1387     -3.9049
# 9  -0.2299 -2.2277 4.1423  -0.3023   1.1730   0.5966     -0.1511     -3.8615
# 10 -0.1813 -4.2218 2.4153   0.2132  -1.9189  -1.3505     -0.1692     -5.2492
# 11 -0.1408 -5.3753 2.0655   0.1774  -1.1082  -0.2735     -0.1684     -5.4230
# 12 -0.1287 -3.1842 1.5569   0.0531   2.1180  -0.3977     -0.1717     -5.3294
#     differencing_Gz_max_w20  differencing_Ax_max_w20  differencing_Ay_max_w20  \
# 0                   -0.3088                  -6.5228                   3.6788
# 1                   -0.3088                  -6.5228                   3.6788
# 2                   -0.2976                  -5.2381                   3.7147
# 3                   -0.2867                  -5.3495                   3.4451
# 4                   -0.2572                  -5.2972                   3.3991
# 5                   -0.1191                  -2.2468                   3.2469
# 6                   -0.0912                  -2.3871                   3.1648
# 7                   -0.0940                  -2.2947                   2.8620
# 8                   -0.0304                  -2.3503                   2.7803
# 9                   -0.0407                  -2.2518                   2.7499
# 10                  -0.0380                  -2.4534                   2.7592
# 11                  -0.0277                  -2.3322                   2.5887
# 12                  -0.0466                  -2.4048                   2.3961
# 13                  -0.0466                  -2.4048                   2.3961
# 14                  -0.0442                  -2.2374                   2.4621
# 15                  -0.0522                  -2.3676                   2.4937
# 16                  -0.0701                  -2.3477                   2.1933
# 17                  -0.0819                  -2.3600                   2.2174
# 18                  -0.3737                  -2.2365                   4.0100
# 19                  -0.3737                  -2.2365                   4.0100
# 20                  -0.0981                  -2.4012                   3.6231
#
#     orient_discr  POSy_discr  label
# 0              1     22.0000   2081
# 1              1     22.0000   2080
# 2              1     22.1000   2079
# 3              1     22.2000   2078
# 4              1     22.3000   2077
# 5              1     22.5000   2076
# 6              1     22.6000   2075
# 7              1     22.7000   2074
# 8              1     22.8000   2073
# 9              1     22.9000   2072
# 10             1     23.0000   2071
# 11             1     23.2000   2070
# 12             1     23.3000   2069
# 13             1     23.3000   2068
# 14             1     23.4000   2067
# 15             1     23.5000   2066
# 16             1     23.8000   2065
# 17             1     23.9000   2064
# 18             1     24.0000   2063
# 19             1     24.0000   2062
# 20             1     24.2000   2061
#
# [21 rows x 114 columns]

# %%
df.describe()
# Out:
#            Gz      Ax      Ay  Gz_diff  Ax_diff  Ay_diff  Gz_mean_w5  \
# count 21.0000 21.0000 21.0000  21.0000  21.0000  21.0000     21.0000
# mean  -0.2151 -3.0390  3.0390  -0.0247   0.0543  -0.0132     -0.2088
# std    0.0681  1.2630  1.0792   0.2271   1.7629   1.0048      0.0458
# min   -0.3069 -5.3753  0.5763  -0.3909  -5.1721  -2.4612     -0.2857
# 25%   -0.2744 -3.6885  2.3940  -0.2311  -0.9684  -0.5883     -0.2337
# 50%   -0.2177 -3.2769  3.1728   0.0354   0.0716   0.0704     -0.2014
# 75%   -0.1611 -2.3783  3.7237   0.1418   1.2234   0.6180     -0.1717
# max   -0.0922  0.5943  5.0701   0.3729   2.8717   2.0676     -0.1387
#
#        Ax_mean_w5  Ay_mean_w5  Gz_std_w5  ...  differencing_Ay_std_w20  \
# count     21.0000     21.0000    21.0000  ...                  21.0000
# mean      -4.3987      5.5456    -0.6405  ...                  -1.6830
# std        0.9027      0.9665     0.1221  ...                   0.4004
# min       -5.8757      3.8282    -0.8680  ...                  -2.4089
# 25%       -5.2492      4.9111    -0.7286  ...                  -1.9654
# 50%       -4.3607      5.3119    -0.6516  ...                  -1.7329
# 75%       -3.7694      5.9159    -0.5648  ...                  -1.3259
# max       -2.5536      7.7439    -0.4221  ...                  -0.9592
#
#        differencing_Gz_min_w20  differencing_Ax_min_w20  \
# count                  21.0000                  21.0000
# mean                    0.0899                  -5.3669
# std                     0.1176                   0.5993
# min                    -0.0876                  -6.1709
# 25%                     0.0025                  -5.8035
# 50%                     0.0629                  -5.4802
# 75%                     0.2011                  -4.7709
# max                     0.3316                  -4.3520
#
#        differencing_Ay_min_w20  differencing_Gz_max_w20  \
# count                  21.0000                  21.0000
# mean                    4.4810                  -0.1470
# std                     0.4331                   0.1264
# min                     3.8160                  -0.3737
# 25%                     4.0960                  -0.2867
# 50%                     4.5346                  -0.0912
# 75%                     4.7837                  -0.0466
# max                     5.5422                  -0.0277
#
#        differencing_Ax_max_w20  differencing_Ay_max_w20  orient_discr  \
# count                  21.0000                  21.0000       21.0000
# mean                   -3.1544                   3.0414        1.0000
# std                     1.5385                   0.5986        0.0000
# min                    -6.5228                   2.1933        1.0000
# 25%                    -2.4534                   2.4937        1.0000
# 50%                    -2.3676                   2.8620        1.0000
# 75%                    -2.2947                   3.6231        1.0000
# max                    -2.2365                   4.0100        1.0000
#
#        POSy_discr     label
# count     21.0000   21.0000
# mean      23.0333 2071.0000
# std        0.7066    6.2048
# min       22.0000 2061.0000
# 25%       22.5000 2066.0000
# 50%       23.0000 2071.0000
# 75%       23.5000 2076.0000
# max       24.2000 2081.0000
#
# [8 rows x 114 columns]

# %% [markdown]
# # Machine learning timings
#
# ### Note: only timings of models' inference are considered, since only them occur in the online phase

# %% [markdown]
# ## Dataset preprocessing for machine learning models
#
# In this section, RUL labels are converted to binary labels (`0/1`, namely `not_fault/fault`) in order to perform classification instead of regression.
#
# For the `AutoEncoder` model, the dataset is partitioned such that the training set does not contain faults or samples which anticipate a fault. In other words, each sample must be compliant with the `good_samples_thr` threshold.
#
# We basically need an entire section of dataset where faults are not present.

# %%
def build_dataset_for_ml_model(df, training_columns, split_size=0.75, as_list=False, ae=False):
    ### START code slightly changed 
    dfs = []
    df_main = df[training_columns]
    good_samples_thr = margin * 2
    
    dfs.append(df_main)
    ### END code slightly changed 
    
    rnd_list = list(range(len(dfs)))
    
    # If split_size is 1, there will be no val/test set
    train_size = floor(len(dfs) * split_size)
    train_index = rnd_list[:train_size]
    test_index = rnd_list[train_size:]
    train_rul = []
    test_rul = []
    
    if not as_list:
        first = True
        for ti in train_index:
            if not ae:
                to_concat = dfs[ti].copy()
            else:
                to_concat = dfs[ti][dfs[ti]["label"] >= good_samples_thr].copy()
            if first:
                training_set = to_concat
                first = False
            else:
                training_set = pd.concat([training_set, to_concat])

        first = True
        for ti in test_index:
            to_concat = dfs[ti].copy()
            if first:
                test_set = to_concat
                first = False
            else:
                test_set = pd.concat([test_set, to_concat])
        
        train_rul = training_set['label'].tolist()
        if split_size < 1:
            test_rul = test_set['label'].tolist()
        
        training_set['label'] = (training_set['label'] >= margin).map({True: 1, False: 0})
        if split_size < 1:
            test_set['label'] = (test_set['label'] >= margin).map({True: 1, False: 0})

        training_set = training_set.to_numpy()
        if split_size < 1:
            test_set = test_set.to_numpy()
        
    else:
        first = True
        for ti in train_index:
            if not ae:
                to_concat = dfs[ti].copy()
            else:
                to_concat = dfs[ti][dfs[ti]["label"] >= good_samples_thr].copy()
            if first:
                training_set = [to_concat]
                first = False
            else:
                training_set.append(to_concat)
                
        first = True
        for ti in test_index:
            to_concat = dfs[ti].copy()
            if first:
                test_set = [to_concat]
                first = False
            else:
                test_set.append(to_concat)
        
        for t in training_set:
            train_rul = train_rul + t['label'].tolist()
            t['label'] = (t['label'] >= margin).map({True: 1, False: 0})
        if split_size < 1:
            for t in test_set:
                test_rul = test_rul + t['label'].tolist()
                t['label'] = (t['label'] >= margin).map({True: 1, False: 0})
    if split_size < 1:
        return training_set, test_set
    return training_set

# %% [markdown]
# ## Cost model for threshold optimization and performance evaluation

# %%
all_perf = []

# %%
BASE_FP = 0.2
BASE_FN = 1

def false_positive_cost(i, is_fault, fault_found):
    return BASE_FP

def false_negative_cost(i, is_fault, fault_found):
    if not fault_found:
        for j in range(1, margin + 1):
            if i + j < is_fault.shape[0] and not is_fault[i + j] or i + j >= is_fault.shape[0]:
                return (margin + 1 - j) * BASE_FN
    else:
        return 0

# %%
def threshold_optimization(signal, rul, start, end, n_steps):
    best_cost = sys.maxsize
    best_thr = -1
    all_cost = []
    all_thr = []
    is_fault = (rul == 0)
    
    for thr in np.linspace(start, end, n_steps):
        tmp_cost = 0
        fault_found = False
        for i in range(signal.shape[0]):
            if is_fault[i] and signal[i] >= thr:
                fault_found = True
            if not is_fault[i]:
                fault_found = False
            if not is_fault[i] and signal[i] >= thr:
                tmp_cost += false_positive_cost(i, is_fault, fault_found)
            elif is_fault[i] and signal[i] <= thr:
                tmp_cost += false_negative_cost(i, is_fault, fault_found)
        if tmp_cost < best_cost:
            best_thr = thr
            best_cost = tmp_cost
        all_cost.append(tmp_cost)
        all_thr.append(thr)

    return best_cost, best_thr, all_cost, all_thr

# %%
def performance_evaluation(signal, thr, rul):
    fp, fn, tp, tot_p = 0, 0, 0, 0
    cost = 0
    alarm = (signal >= thr)
    anticipation = []
    is_fault = (rul == 0)
    
    fault_found = False
    for i in range(len(rul)):
        if i > 0 and is_fault[i] and not is_fault[i - 1]:
            tot_p += 1
            start = i
        if is_fault[i] and not fault_found and alarm[i]:
            tp += 1
            fault_found = True
            anticipation.append((margin - 1) - (i - start))
        if (i < len(rul) - 1 and is_fault[i] and not is_fault[i + 1] and not fault_found) or (i == len(rul) - 1 and not fault_found):
            fn += 1 
        if is_fault[i] and signal[i] <= thr:
            cost += false_negative_cost(i, is_fault, fault_found)
        if not is_fault[i]:
            fault_found = False
            if alarm[i]:
                fp += 1
                cost += false_positive_cost(i, is_fault, fault_found)
        
    tot_a = sum(anticipation) / 10
    if sum(anticipation) > 0:
        mean_a = mean(anticipation) / 10
    else:
        mean_a = 0
    
    return [cost, mean_a, tp, fn, fp]

# %% [markdown]
# ## Baseline: raw signal pre-anomaly detection

# %%
features_raw = [
 'Ax',
 'Ax_diff',
 'Ax_mean_w5',
 'Ax_std_w5',
 'Ax_min_w5',
 'Ax_max_w5',
 'Ax_mean_w10',
 'Ax_std_w10',
 'Ax_min_w10',
 'Ax_max_w10',
 'Ax_mean_w15',
 'Ax_std_w15',
 'Ax_min_w15',
 'Ax_max_w15',
 'Ax_mean_w20',
 'Ax_std_w20',
 'Ax_min_w20',
 'Ax_max_w20',
 'differencing_Ax',
 'differencing_Ax_diff',
 'differencing_Ax_mean_w5',
 'differencing_Ax_std_w5',
 'differencing_Ax_min_w5',
 'differencing_Ax_max_w5',
 'differencing_Ax_mean_w10',
 'differencing_Ax_std_w10',
 'differencing_Ax_min_w10',
 'differencing_Ax_max_w10',
 'differencing_Ax_mean_w15',
 'differencing_Ax_std_w15',
 'differencing_Ax_min_w15',
 'differencing_Ax_max_w15',
 'differencing_Ax_mean_w20',
 'differencing_Ax_std_w20',
 'differencing_Ax_min_w20',
 'differencing_Ax_max_w20',
]

for seed in seeds:
    for feature in features_raw:
        
        f = results_path + "raw_signal-" + feature + "-s" + str(seed) + "-p0"
        with open(f, "rb") as file:
            _, _, _, best_cost_raw, best_thr_raw, _, _, _ = pickle.load(file)
        
        training_columns = [feature, "label"]
        test_set_raw = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
        
        test_set_raw = test_set_raw[0, :]
        
        start = time()
        
        test_raw_signal, test_raw_rul = -test_set_raw[0], test_set_raw[-1]
        alarm_signal = (test_raw_signal >= best_thr_raw)
        
        end = (time() - start)
        print(f"Executed in {end} seconds")
        if end < min_time:
            print("EXECUTION TIME NEGLIGIBLE")
        else:
            timings_net.append({"name": "raw_signal_" + feature, "time": end})
# Out:
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.6689300537109375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.430511474609375e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 1.1920928955078125e-06 seconds
# EXECUTION TIME NEGLIGIBLE
# Executed in 9.5367431640625e-07 seconds
# EXECUTION TIME NEGLIGIBLE

# %% [markdown]
# ## Autoencoders

# %%
params_ae = [{"hidden_ae": [16, 8, 2, 8, 16]}, 
             {"hidden_ae": [64, 24, 9, 24, 64]}, 
             {"hidden_ae": [128, 56, 18, 56, 128]}]

for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_ae):
            
            ae = keras.models.load_model(models_path + "autoencoder" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "autoencoder-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_ae, best_thr_ae, _, _, _ = pickle.load(file)
            
            test_set_ae = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
        
            start = time()
            
            test_preds_ae = ae.predict(np.expand_dims(test_set_ae[0, :-1], axis=0))
            test_signal_ae = pd.Series(data=np.sum(np.square(test_preds_ae - test_set_ae[:0, :-1]), axis=1))
            alarm_signal = (test_signal_ae >= best_thr_ae)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "autoencoder_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# 1/1 [==============================] - 1s 525ms/step
# Executed in 0.5608334541320801 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.061768531799316406 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.0612640380859375 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06390666961669922 seconds
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f83242d9700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 44ms/step
# Executed in 0.06466412544250488 seconds
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8324ef3b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.06286978721618652 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06065702438354492 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06090259552001953 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.061189889907836914 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.061929941177368164 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06064414978027344 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06004023551940918 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.06210160255432129 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06094241142272949 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06134986877441406 seconds
# 1/1 [==============================] - 0s 43ms/step
# Executed in 0.06622743606567383 seconds
# 1/1 [==============================] - 0s 43ms/step
# Executed in 0.06241440773010254 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.06125330924987793 seconds
# 1/1 [==============================] - 0s 41ms/step
# Executed in 0.061150550842285156 seconds
# 1/1 [==============================] - 0s 44ms/step
# Executed in 0.06397581100463867 seconds
# 1/1 [==============================] - 0s 42ms/step
# Executed in 0.06228971481323242 seconds

# %% [markdown]
# ## Dense Neural Network

# %%
params_mlp = [{"hidden_mlp": []},
              {"hidden_mlp": [32]},
              {"hidden_mlp": [64, 32]}, 
              {"hidden_mlp": [128, 64, 32]}]

for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_mlp):
            mlp = keras.models.load_model(models_path + "mlp" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "mlp-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_mlp, best_thr_mlp, _, _, _ = pickle.load(file)
            
            test_set_mlp = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
            
            start = time()
            
            test_preds_mlp = mlp.predict(np.expand_dims(test_set_mlp[0, :-1], axis=0)).ravel()
            test_signal_mlp =  pd.Series(data=(1 - test_preds_mlp))
            alarm_signal = (test_signal_mlp >= best_thr_mlp)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "mlp_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Executed in 0.04433107376098633 seconds
# 1/1 [==============================] - 0s 28ms/step
# Executed in 0.047879695892333984 seconds
# 1/1 [==============================] - 0s 32ms/step
# Executed in 0.05115699768066406 seconds
# 1/1 [==============================] - 0s 36ms/step
# Executed in 0.05597376823425293 seconds
# 1/1 [==============================] - 0s 25ms/step
# Executed in 0.04470705986022949 seconds
# 1/1 [==============================] - 0s 29ms/step
# Executed in 0.04809451103210449 seconds
# 1/1 [==============================] - 0s 31ms/step
# Executed in 0.0507512092590332 seconds
# 1/1 [==============================] - 0s 35ms/step
# Executed in 0.05428147315979004 seconds
# 1/1 [==============================] - 0s 24ms/step
# Executed in 0.04319000244140625 seconds
# 1/1 [==============================] - 0s 28ms/step
# Executed in 0.0471649169921875 seconds
# 1/1 [==============================] - 0s 33ms/step
# Executed in 0.053197622299194336 seconds
# 1/1 [==============================] - 0s 36ms/step
# Executed in 0.05628228187561035 seconds
# 1/1 [==============================] - 0s 25ms/step
# Executed in 0.045440673828125 seconds
# 1/1 [==============================] - 0s 28ms/step
# Executed in 0.04762434959411621 seconds
# 1/1 [==============================] - 0s 31ms/step
# Executed in 0.0508723258972168 seconds
# 1/1 [==============================] - 0s 35ms/step
# Executed in 0.05413627624511719 seconds
# 1/1 [==============================] - 0s 24ms/step
# Executed in 0.04352927207946777 seconds
# 1/1 [==============================] - 0s 30ms/step
# Executed in 0.04971933364868164 seconds
# 1/1 [==============================] - 0s 32ms/step
# Executed in 0.051610708236694336 seconds
# 1/1 [==============================] - 0s 35ms/step
# Executed in 0.05391883850097656 seconds
# 1/1 [==============================] - 0s 24ms/step
# Executed in 0.04316544532775879 seconds
# 1/1 [==============================] - 0s 28ms/step
# Executed in 0.046918630599975586 seconds
# 1/1 [==============================] - 0s 31ms/step
# Executed in 0.05103278160095215 seconds
# 1/1 [==============================] - 0s 37ms/step
# Executed in 0.05677390098571777 seconds
# 1/1 [==============================] - 0s 26ms/step
# Executed in 0.04684090614318848 seconds
# 1/1 [==============================] - 0s 28ms/step
# Executed in 0.047831058502197266 seconds
# 1/1 [==============================] - 0s 31ms/step
# Executed in 0.050729990005493164 seconds
# 1/1 [==============================] - 0s 34ms/step
# Executed in 0.05430412292480469 seconds

# %% [markdown]
# ## Convolutional Neural Network

# %%
def sliding_window_2D(data, w_len, stride=1):
    # Get shifted tables
    m = len(data)
    lt = [data.iloc[i:m-w_len+i+1:stride, :].values for i in range(w_len)]
    # Reshape to add a new axis
    s = lt[0].shape
    for i in range(w_len):
        lt[i] = lt[i].reshape(s[0], 1, s[1])
    # Concatenate
    wdata = np.concatenate(lt, axis=1)
    return wdata


def sliding_window_by_fault(data, cols, w_len, stride=1):
    l_w, l_r = [], []
    cols.pop()
    for gdata in data:
        # Apply a sliding window
        tmp_w = sliding_window_2D(gdata[cols], w_len, stride)
        # Build the RUL vector
        tmp_r = gdata['label'].iloc[w_len-1::stride]
        # Store everything
        l_w.append(tmp_w)
        l_r.append(tmp_r)
    res_w = np.concatenate(l_w)
    res_r = np.concatenate(l_r)
    return res_w, res_r

# %%
params_cnn = [{"filters": 1, "kernel_size": 3, "hidden": [32], "w_len": 5},
              {"filters": 4, "kernel_size": 3, "hidden": [32], "w_len": 5},
              {"filters": 1, "kernel_size": 5, "hidden": [32], "w_len": 5},
              {"filters": 4, "kernel_size": 5, "hidden": [32], "w_len": 5},
              {"filters": 4, "kernel_size": 5, "hidden": [64, 32], "w_len": 5},
              {"filters": 1, "kernel_size": 3, "hidden": [32], "w_len": 10},
              {"filters": 4, "kernel_size": 3, "hidden": [32], "w_len": 10},
              {"filters": 1, "kernel_size": 5, "hidden": [32], "w_len": 10},
              {"filters": 4, "kernel_size": 5, "hidden": [32], "w_len": 10},
              {"filters": 4, "kernel_size": 5, "hidden": [64, 32], "w_len": 10},
              {"filters": 4, "kernel_size": 7, "hidden": [128, 64, 32], "w_len": 10}]

# %%
for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_cnn):
            
            cnn = keras.models.load_model(models_path + "conv_nn" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "conv_nn-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_cnn, best_thr_cnn, _, _, _ = pickle.load(file)
            
            test_set_cnn = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1, as_list=True)
            ts_sw, ts_sw_r = sliding_window_by_fault(test_set_cnn, training_columns, params["w_len"])

            start = time()
            
            test_preds_cnn = cnn.predict(np.expand_dims(ts_sw[0], axis=0)).ravel()
            test_signal_cnn =  pd.Series(data=(1 - test_preds_cnn))
            alarm_signal = (test_signal_cnn >= best_thr_cnn)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "cnn_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# [[[-0.18574795 -4.36065588  6.19347702 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]]
#
#  [[-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]
#   [-0.21218094 -2.55364819  5.26083089 ... -2.24679809  3.24690416
#     1.        ]]
#
#  [[-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]
#   [-0.21218094 -2.55364819  5.26083089 ... -2.24679809  3.24690416
#     1.        ]
#   [-0.18739257 -2.98457686  5.28813449 ... -2.38707591  3.16477735
#     1.        ]]
#
#  ...
#
#  [[-0.19234808 -5.87567971  3.82815257 ... -2.23742329  2.46208065
#     1.        ]
#   [-0.21548101 -5.66522362  4.44388477 ... -2.36757158  2.49367405
#     1.        ]
#   [-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]]
#
#  [[-0.21548101 -5.66522362  4.44388477 ... -2.36757158  2.49367405
#     1.        ]
#   [-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]
#   [-0.2857021  -4.5644343   7.74393715 ... -2.23647756  4.0100256
#     1.        ]]
#
#  [[-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]
#   [-0.2857021  -4.5644343   7.74393715 ... -2.23647756  4.0100256
#     1.        ]
#   [-0.28487979 -4.32223191  7.08905111 ... -2.40115703  3.62314775
#     1.        ]]]
# 1/1 [==============================] - 1s 955ms/step
# Executed in 0.9775769710540771 seconds
# [[[-0.18574795 -4.36065588  6.19347702 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]]
#
#  [[-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]
#   [-0.21218094 -2.55364819  5.26083089 ... -2.24679809  3.24690416
#     1.        ]]
#
#  [[-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]
#   [-0.21218094 -2.55364819  5.26083089 ... -2.24679809  3.24690416
#     1.        ]
#   [-0.18739257 -2.98457686  5.28813449 ... -2.38707591  3.16477735
#     1.        ]]
#
#  ...
#
#  [[-0.19234808 -5.87567971  3.82815257 ... -2.23742329  2.46208065
#     1.        ]
#   [-0.21548101 -5.66522362  4.44388477 ... -2.36757158  2.49367405
#     1.        ]
#   [-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]]
#
#  [[-0.21548101 -5.66522362  4.44388477 ... -2.36757158  2.49367405
#     1.        ]
#   [-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]
#   [-0.2857021  -4.5644343   7.74393715 ... -2.23647756  4.0100256
#     1.        ]]
#
#  [[-0.24439176 -4.71481872  4.9110886  ... -2.34773359  2.19333392
#     1.        ]
#   [-0.27412482 -4.86014015  5.91587708 ... -2.35998251  2.21737101
#     1.        ]
#   [-0.27909115 -4.62956895  7.2024291  ... -2.23647756  4.0100256
#     1.        ]
#   [-0.2857021  -4.5644343   7.74393715 ... -2.23647756  4.0100256
#     1.        ]
#   [-0.28487979 -4.32223191  7.08905111 ... -2.40115703  3.62314775
#     1.        ]]]
# 1/1 [==============================] - 0s 39ms/step
# Executed in 0.060552120208740234 seconds
# [[[-0.18574795 -4.36065588  6.19347702 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]]
#
#  [[-0.20144761 -4.26210551  5.76342531 ... -6.52276218  3.67879632
#     1.        ]
#   [-0.22456972 -3.68919424  5.8924168  ... -5.23807701  3.71470113
#     1.        ]
#   [-0.23365842 -3.76938102  5.67350759 ... -5.34953216  3.44507109
#     1.        ]
#   [-0.23282529 -3.37850468  6.06448553 ... -5.29723788  3.3991465
#     1.        ]
#   [-0.21218094 -2.55364819  5.26083089 ...
+00 ... -2.23647756e+00
#     4.01002560e+00  1.00000000e+00]]
#
#  [[ 8.68576934e-02 -8.41215194e+00  5.57524324e+00 ... -2.33220298e+00
#     2.58869033e+00  1.00000000e+00]
#   [ 1.13167167e-01 -8.22544232e+00  5.13736539e+00 ... -2.40479703e+00
#     2.39606814e+00  1.00000000e+00]
#   [ 9.89116357e-02 -8.28482237e+00  4.45350100e+00 ... -2.40479703e+00
#     2.39606814e+00  1.00000000e+00]
#   ...
#   [-1.20374130e-01 -6.27879278e+00  7.59023989e+00 ... -2.23647756e+00
#     4.01002560e+00  1.00000000e+00]
#   [-1.28529682e-01 -6.18627263e+00  8.14908171e+00 ... -2.23647756e+00
#     4.01002560e+00  1.00000000e+00]
#   [ 1.10252775e-01 -6.53792315e+00  7.55999146e+00 ... -2.40115703e+00
#     3.62314775e+00  1.00000000e+00]]]
# 1/1 [==============================] - 0s 51ms/step
# Executed in 0.07509970664978027 seconds

# %% [markdown]
# ## Recurrent Neural Network (LSTM)

# %%
def create_dataset_3D(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

# %%
params_rnn = [{"time_steps": 5, "units": 64},
              {"time_steps": 5, "units": 128},
              {"time_steps": 10, "units": 64},
              {"time_steps": 10, "units": 128}]

# %%
for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_rnn):
            
            model_lstm = keras.models.load_model(models_path + "lstm" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "lstm-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_lstm, best_thr_lstm, _, _, _ = pickle.load(file)
            
            test_set_lstm = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
            X_test_lstm, y_test_lstm = create_dataset_3D(test_set_lstm[:, :-1], 
                                           test_set_lstm[:, -1], 
                                           params["time_steps"])            

            start = time()
            
            test_preds_lstm = model_lstm.predict(np.expand_dims(X_test_lstm[0], axis=0)).ravel()
            test_signal_lstm =  pd.Series(data=(1 - test_preds_lstm))
            alarm_signal = (test_signal_lstm >= best_thr_lstm)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "lstm_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# 1/1 [==============================] - 0s 466ms/step
# Executed in 0.4913747310638428 seconds
# 1/1 [==============================] - 0s 354ms/step
# Executed in 0.3746340274810791 seconds
# 1/1 [==============================] - 0s 343ms/step
# Executed in 0.36623215675354004 seconds
# 1/1 [==============================] - 0s 348ms/step
# Executed in 0.3684544563293457 seconds
# 1/1 [==============================] - 0s 348ms/step
# Executed in 0.37064647674560547 seconds
# 1/1 [==============================] - 0s 347ms/step
# Executed in 0.3672506809234619 seconds
# 1/1 [==============================] - 1s 804ms/step
# Executed in 0.8275060653686523 seconds
# 1/1 [==============================] - 0s 350ms/step
# Executed in 0.3700113296508789 seconds
# 1/1 [==============================] - 0s 353ms/step
# Executed in 0.3732740879058838 seconds
# 1/1 [==============================] - 0s 357ms/step
# Executed in 0.3778057098388672 seconds
# 1/1 [==============================] - 0s 362ms/step
# Executed in 0.3830568790435791 seconds
# 1/1 [==============================] - 0s 346ms/step
# Executed in 0.36663007736206055 seconds
# 1/1 [==============================] - 0s 350ms/step
# Executed in 0.37134218215942383 seconds
# 1/1 [==============================] - 0s 346ms/step
# Executed in 0.3667609691619873 seconds
# 1/1 [==============================] - 0s 345ms/step
# Executed in 0.36559629440307617 seconds
# 1/1 [==============================] - 0s 354ms/step
# Executed in 0.37505006790161133 seconds
# 1/1 [==============================] - 0s 360ms/step
# Executed in 0.381131649017334 seconds
# 1/1 [==============================] - 0s 343ms/step
# Executed in 0.3640015125274658 seconds
# 1/1 [==============================] - 0s 346ms/step
# Executed in 0.3662528991699219 seconds
# 1/1 [==============================] - 0s 346ms/step
# Executed in 0.36593079566955566 seconds
# 1/1 [==============================] - 0s 344ms/step
# Executed in 0.3661463260650635 seconds
# 1/1 [==============================] - 0s 339ms/step
# Executed in 0.3636500835418701 seconds
# 1/1 [==============================] - 0s 366ms/step
# Executed in 0.3903491497039795 seconds
# 1/1 [==============================] - 0s 351ms/step
# Executed in 0.3721601963043213 seconds
# 1/1 [==============================] - 0s 344ms/step
# Executed in 0.36423158645629883 seconds
# 1/1 [==============================] - 0s 348ms/step
# Executed in 0.36821603775024414 seconds
# 1/1 [==============================] - 0s 369ms/step
# Executed in 0.3886411190032959 seconds
# 1/1 [==============================] - 0s 360ms/step
# Executed in 0.3808412551879883 seconds

# %% [markdown]
# ## Recurrent Neural Network (GRU)

# %%
for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_rnn):
            
            model_gru = keras.models.load_model(models_path + "gru" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "gru-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_gru, best_thr_gru, _, _, _ = pickle.load(file)
            
            test_set_gru = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
            X_test_gru, y_test_gru = create_dataset_3D(test_set_gru[:, :-1], 
                                           test_set_gru[:, -1], 
                                           params["time_steps"])            
            
            start = time()
            
            test_preds_gru = model_gru.predict(np.expand_dims(X_test_gru[0], axis=0)).ravel()
            test_signal_gru =  pd.Series(data=(1 - test_preds_gru))
            alarm_signal = (test_signal_gru >= best_thr_gru)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "gru_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# 1/1 [==============================] - 0s 312ms/step
# Executed in 0.3331615924835205 seconds
# 1/1 [==============================] - 0s 308ms/step
# Executed in 0.32822132110595703 seconds
# 1/1 [==============================] - 0s 314ms/step
# Executed in 0.33524417877197266 seconds
# 1/1 [==============================] - 0s 308ms/step
# Executed in 0.3288607597351074 seconds
# 1/1 [==============================] - 0s 308ms/step
# Executed in 0.3281073570251465 seconds
# 1/1 [==============================] - 0s 307ms/step
# Executed in 0.3280057907104492 seconds
# 1/1 [==============================] - 0s 310ms/step
# Executed in 0.33014535903930664 seconds
# 1/1 [==============================] - 0s 306ms/step
# Executed in 0.3263876438140869 seconds
# 1/1 [==============================] - 0s 334ms/step
# Executed in 0.356060266494751 seconds
# 1/1 [==============================] - 0s 322ms/step
# Executed in 0.34317779541015625 seconds
# 1/1 [==============================] - 0s 311ms/step
# Executed in 0.3317267894744873 seconds
# 1/1 [==============================] - 0s 315ms/step
# Executed in 0.33489346504211426 seconds
# 1/1 [==============================] - 0s 329ms/step
# Executed in 0.34979963302612305 seconds
# 1/1 [==============================] - 0s 311ms/step
# Executed in 0.33174681663513184 seconds
# 1/1 [==============================] - 0s 302ms/step
# Executed in 0.32549452781677246 seconds
# 1/1 [==============================] - 0s 302ms/step
# Executed in 0.3223226070404053 seconds
# 1/1 [==============================] - 0s 317ms/step
# Executed in 0.3380589485168457 seconds
# 1/1 [==============================] - 0s 305ms/step
# Executed in 0.32533717155456543 seconds
# 1/1 [==============================] - 0s 301ms/step
# Executed in 0.32474255561828613 seconds
# 1/1 [==============================] - 0s 307ms/step
# Executed in 0.32704806327819824 seconds
# 1/1 [==============================] - 0s 312ms/step
# Executed in 0.33681535720825195 seconds
# 1/1 [==============================] - 0s 308ms/step
# Executed in 0.3276941776275635 seconds
# 1/1 [==============================] - 0s 323ms/step
# Executed in 0.3437199592590332 seconds
# 1/1 [==============================] - 0s 313ms/step
# Executed in 0.3342406749725342 seconds
# 1/1 [==============================] - 0s 309ms/step
# Executed in 0.330089807510376 seconds
# 1/1 [==============================] - 0s 313ms/step
# Executed in 0.3342757225036621 seconds
# 1/1 [==============================] - 0s 323ms/step
# Executed in 0.3440878391265869 seconds
# 1/1 [==============================] - 0s 315ms/step
# Executed in 0.33615922927856445 seconds

# %% [markdown]
# ## Recurrent Neural Network (BiLSTM)

# %%
for seed in seeds:
    for columns in features:
        for params_idx, params in enumerate(params_rnn):
            
            model_bilstm = keras.models.load_model(models_path + "bilstm" + "-" + columns + "-s" + str(seed) + "-p" + str(params_idx))
            f = results_path + "bilstm-" + columns + "-s" + str(seed) + "-p" + str(params_idx)
            with open(f, "rb") as file:
                training_columns, _, _, best_cost_bilstm, best_thr_bilstm, _, _, _ = pickle.load(file)
            
            test_set_bilstm = build_dataset_for_ml_model(df, training_columns=training_columns, split_size=1)
            X_test_bilstm, y_test_bilstm = create_dataset_3D(test_set_bilstm[:, :-1], 
                                           test_set_bilstm[:, -1], 
                                           params["time_steps"])                      
            
            start = time()
            
            test_preds_bilstm = model_bilstm.predict(np.expand_dims(X_test_bilstm[0], axis=0)).ravel()
            test_signal_bilstm =  pd.Series(data=(1 - test_preds_bilstm))
            alarm_signal = (test_signal_gru >= best_thr_gru)

            end = (time() - start)
            print(f"Executed in {end} seconds")
            if end < min_time:
                print("EXECUTION TIME NEGLIGIBLE")
            else:
                timings_net.append({"name": "bilstm_" + columns + "_p" + str(params_idx), "time": end})
# Out:
# 1/1 [==============================] - 1s 667ms/step
# Executed in 0.6883318424224854 seconds
# 1/1 [==============================] - 1s 662ms/step
# Executed in 0.682114839553833 seconds
# 1/1 [==============================] - 1s 684ms/step
# Executed in 0.7049915790557861 seconds
# 1/1 [==============================] - 1s 670ms/step
# Executed in 0.6916570663452148 seconds
# 1/1 [==============================] - 1s 671ms/step
# Executed in 0.6917862892150879 seconds
# 1/1 [==============================] - 1s 676ms/step
# Executed in 0.6970171928405762 seconds
# 1/1 [==============================] - 1s 659ms/step
# Executed in 0.6792292594909668 seconds
# 1/1 [==============================] - 1s 671ms/step
# Executed in 0.6915590763092041 seconds
# 1/1 [==============================] - 1s 685ms/step
# Executed in 0.7063710689544678 seconds
# 1/1 [==============================] - 1s 668ms/step
# Executed in 0.6890983581542969 seconds
# 1/1 [==============================] - 1s 664ms/step
# Executed in 0.6849789619445801 seconds
# 1/1 [==============================] - 1s 655ms/step
# Executed in 0.6750645637512207 seconds
# 1/1 [==============================] - 1s 661ms/step
# Executed in 0.6824078559875488 seconds
# 1/1 [==============================] - 1s 658ms/step
# Executed in 0.6797807216644287 seconds
# 1/1 [==============================] - 1s 682ms/step
# Executed in 0.7033810615539551 seconds
# 1/1 [==============================] - 1s 664ms/step
# Executed in 0.6850202083587646 seconds
# 1/1 [==============================] - 1s 669ms/step
# Executed in 0.6904871463775635 seconds
# 1/1 [==============================] - 1s 680ms/step
# Executed in 0.7016384601593018 seconds
# 1/1 [==============================] - 1s 681ms/step
# Executed in 0.7026774883270264 seconds
# 1/1 [==============================] - 1s 671ms/step
# Executed in 0.6919405460357666 seconds
# 1/1 [==============================] - 1s 674ms/step
# Executed in 0.6955175399780273 seconds
# 1/1 [==============================] - 1s 675ms/step
# Executed in 0.6959969997406006 seconds
# 1/1 [==============================] - 1s 672ms/step
# Executed in 0.6928205490112305 seconds
# 1/1 [==============================] - 1s 686ms/step
# Executed in 0.7068078517913818 seconds
# 1/1 [==============================] - 1s 666ms/step
# Executed in 0.6861567497253418 seconds
# 1/1 [==============================] - 1s 676ms/step
# Executed in 0.6970586776733398 seconds
# 1/1 [==============================] - 1s 677ms/step
# Executed in 0.6997597217559814 seconds
# 1/1 [==============================] - 1s 684ms/step
# Executed in 0.7048876285552979 seconds

# %% [markdown]
# ## TIMINGS

# %%
timings
# Out:
# [{'name': 'merge_time', 'time': 0.04078222986251589},
#  {'name': 'lag_mean_5', 'time': 1.9365549087524413e-05},
#  {'name': 'lag_std_5', 'time': 1.749396324157715e-05},
#  {'name': 'lag_min_5', 'time': 1.1104345321655274e-05},
#  {'name': 'lag_max_5', 'time': 1.0710954666137695e-05},
#  {'name': 'lag_mean_10', 'time': 1.1152029037475586e-05},
#  {'name': 'lag_std_10', 'time': 1.271963119506836e-05},
#  {'name': 'lag_min_10', 'time': 1.0085105895996093e-05},
#  {'name': 'lag_max_10', 'time': 1.0520219802856445e-05},
#  {'name': 'lag_mean_15', 'time': 1.1205673217773438e-05},
#  {'name': 'lag_std_15', 'time': 1.2928247451782227e-05},
#  {'name': 'lag_min_15', 'time': 1.0126829147338868e-05},
#  {'name': 'lag_max_15', 'time': 1.0609626770019531e-05},
#  {'name': 'lag_mean_20', 'time': 1.1092424392700195e-05},
#  {'name': 'lag_std_20', 'time': 1.3637542724609376e-05},
#  {'name': 'lag_min_20', 'time': 1.0317564010620117e-05},
#  {'name': 'lag_max_20', 'time': 1.0073184967041016e-05},
#  {'name': 'lag_diff_20', 'time': 1.0967254638671875e-05},
#  {'name': 'differencing_Gz', 'time': 2.5272369384765625e-05},
#  {'name': 'differencing_Gz_mean_w5', 'time': 1.049041748046875e-05},
#  {'name': 'scaler', 'time': 0.00015957014901297434}]

# %%
timings_net
# Out:
# [{'name': 'autoencoder_all_features_p0', 'time': 0.5608334541320801},
#  {'name': 'autoencoder_all_features_p1', 'time': 0.061768531799316406},
#  {'name': 'autoencoder_all_features_p2', 'time': 0.0612640380859375},
#  {'name': 'autoencoder_w5_features_p0', 'time': 0.06390666961669922},
#  {'name': 'autoencoder_w5_features_p1', 'time': 0.06466412544250488},
#  {'name': 'autoencoder_w5_features_p2', 'time': 0.06286978721618652},
#  {'name': 'autoencoder_w10_features_p0', 'time': 0.06065702438354492},
#  {'name': 'autoencoder_w10_features_p1', 'time': 0.06090259552001953},
#  {'name': 'autoencoder_w10_features_p2', 'time': 0.061189889907836914},
#  {'name': 'autoencoder_w15_features_p0', 'time': 0.061929941177368164},
#  {'name': 'autoencoder_w15_features_p1', 'time': 0.06064414978027344},
#  {'name': 'autoencoder_w15_features_p2', 'time': 0.06004023551940918},
#  {'name': 'autoencoder_w20_features_p0', 'time': 0.06210160255432129},
#  {'name': 'autoencoder_w20_features_p1', 'time': 0.06094241142272949},
#  {'name': 'autoencoder_w20_features_p2', 'time': 0.06134986877441406},
#  {'name': 'autoencoder_no_diff_features_p0', 'time': 0.06622743606567383},
#  {'name': 'autoencoder_no_diff_features_p1', 'time': 0.06241440773010254},
#  {'name': 'autoencoder_no_diff_features_p2', 'time': 0.06125330924987793},
#  {'name': 'autoencoder_diff_features_p0', 'time': 0.061150550842285156},
#  {'name': 'autoencoder_diff_features_p1', 'time': 0.06397581100463867},
#  {'name': 'autoencoder_diff_features_p2', 'time': 0.06228971481323242},
#  {'name': 'mlp_all_features_p0', 'time': 0.04433107376098633},
#  {'name': 'mlp_all_features_p1', 'time': 0.047879695892333984},
#  {'name': 'mlp_all_features_p2', 'time': 0.05115699768066406},
#  {'name': 'mlp_all_features_p3', 'time': 0.05597376823425293},
#  {'name': 'mlp_w5_features_p0', 'time': 0.04470705986022949},
#  {'name': 'mlp_w5_features_p1', 'time': 0.04809451103210449},
#  {'name': 'mlp_w5_features_p2', 'time': 0.0507512092590332},
#  {'name': 'mlp_w5_features_p3', 'time': 0.05428147315979004},
#  {'name': 'mlp_w10_features_p0', 'time': 0.04319000244140625},
#  {'name': 'mlp_w10_features_p1', 'time': 0.0471649169921875},
#  {'name': 'mlp_w10_features_p2', 'time': 0.053197622299194336},
#  {'name': 'mlp_w10_features_p3', 'time': 0.05628228187561035},
#  {'name': 'mlp_w15_features_p0', 'time': 0.045440673828125},
#  {'name': 'mlp_w15_features_p1', 'time': 0.04762434959411621},
#  {'name': 'mlp_w15_features_p2', 'time': 0.0508723258972168},
#  {'name': 'mlp_w15_features_p3', 'time': 0.05413627624511719},
#  {'name': 'mlp_w20_features_p0', 'time': 0.04352927207946777},
#  {'name': 'mlp_w20_features_p1', 'time': 0.04971933364868164},
#  {'name': 'mlp_w20_features_p2', 'time': 0.051610708236694336},
#  {'name': 'mlp_w20_features_p3', 'time': 0.05391883850097656},
#  {'name': 'mlp_no_diff_features_p0', 'time': 0.04316544532775879},
#  {'name': 'mlp_no_diff_features_p1', 'time': 0.046918630599975586},
#  {'name': 'mlp_no_diff_features_p2', 'time': 0.05103278160095215},
#  {'name': 'mlp_no_diff_features_p3', 'time': 0.05677390098571777},
#  {'name': 'mlp_diff_features_p0', 'time': 0.04684090614318848},
#  {'name': 'mlp_diff_features_p1', 'time': 0.047831058502197266},
#  {'name': 'mlp_diff_features_p2', 'time': 0.050729990005493164},
#  {'name': 'mlp_diff_features_p3', 'time': 0.05430412292480469},
#  {'name': 'cnn_all_features_p0', 'time': 0.9775769710540771},
#  {'name': 'cnn_all_features_p1', 'time': 0.060552120208740234},
#  {'name': 'cnn_all_features_p2', 'time': 0.05865478515625},
#  {'name': 'cnn_all_features_p3', 'time': 0.05709481239318848},
#  {'name': 'cnn_all_features_p4', 'time': 0.060131072998046875},
#  {'name': 'cnn_all_features_p5', 'time': 0.06032896041870117},
#  {'name': 'cnn_all_features_p6', 'time': 0.06627655029296875},
#  {'name': 'cnn_all_features_p7', 'time': 0.06215500831604004},
#  {'name': 'cnn_all_features_p8', 'time': 0.05996847152709961},
#  {'name': 'cnn_all_features_p9', 'time': 0.059761762619018555},
#  {'name': 'cnn_all_features_p10', 'time': 0.08391618728637695},
#  {'name': 'cnn_w5_features_p0', 'time': 0.06264019012451172},
#  {'name': 'cnn_w5_features_p1', 'time': 0.060631752014160156},
#  {'name': 'cnn_w5_features_p2', 'time': 0.060144901275634766},
#  {'name': 'cnn_w5_features_p3', 'time': 0.0585331916809082},
#  {'name': 'cnn_w5_features_p4', 'time': 0.0605471134185791},
#  {'name': 'cnn_w5_features_p5', 'time': 0.06835460662841797},
#  {'name': 'cnn_w5_features_p6', 'time': 0.06238055229187012},
#  {'name': 'cnn_w5_features_p7', 'time': 0.06022191047668457},
#  {'name': 'cnn_w5_features_p8', 'time': 0.05905723571777344},
#  {'name': 'cnn_w5_features_p9', 'time': 0.06148076057434082},
#  {'name': 'cnn_w5_features_p10', 'time': 0.06881237030029297},
#  {'name': 'cnn_w10_features_p0', 'time': 0.059396982192993164},
#  {'name': 'cnn_w10_features_p1', 'time': 0.05936861038208008},
#  {'name': 'cnn_w10_features_p2', 'time': 0.056611061096191406},
#  {'name': 'cnn_w10_features_p3', 'time': 0.05682373046875},
#  {'name': 'cnn_w10_features_p4', 'time': 0.06859898567199707},
#  {'name': 'cnn_w10_features_p5', 'time': 0.0623934268951416},
#  {'name': 'cnn_w10_features_p6', 'time': 0.06029176712036133},
#  {'name': 'cnn_w10_features_p7', 'time': 0.058255672454833984},
#  {'name': 'cnn_w10_features_p8', 'time': 0.05836033821105957},
#  {'name': 'cnn_w10_features_p9', 'time': 0.07275009155273438},
#  {'name': 'cnn_w10_features_p10', 'time': 0.0708620548248291},
#  {'name': 'cnn_w15_features_p0', 'time': 0.05925273895263672},
#  {'name': 'cnn_w15_features_p1', 'time': 0.05709099769592285},
#  {'name': 'cnn_w15_features_p2', 'time': 0.05652427673339844},
#  {'name': 'cnn_w15_features_p3', 'time': 0.0661928653717041},
#  {'name': 'cnn_w15_features_p4', 'time': 0.06802988052368164},
#  {'name': 'cnn_w15_features_p5', 'time': 0.06104326248168945},
#  {'name': 'cnn_w15_features_p6', 'time': 0.05890393257141113},
#  {'name': 'cnn_w15_features_p7', 'time': 0.05794715881347656},
#  {'name': 'cnn_w15_features_p8', 'time': 0.27773451805114746},
#  {'name': 'cnn_w15_features_p9', 'time': 0.0658271312713623},
#  {'name': 'cnn_w15_features_p10', 'time': 0.06765365600585938},
#  {'name': 'cnn_w20_features_p0', 'time': 0.058808326721191406},
#  {'name': 'cnn_w20_features_p1', 'time': 0.05829191207885742},
#  {'name': 'cnn_w20_features_p2', 'time': 0.0641474723815918},
#  {'name': 'cnn_w20_features_p3', 'time': 0.06260085105895996},
#  {'name': 'cnn_w20_features_p4', 'time': 0.06350493431091309},
#  {'name': 'cnn_w20_features_p5', 'time': 0.05935549736022949},
#  {'name': 'cnn_w20_features_p6', 'time': 0.05793619155883789},
#  {'name': 'cnn_w20_features_p7', 'time': 0.06487441062927246},
#  {'name': 'cnn_w20_features_p8', 'time': 0.06278228759765625},
#  {'name': 'cnn_w20_features_p9', 'time': 0.06349372863769531},
#  {'name': 'cnn_w20_features_p10', 'time': 0.06565690040588379},
#  {'name': 'cnn_no_diff_features_p0', 'time': 0.061720848083496094},
#  {'name': 'cnn_no_diff_features_p1', 'time': 0.06459331512451172},
#  {'name': 'cnn_no_diff_features_p2', 'time': 0.06163501739501953},
#  {'name': 'cnn_no_diff_features_p3', 'time': 0.059165239334106445},
#  {'name': 'cnn_no_diff_features_p4', 'time': 0.06089901924133301},
#  {'name': 'cnn_no_diff_features_p5', 'time': 0.062209367752075195},
#  {'name': 'cnn_no_diff_features_p6', 'time': 0.0667886734008789},
#  {'name': 'cnn_no_diff_features_p7', 'time': 0.06388115882873535},
#  {'name': 'cnn_no_diff_features_p8', 'time': 0.06091022491455078},
#  {'name': 'cnn_no_diff_features_p9', 'time': 0.06110954284667969},
#  {'name': 'cnn_no_diff_features_p10', 'time': 0.06600284576416016},
#  {'name': 'cnn_diff_features_p0', 'time': 0.06290411949157715},
#  {'name': 'cnn_diff_features_p1', 'time': 0.06170797348022461},
#  {'name': 'cnn_diff_features_p2', 'time': 0.05924367904663086},
#  {'name': 'cnn_diff_features_p3', 'time': 0.05847811698913574},
#  {'name': 'cnn_diff_features_p4', 'time': 0.06175518035888672},
#  {'name': 'cnn_diff_features_p5', 'time': 0.06554365158081055},
#  {'name': 'cnn_diff_features_p6', 'time': 0.06242632865905762},
#  {'name': 'cnn_diff_features_p7', 'time': 0.06070709228515625},
#  {'name': 'cnn_diff_features_p8', 'time': 0.058031558990478516},
#  {'name': 'cnn_diff_features_p9', 'time': 0.060799598693847656},
#  {'name': 'cnn_diff_features_p10', 'time': 0.07509970664978027},
#  {'name': 'lstm_all_features_p0', 'time': 0.4913747310638428},
#  {'name': 'lstm_all_features_p1', 'time': 0.3746340274810791},
#  {'name': 'lstm_all_features_p2', 'time': 0.36623215675354004},
#  {'name': 'lstm_all_features_p3', 'time': 0.3684544563293457},
#  {'name': 'lstm_w5_features_p0', 'time': 0.37064647674560547},
#  {'name': 'lstm_w5_features_p1', 'time': 0.3672506809234619},
#  {'name': 'lstm_w5_features_p2', 'time': 0.8275060653686523},
#  {'name': 'lstm_w5_features_p3', 'time': 0.3700113296508789},
#  {'name': 'lstm_w10_features_p0', 'time': 0.3732740879058838},
#  {'name': 'lstm_w10_features_p1', 'time': 0.3778057098388672},
#  {'name': 'lstm_w10_features_p2', 'time': 0.3830568790435791},
#  {'name': 'lstm_w10_features_p3', 'time': 0.36663007736206055},
#  {'name': 'lstm_w15_features_p0', 'time': 0.37134218215942383},
#  {'name': 'lstm_w15_features_p1', 'time': 0.3667609691619873},
#  {'name': 'lstm_w15_features_p2', 'time': 0.36559629440307617},
#  {'name': 'lstm_w15_features_p3', 'time': 0.37505006790161133},
#  {'name': 'lstm_w20_features_p0', 'time': 0.381131649017334},
#  {'name': 'lstm_w20_features_p1', 'time': 0.3640015125274658},
#  {'name': 'lstm_w20_features_p2', 'time': 0.3662528991699219},
#  {'name': 'lstm_w20_features_p3', 'time': 0.36593079566955566},
#  {'name': 'lstm_no_diff_features_p0', 'time': 0.3661463260650635},
#  {'name': 'lstm_no_diff_features_p1', 'time': 0.3636500835418701},
#  {'name': 'lstm_no_diff_features_p2', 'time': 0.3903491497039795},
#  {'name': 'lstm_no_diff_features_p3', 'time': 0.3721601963043213},
#  {'name': 'lstm_diff_features_p0', 'time': 0.36423158645629883},
#  {'name': 'lstm_diff_features_p1', 'time': 0.36821603775024414},
#  {'name': 'lstm_diff_features_p2', 'time': 0.3886411190032959},
#  {'name': 'lstm_diff_features_p3', 'time': 0.3808412551879883},
#  {'name': 'gru_all_features_p0', 'time': 0.3331615924835205},
#  {'name': 'gru_all_features_p1', 'time': 0.32822132110595703},
#  {'name': 'gru_all_features_p2', 'time': 0.33524417877197266},
#  {'name': 'gru_all_features_p3', 'time': 0.3288607597351074},
#  {'name': 'gru_w5_features_p0', 'time': 0.3281073570251465},
#  {'name': 'gru_w5_features_p1', 'time': 0.3280057907104492},
#  {'name': 'gru_w5_features_p2', 'time': 0.33014535903930664},
#  {'name': 'gru_w5_features_p3', 'time': 0.3263876438140869},
#  {'name': 'gru_w10_features_p0', 'time': 0.356060266494751},
#  {'name': 'gru_w10_features_p1', 'time': 0.34317779541015625},
#  {'name': 'gru_w10_features_p2', 'time': 0.3317267894744873},
#  {'name': 'gru_w10_features_p3', 'time': 0.33489346504211426},
#  {'name': 'gru_w15_features_p0', 'time': 0.34979963302612305},
#  {'name': 'gru_w15_features_p1', 'time': 0.33174681663513184},
#  {'name': 'gru_w15_features_p2', 'time': 0.32549452781677246},
#  {'name': 'gru_w15_features_p3', 'time': 0.3223226070404053},
#  {'name': 'gru_w20_features_p0', 'time': 0.3380589485168457},
#  {'name': 'gru_w20_features_p1', 'time': 0.32533717155456543},
#  {'name': 'gru_w20_features_p2', 'time': 0.32474255561828613},
#  {'name': 'gru_w20_features_p3', 'time': 0.32704806327819824},
#  {'name': 'gru_no_diff_features_p0', 'time': 0.33681535720825195},
#  {'name': 'gru_no_diff_features_p1', 'time': 0.3276941776275635},
#  {'name': 'gru_no_diff_features_p2', 'time': 0.3437199592590332},
#  {'name': 'gru_no_diff_features_p3', 'time': 0.3342406749725342},
#  {'name': 'gru_diff_features_p0', 'time': 0.330089807510376},
#  {'name': 'gru_diff_features_p1', 'time': 0.3342757225036621},
#  {'name': 'gru_diff_features_p2', 'time': 0.3440878391265869},
#  {'name': 'gru_diff_features_p3', 'time': 0.33615922927856445},
#  {'name': 'bilstm_all_features_p0', 'time': 0.6883318424224854},
#  {'name': 'bilstm_all_features_p1', 'time': 0.682114839553833},
#  {'name': 'bilstm_all_features_p2', 'time': 0.7049915790557861},
#  {'name': 'bilstm_all_features_p3', 'time': 0.6916570663452148},
#  {'name': 'bilstm_w5_features_p0', 'time': 0.6917862892150879},
#  {'name': 'bilstm_w5_features_p1', 'time': 0.6970171928405762},
#  {'name': 'bilstm_w5_features_p2', 'time': 0.6792292594909668},
#  {'name': 'bilstm_w5_features_p3', 'time': 0.6915590763092041},
#  {'name': 'bilstm_w10_features_p0', 'time': 0.7063710689544678},
#  {'name': 'bilstm_w10_features_p1', 'time': 0.6890983581542969},
#  {'name': 'bilstm_w10_features_p2', 'time': 0.6849789619445801},
#  {'name': 'bilstm_w10_features_p3', 'time': 0.6750645637512207},
#  {'name': 'bilstm_w15_features_p0', 'time': 0.6824078559875488},
#  {'name': 'bilstm_w15_features_p1', 'time': 0.6797807216644287},
#  {'name': 'bilstm_w15_features_p2', 'time': 0.7033810615539551},
#  {'name': 'bilstm_w15_features_p3', 'time': 0.6850202083587646},
#  {'name': 'bilstm_w20_features_p0', 'time': 0.6904871463775635},
#  {'name': 'bilstm_w20_features_p1', 'time': 0.7016384601593018},
#  {'name': 'bilstm_w20_features_p2', 'time': 0.7026774883270264},
#  {'name': 'bilstm_w20_features_p3', 'time': 0.6919405460357666},
#  {'name': 'bilstm_no_diff_features_p0', 'time': 0.6955175399780273},
#  {'name': 'bilstm_no_diff_features_p1', 'time': 0.6959969997406006},
#  {'name': 'bilstm_no_diff_features_p2', 'time': 0.6928205490112305},
#  {'name': 'bilstm_no_diff_features_p3', 'time': 0.7068078517913818},
#  {'name': 'bilstm_diff_features_p0', 'time': 0.6861567497253418},
#  {'name': 'bilstm_diff_features_p1', 'time': 0.6970586776733398},
#  {'name': 'bilstm_diff_features_p2', 'time': 0.6997597217559814},
#  {'name': 'bilstm_diff_features_p3', 'time': 0.7048876285552979}]
