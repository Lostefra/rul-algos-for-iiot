# %% [markdown]
# # Testing analysis

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {4, 7, 10, 13} (aka 0.3, 0.6, 0.9, 1.2 seconds)
margin = 7

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_res = pd.read_csv("summaries/testing_summary_improved_" + str(margin) + ".csv", index_col=[0])

df_res_sorted = df_res.sort_values(by=['cost'])
df_res_sorted = df_res_sorted.reset_index(drop=True)
df_res_sorted['#'] = df_res_sorted.index
print("There are", len(df_res_sorted), "models for margin =", margin)
df_res_sorted.head(50)
# Out:
# There are 2100 models for margin = 7
#       model  seed           columns  \
# 0   conv_nn  1800      w15_features
# 1   conv_nn  1600      w20_features
# 2   conv_nn  2600      w15_features
# 3   conv_nn  2500     diff_features
# 4   conv_nn  1800      w20_features
# 5   conv_nn  1500      w20_features
# 6   conv_nn  2400      w20_features
# 7   conv_nn  1100      w20_features
# 8   conv_nn  1300      w20_features
# 9   conv_nn  1000      w20_features
# 10  conv_nn  1500      all_features
# 11  conv_nn  2800      w20_features
# 12  conv_nn  2500      w20_features
# 13  conv_nn  1800      w20_features
# 14  conv_nn  1700      w20_features
# 15  conv_nn  1300      w15_features
# 16  conv_nn  1100      all_features
# 17  conv_nn  2400      all_features
# 18  conv_nn  1100      w10_features
# 19  conv_nn  2000      w20_features
# 20  conv_nn  1400      w20_features
# 21  conv_nn  1200      all_features
# 22  conv_nn  1600      w15_features
# 23  conv_nn  1200      w15_features
# 24  conv_nn  2800      w15_features
# 25  conv_nn  1300      w20_features
# 26  conv_nn  2700      w15_features
# 27  conv_nn  1600      w20_features
# 28  conv_nn  2800      w20_features
# 29  conv_nn  1700      w15_features
# 30  conv_nn  1900  no_diff_features
# 31  conv_nn  2500      w20_features
# 32  conv_nn  1200      w15_features
# 33  conv_nn  1600      w20_features
# 34  conv_nn  1300       w5_features
# 35  conv_nn  1700      all_features
# 36  conv_nn  2900      w20_features
# 37  conv_nn  2300      w20_features
# 38  conv_nn  1100      w20_features
# 39  conv_nn  1200      w20_features
# 40  conv_nn  2000      w15_features
# 41  conv_nn  2900      w20_features
# 42  conv_nn  1600     diff_features
# 43  conv_nn  2200      all_features
# 44  conv_nn  2000      w20_features
# 45  conv_nn  1600      all_features
# 46  conv_nn  1600      all_features
# 47  conv_nn  2500      w20_features
# 48  conv_nn  1700      all_features
# 49  conv_nn  2400      all_features
#
#                                                                     params  \
# 0         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 1            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 2         {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 3             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 4         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 5             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 6             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 7        {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 10}
# 8             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 9         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 10           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 11        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 12       {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 10}
# 13            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 14            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 15        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 16           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 17            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 18       {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 10}
# 19        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 20            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 21            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 22        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 23        {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 24        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 25       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 26            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 27       {'filters': 1, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 28       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 29            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 30        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 31        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 32        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 33           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 34            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 35            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 36        {'filters': 1, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 37        {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 38            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 39            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 40        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 41            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 42           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 43        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 44  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 45       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 46           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 47        {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 48            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 49           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
#
#     params_idx   cost  anticipation  detected_faults  missed_faults  \
# 0            4  75.00          0.29                7              0
# 1            7  80.20          0.37                7              0
# 2           11  82.00          0.36                7              0
# 3            0  84.80          0.42                6              1
# 4            4  88.20          0.31                7              0
# 5            3  88.40          0.33                6              1
# 6            1  88.40          0.31                7              0
# 7           13  89.80          0.34                7              0
# 8            3  91.60          0.32                6              1
# 9            4  93.60          0.29                7              0
# 10           7  94.40          0.36                7              0
# 11           4  96.00          0.27                6              1
# 12          13  98.60          0.41                7              0
# 13           3  98.80          0.30                7              0
# 14           3 100.20          0.30                7              0
# 15           4 100.60          0.25                6              1
# 16           7 101.60          0.33                7              0
# 17           2 102.20          0.26                7              0
# 18          13 102.20          0.33                6              1
# 19           4 102.80          0.38                6              1
# 20           3 103.00          0.25                6              1
# 21           3 103.00          0.46                7              0
# 22           4 104.00          0.25                6              1
# 23          11 104.40          0.30                6              1
# 24           4 104.40          0.39                7              0
# 25           9 105.20          0.19                7              0
# 26           3 105.80          0.28                6              1
# 27          14 106.00          0.23                7              0
# 28           9 106.40          0.32                6              1
# 29           1 106.60          0.44                7              0
# 30           4 108.60          0.35                6              1
# 31           4 108.60          0.34                7              0
# 32           4 108.60          0.40                7              0
# 33           6 109.20          0.33                6              1
# 34           0 109.80          0.17                6              1
# 35           1 110.20          0.29                7              0
# 36          12 110.40          0.17                6              1
# 37          11 110.80          0.17                6              1
# 38           2 111.00          0.30                7              0
# 39           1 111.20          0.23                6              1
# 40           4 111.20          0.33                6              1
# 41           3 111.80          0.33                7              0
# 42           6 113.00          0.30                5              2
# 43           4 113.40          0.20                6              1
# 44          10 114.20          0.34                5              2
# 45           9 114.20          0.33                6              1
# 46           7 114.20          0.39                7              0
# 47          11 114.40          0.30                6              1
# 48           2 114.40          0.31                7              0
# 49           7 115.00          0.18                6              1
#
#     false_alarms   #
# 0             35   0
# 1            171   1
# 2            190   2
# 3            149   3
# 4            141   4
# 5             47   5
# 6            142   6
# 7            194   7
# 8             33   8
# 9            133   9
# 10           242  10
# 11            40  11
# 12           298  12
# 13           164  13
# 14           196  14
# 15            58  15
# 16           233  16
# 17           161  17
# 18           136  18
# 19           204  19
# 20            45  20
# 21           385  21
# 22            45  22
# 23           112  23
# 24           297  24
# 25            56  25
# 26           129  26
# 27           120  27
# 28           132  28
# 29           378  29
# 30           178  30
# 31           293  31
# 32           343  32
# 33           151  33
# 34             4  34
# 35           216  35
# 36             7  36
# 37             9  37
# 38           250  38
# 39            81  39
# 40           191  40
# 41           284  41
# 42            90  42
# 43            67  43
# 44           101  44
# 45           236  45
# 46           331  46
# 47           157  47
# 48           292  48
# 49            55  49

# %%
### Logistic Regression

df_res_sorted[(df_res_sorted["model"] == "mlp") & (df_res_sorted["params_idx"] == 0)].head(1)
# Out:
# Empty DataFrame
# Columns: [model, seed, columns, params, params_idx, cost, anticipation, detected_faults, missed_faults, false_alarms, #]
# Index: []

# %% [markdown]
# ---
#
# ## Check performance of a given model for all seeds

# %%
model = "conv_nn"
columns = "all_features"
params_idx = 11

df_res_sorted[(df_res_sorted["model"] == model) & (df_res_sorted["columns"] == columns) & (df_res_sorted["params_idx"] == params_idx)]
# Out:
#         model  seed       columns  \
# 267   conv_nn  1600  all_features
# 523   conv_nn  1300  all_features
# 627   conv_nn  2200  all_features
# 655   conv_nn  1200  all_features
# 890   conv_nn  1500  all_features
# 898   conv_nn  1800  all_features
# 1004  conv_nn  2900  all_features
# 1239  conv_nn  2300  all_features
# 1460  conv_nn  2000  all_features
# 1807  conv_nn  1900  all_features
# 1821  conv_nn  1000  all_features
# 1839  conv_nn  1100  all_features
# 1844  conv_nn  2800  all_features
# 1846  conv_nn  2600  all_features
# 1865  conv_nn  1400  all_features
# 1867  conv_nn  1700  all_features
# 1946  conv_nn  2500  all_features
# 1985  conv_nn  2700  all_features
# 2004  conv_nn  2400  all_features
# 2028  conv_nn  2100  all_features
#
#                                                                 params  \
# 267   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 523   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 627   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 655   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 890   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 898   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1004  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1239  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1460  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1807  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1821  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1839  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1844  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1846  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1865  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1867  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1946  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 1985  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 2004  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 2028  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
#
#       params_idx   cost  anticipation  detected_faults  missed_faults  \
# 267           11 136.40          0.29                7              0
# 523           11 153.00          0.16                7              0
# 627           11 158.80          0.23                4              3
# 655           11 160.20          0.11                7              0
# 890           11 173.80          0.26                7              0
# 898           11 174.00          0.20                4              3
# 1004          11 180.20          0.20                6              1
# 1239          11 194.60          0.20                6              1
# 1460          11 204.20          0.23                7              0
# 1807          11 702.40          0.60                6              1
# 1821          11 711.60          0.56                7              0
# 1839          11 720.20          0.60                6              1
# 1844          11 723.00          0.60                6              1
# 1846          11 723.40          0.59                7              0
# 1865          11 733.00          0.60                7              0
# 1867          11 734.60          0.60                6              1
# 1946          11 777.60          0.59                7              0
# 1985          11 798.60          0.60                7              0
# 2004          11 817.00          0.60                7              0
# 2028          11 844.80          0.60                7              0
#
#       false_alarms     #
# 267            397   267
# 523            275   523
# 627            144   627
# 655            231   655
# 890            549   890
# 898            195   898
# 1004           386  1004
# 1239           458  1239
# 1460           636  1460
# 1807          3372  1807
# 1821          3528  1821
# 1839          3461  1839
# 1844          3475  1844
# 1846          3612  1846
# 1865          3665  1865
# 1867          3533  1867
# 1946          3883  1946
# 1985          3993  1985
# 2004          4085  2004
# 2028          4224  2028

# %% [markdown]
# ---
#
# ## Best performance of models

# %%
df_res_sorted.sort_values(by=["model", "cost"]).drop_duplicates(subset=["model"]).sort_values(by="cost")[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
#      model  cost  anticipation  detected_faults  missed_faults  false_alarms
# 0  conv_nn 75.00          0.29                7              0            35

# %% [markdown]
# ## Average performance of models

# %%
df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 
w20_featuresno_diff_featuresno_diff_featuresw10_featuresw5_featuresw15_featuresw20_featuresall_featuresw20_featuresall_featuresw15_featuresno_diff_featuresw20_featuresw10_featuresw20_featuresall_featuresw20_featuresno_diff_featuresno_diff_featuresno_diff_featuresw20_featuresw5_featuresdiff_featuresw5_featuresw5_featuresw15_featuresall_featuresw20_featuresw10_featuresw15_featuresw15_featuresdiff_featuresall_featuresw15_featuresw20_featuresno_diff_featuresall_featuresw5_featuresdiff_featuresw20_featuresw15_featuresall_featuresall_featuresno_diff_featuresall_featuresw20_featuresdiff_featuresw10_featuresw10_featuresw5_featuresw15_featuresw5_featuresall_featuresno_diff_featuresall_featuresdiff_featuresw20_featuresno_diff_featuresw15_featuresdiff_featuresw10_featuresw20_featuresall_featuresno_diff_featuresdiff_featuresno_diff_featuresdiff_featuresno_diff_featuresall_featuresw20_featuresw20_featuresno_diff_featuresall_featuresw20_featuresw20_featuresall_featuresw15_featuresw20_featuresw5_featuresw20_featuresno_diff_featuresw20_featuresw10_featuresw10_featuresdiff_featuresdiff_featuresdiff_featuresw20_featuresno_diff_featuresall_featuresw5_featuresall_featuresw20_featuresw15_featuresw5_featuresdiff_featuresdiff_featuresno_diff_featuresdiff_featuresdiff_featuresw15_featuresw20_featuresdiff_featuresall_featuresdiff_featuresdiff_featuresno_diff_featuresw15_featuresdiff_featuresdiff_featuresw10_featuresall_featuresdiff_featuresw20_featuresw15_featuresall_featuresw5_featuresw5_featuresno_diff_featuresw5_featuresw20_featuresw20_featuresno_diff_featuresw10_featuresall_featuresall_featuresall_featuresall_featuresw20_featuresw5_featuresw15_featuresall_featuresno_diff_featuresw10_featuresw5_featuresw5_featuresw15_featuresall_featuresw15_featuresw15_featuresw5_featuresw5_featuresno_diff_featuresall_featuresall_featuresdiff_featuresdiff_featuresw15_featuresall_featuresw5_featuresw20_featuresall_featuresw20_featuresdiff_featuresall_featuresdiff_featuresw5_featuresall_featuresall_featuresw5_featuresw20_featuresno_diff_featuresall_featuresw5_featuresno_diff_featuresno_diff_featuresw5_featuresw5_featuresall_featuresw10_featuresno_diff_featuresall_featuresw15_featuresall_featuresdiff_featuresall_featuresno_diff_featuresw10_featuresno_diff_featuresall_featuresdiff_featuresw15_featuresw10_featuresw15_featuresall_featuresall_featuresall_featuresdiff_featuresno_diff_featuresw10_featuresno_diff_featuresno_diff_featuresw10_featuresdiff_featuresdiff_featuresno_diff_featuresall_featuresno_diff_featuresdiff_featuresno_diff_featuresw20_featuresdiff_featuresno_diff_featuresw5_featuresw15_featuresno_diff_featuresall_featur ...

# %% [markdown]
# ---
#
# ## Best performance of models given hyperparameters and features

# %%
df_res_sorted.sort_values(by=["model", "columns", "params", "cost"]).drop_duplicates(subset=["model", "columns", "params"]).sort_values(by="cost")[["model", "columns", "params", "params_idx", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]].head(50)

# %% [markdown]
# ## Average performance of models with same hyperparameters and features

# %%
df_res_sorted.groupby(by=["model", "columns", "params"]).mean().sort_values(by=["cost"]).reset_index()[["model", "columns", "params", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]].head(50)
