# %% [markdown]
# # Testing analysis

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {5, 10, 15, 20} (aka 0.5, 1, 1.5, 2 seconds)
margin = 10

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_res = pd.read_csv("testing_summary_" + str(margin) + ".csv", index_col=[0])
df_res_sorted = df_res.sort_values(by=['cost'])
df_res_sorted = df_res_sorted.reset_index(drop=True)
df_res_sorted['#'] = df_res_sorted.index
print("There are", len(df_res_sorted), "models for margin =", margin)
df_res_sorted.head(50)
# Out:
# There are 738 models for margin = 10
#       model  seed           columns  \
# 0   conv_nn   100      w10_features
# 1   conv_nn   100       w5_features
# 2   conv_nn   100      w10_features
# 3   conv_nn   100      w15_features
# 4   conv_nn   300      w10_features
# 5   conv_nn   300      w10_features
# 6   conv_nn   100      w15_features
# 7   conv_nn   100       w5_features
# 8   conv_nn   100      w15_features
# 9   conv_nn   300      w15_features
# 10  conv_nn   100      w20_features
# 11  conv_nn   300      w15_features
# 12  conv_nn   100      w20_features
# 13  conv_nn   300      w20_features
# 14  conv_nn   300     diff_features
# 15  conv_nn   100     diff_features
# 16  conv_nn   300      w20_features
# 17  conv_nn   300       w5_features
# 18  conv_nn   300      all_features
# 19  conv_nn   100       w5_features
# 20  conv_nn   300       w5_features
# 21  conv_nn   100     diff_features
# 22  conv_nn   300     diff_features
# 23  conv_nn   300       w5_features
# 24  conv_nn   300     diff_features
# 25  conv_nn   300      w20_features
# 26  conv_nn   100      w10_features
# 27  conv_nn   200       w5_features
# 28  conv_nn   300     diff_features
# 29  conv_nn   200       w5_features
# 30  conv_nn   200      w20_features
# 31  conv_nn   300      all_features
# 32  conv_nn   100      w15_features
# 33  conv_nn   300  no_diff_features
# 34  conv_nn   300  no_diff_features
# 35  conv_nn   200       w5_features
# 36  conv_nn   300      w15_features
# 37  conv_nn   100       w5_features
# 38  conv_nn   300      all_features
# 39  conv_nn   200       w5_features
# 40  conv_nn   100  no_diff_features
# 41  conv_nn   200      w15_features
# 42  conv_nn   200      all_features
# 43  conv_nn   100  no_diff_features
# 44  conv_nn   300      w20_features
# 45  conv_nn   100       w5_features
# 46  conv_nn   200      w10_features
# 47  conv_nn   100       w5_features
# 48  conv_nn   100      w20_features
# 49  conv_nn   200      w10_features
#
#                                                            params  params_idx  \
# 0    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 1   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 2   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 3    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 4    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 5   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 6   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 7    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 8   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 9   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 10   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 11   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 12  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 13  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 14  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 15   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 16   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 17   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 18   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 19  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 20  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 21   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 22   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 23  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 24   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 25  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 26  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 27   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 28   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 29   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 30   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 31  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 32   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 33  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 34   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 35   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 36  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 37   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 38  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 39  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 40   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 41   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 42  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 43  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 44   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 45   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 46  {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           6
# 47  {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           8
# 48   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 49   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
#
#     cost  anticipation  detected_faults  missed_faults  false_alarms   #
# 0   0.00          0.90               13              0             0   0
# 1   0.00          0.90               13              0             0   1
# 2   0.00          0.90               13              0             0   2
# 3   0.00          0.90               13              0             0   3
# 4   0.00          0.90               13              0             0   4
# 5   0.00          0.90               13              0             0   5
# 6   0.00          0.90               13              0             0   6
# 7   0.00          0.90               13              0             0   7
# 8   0.00          0.90               13              0             0   8
# 9   0.00          0.90               13              0             0   9
# 10  0.00          0.90               13              0             0  10
# 11  0.00          0.90               13              0             0  11
# 12  0.00          0.90               13              0             0  12
# 13  0.00          0.90               13              0             0  13
# 14  0.00          0.90               13              0             0  14
# 15  0.00          0.90               13              0             0  15
# 16  0.00          0.90               13              0             0  16
# 17  0.20          0.90               13              0             1  17
# 18  0.40          0.90               13              0             2  18
# 19  0.40          0.90               13              0             2  19
# 20  1.00          0.89               13              0             0  20
# 21  1.00          0.89               13              0             0  21
# 22  1.20          0.89               13              0             1  22
# 23  1.60          0.90               13              0             8  23
# 24  1.60          0.90               13              0             8  24
# 25  2.00          0.88               13              0             0  25
# 26  3.00          0.88               13              0             0  26
# 27  3.20          0.88               13              0             1  27
# 28  3.20          0.90               13              0            16  28
# 29  4.00          0.88               13              0             0  29
# 30  4.60          0.90               13              0            23  30
# 31  5.40          0.90               13              0            27  31
# 32  6.20          0.89               13              0            26  32
# 33  7.00          0.85               13              0             0  33
# 34  8.00          0.84               13              0             0  34
# 35  9.00          0.86               13              0             0  35
# 36  9.80          0.90               13              0            49  36
# 37 10.00          0.85               13              0             0  37
# 38 11.40          0.88               13              0            42  38
# 39 14.00          0.89               13              0            65  39
# 40 14.00          0.81               13              0             0  40
# 41 15.60          0.90               13              0            78  41
# 42 15.80          0.84               13              0            34  42
# 43 16.00          0.79               13              0             0  43
# 44 18.00          0.79               13              0             0  44
# 45 19.20          0.79               13              0             1  45
# 46 19.80          0.83               13              0            34  46
# 47 21.00          0.78               13              0             0  47
# 48 21.00          0.77               13              0             0  48
# 49 22.00          0.78               13              0             0  49

# %% [markdown]
# ## Check performance of a given model for all seeds

# %%
model = "conv_nn"
columns = "w5_features"
params_idx = 0

df_res_sorted[(df_res_sorted["model"] == model) & (df_res_sorted["columns"] == columns) & (df_res_sorted["params_idx"] == params_idx)]
# Out:
#       model  seed      columns  \
# 7   conv_nn   100  w5_features
# 17  conv_nn   300  w5_features
# 27  conv_nn   200  w5_features
#
#                                                           params  params_idx  \
# 7   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 17  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 27  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
#
#     cost  anticipation  detected_faults  missed_faults  false_alarms   #
# 7   0.00          0.90               13              0             0   7
# 17  0.20          0.90               13              0             1  17
# 27  3.20          0.88               13              0             1  27

# %% [markdown]
# ## Average performance of models with same hyperparameters and features

# %%
df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["#"]).reset_index()
# Out:
# <ipython-input-9-74c72ade384c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["#"]).reset_index()
#          model   seed  params_idx    cost  anticipation  detected_faults  \
# 0      conv_nn 200.00        5.00  408.59          0.45             8.42
# 1          mlp 200.00        1.50  594.06          0.23             5.36
# 2       bilstm 200.00        1.50  682.42          0.20             5.90
# 3         lstm 200.00        1.50  917.86          0.37             7.94
# 4          gru 200.00        1.50 1294.25          0.59            11.40
# 5   raw_signal 200.00        0.00 2069.13          0.66            10.08
# 6  autoencoder 200.00        1.00 2753.47          0.90            13.00
#
#    missed_faults  false_alarms      #
# 0           4.58        425.64 204.02
# 1           7.64        458.04 300.08
# 2           7.10        818.05 324.08
# 3           5.06       2626.81 362.55
# 4           1.60       5488.21 439.98
# 5           2.92       9471.61 569.19
# 6           0.00      13767.35 690.63

# %%
df_res_sorted.groupby(by=["model", "columns", "params"]).mean().sort_values(by=["#"]).reset_index()
# Out:
#            model                   columns  \
# 0        conv_nn               w5_features
# 1        conv_nn               w5_features
# 2        conv_nn              w15_features
# 3        conv_nn              w10_features
# 4        conv_nn               w5_features
# 5        conv_nn              w10_features
# 6        conv_nn               w5_features
# 7        conv_nn              all_features
# 8        conv_nn               w5_features
# 9        conv_nn              w10_features
# 10       conv_nn             diff_features
# 11       conv_nn               w5_features
# 12       conv_nn              all_features
# 13       conv_nn               w5_features
# 14       conv_nn              w15_features
# 15       conv_nn              w15_features
# 16       conv_nn              w10_features
# 17           mlp               w5_features
# 18       conv_nn              w10_features
# 19       conv_nn             diff_features
# 20       conv_nn              all_features
# 21           mlp               w5_features
# 22           mlp              all_features
# 23       conv_nn               w5_features
# 24       conv_nn          no_diff_features
# 25       conv_nn          no_diff_features
# 26           mlp             diff_features
# 27    raw_signal                   Ax_diff
# 28           mlp               w5_features
# 29       conv_nn              w10_features
# 30    raw_signal      differencing_Ax_diff
# 31       conv_nn              w20_features
# 32       conv_nn              all_features
# 33       conv_nn              all_features
# 34       conv_nn              w10_features
# 35           mlp             diff_features
# 36       conv_nn               w5_features
# 37       conv_nn              w20_features
# 38           gru              all_features
# 39       conv_nn              w20_features
# 40       conv_nn              w20_features
# 41       conv_nn             diff_features
# 42        bilstm               w5_features
# 43           mlp             diff_features
# 44        bilstm              w10_features
# 45       conv_nn              all_features
# 46           mlp              w10_features
# 47       conv_nn              w10_features
# 48           mlp             diff_features
# 49       conv_nn              w15_features
# 50       conv_nn              w15_features
# 51          lstm              w10_features
# 52       conv_nn          no_diff_features
# 53       conv_nn              w15_features
# 54       conv_nn             diff_features
# 55          lstm              w15_features
# 56       conv_nn              w15_features
# 57       conv_nn          no_diff_features
# 58          lstm               w5_features
# 59           gru              w20_features
# 60       conv_nn              w20_features
# 61       conv_nn             diff_features
# 62        bilstm              all_features
# 63           mlp              w15_features
# 64        bilstm               w5_features
# 65       conv_nn              w20_features
# 66       conv_nn             diff_features
# 67       conv_nn              w20_features
# 68        bilstm              w20_features
# 69        bilstm              w10_features
# 70          lstm              w15_features
# 71       conv_nn              w10_features
# 72           mlp              w10_features
# 73        bilstm               w5_features
# 74       conv_nn             diff_features
# 75          lstm              all_features
# 76       conv_nn              w15_features
# 77       conv_nn              w20_features
# 78           gru              w15_features
# 79        bilstm              all_features
# 80       conv_nn              all_features
# 81          lstm              w10_features
# 82        bilstm               w5_features
# 83          lstm               w5_features
# 84       conv_nn              w15_features
# 85           mlp              all_features
# 86          lstm               w5_features
# 87           gru              all_features
# 88       conv_nn             diff_features
# 89        bilstm              all_features
# 90          lstm               w5_features
# 91           gru          no_diff_features
# 92       conv_nn          no_diff_features
# 93        bilstm              w15_features
# 94       conv_nn          no_diff_features
# 95       conv_nn              w20_features
# 96          lstm              w15_features
# 97       conv_nn          no_diff_features
# 98       conv_nn               w5_features
# 99       conv_nn               w5_features
# 100       bilstm             diff_features
# 101         lstm              w10_features
# 102      conv_nn              w15_features
# 103       bilstm          no_diff_features
# 104       bilstm              all_features
# 105          mlp              w20_features
# 106      conv_nn              w20_features
# 107          mlp              w10_features
# 108       bilstm              w20_features
# 109         lstm              all_features
# 110         lstm              all_features
# 111      conv_nn          no_diff_features
# 112      conv_nn              all_features
# 113          gru          no_diff_features
# 114          gru              w20_features
# 115       bilstm              w15_features
# 116         lstm             diff_features
# 117       bilstm              w10_features
# 118          mlp              w15_features
# 119          gru          no_diff_features
# 120      conv_nn          no_diff_features
# 121          gru          no_diff_features
# 122         lstm          no_diff_features
# 123          mlp              w20_features
# 124         lstm          no_diff_features
# 125         lstm          no_diff_features
# 126      conv_nn              w10_features
# 127         lstm              w20_features
# 128       bilstm              w15_features
# 129      conv_nn              w20_features
# 130      conv_nn              all_features
# 131      conv_nn          no_diff_features
# 132         lstm          no_diff_features
# 133      conv_nn             diff_features
# 134          gru              w10_features
# 135         lstm              all_features
# 136          mlp              all_features
# 137      conv_nn          no_diff_features
# 138      conv_nn              w10_features
# 139          mlp              w20_features
# 140       bilstm              w10_features
# 141       bilstm          no_diff_features
# 142      conv_nn             diff_features
# 143          mlp              w10_features
# 144          mlp              w15_features
# 145          gru              w10_features
# 146   raw_signal                Ax_std_w15
# 147      conv_nn              w15_features
# 148          gru              w10_features
# 149       bilstm             diff_features
# 150       bilstm          no_diff_features
# 151   raw_signal                Ax_std_w10
# 152       bilstm             diff_features
# 153          gru              all_features
# 154       bilstm              w20_features
# 155       bilstm          no_diff_features
# 156       bilstm              w20_features
# 157          mlp              w15_features
# 158      conv_nn              all_features
# 159       bilstm              w15_features
# 160      conv_nn              all_features
# 161   raw_signal                Ax_std_w20
# 162      conv_nn             diff_features
# 163          mlp          no_diff_features
# 164         lstm              w10_features
# 165          mlp              w20_features
# 166          mlp          no_diff_features
# 167       bilstm             diff_features
# 168          mlp          no_diff_features
# 169          mlp              all_features
# 170          mlp          no_diff_features
# 171          gru              w15_features
# 172          gru              w20_features
# 173         lstm              w20_features
# 174         lstm              w20_features
# 175          gru             diff_features
# 176   raw_signal                 Ax_std_w5
# 177   raw_signal   differencing_Ax_std_w20
# 178   raw_signal   differencing_Ax_std_w15
# 179   raw_signal   differencing_Ax_std_w10
# 180          gru              w15_features
# 181   raw_signal    differencing_Ax_std_w5
# 182         lstm              w20_features
# 183          gru              w15_features
# 184         lstm              w15_features
# 185          gru               w5_features
# 186          mlp               w5_features
# 187          gru               w5_features
# 188          gru              w10_features
# 189          gru              w20_features
# 190   raw_signal                 Ax_min_w5
# 191         lstm             diff_features
# 192          gru               w5_features
# 193   raw_signal                Ax_max_w10
# 194          gru              all_features
# 195   raw_signal                Ax_min_w10
# 196   raw_signal                Ax_min_w15
# 197          gru               w5_features
# 198   raw_signal                        Ax
# 199         lstm             diff_features
# 200   raw_signal                Ax_min_w20
# 201          gru             diff_features
# 202         lstm             diff_features
# 203   raw_signal                Ax_mean_w5
# 204   raw_signal           differencing_Ax
# 205          gru             diff_features
# 206   raw_signal   differencing_Ax_min_w10
# 207  autoencoder               w5_features
# 208   raw_signal                Ax_max_w20
# 209   raw_signal                Ax_max_w15
# 210  autoencoder               w5_features
# 211   raw_signal   differencing_Ax_min_w15
# 212   raw_signal   differencing_Ax_min_w20
# 213   raw_signal    differencing_Ax_min_w5
# 214   raw_signal   differencing_Ax_max_w15
# 215   raw_signal    differencing_Ax_max_w5
# 216   raw_signal                 Ax_max_w5
# 217   raw_signal   differencing_Ax_max_w10
# 218  autoencoder              w10_features
# 219          gru             diff_features
# 220   raw_signal   differencing_Ax_max_w20
# 221  autoencoder              w10_features
# 222   raw_signal   differencing_Ax_mean_w5
# 223  autoencoder               w5_features
# 224  autoencoder          no_diff_features
# 225  autoencoder             diff_features
# 226   raw_signal               Ax_mean_w15
# 227   raw_signal               Ax_mean_w10
# 228  autoencoder             diff_features
# 229  autoencoder              w15_features
# 230   raw_signal               Ax_mean_w20
# 231   raw_signal  differencing_Ax_mean_w20
# 232   raw_signal  differencing_Ax_mean_w10
# 233  autoencoder          no_diff_features
# 234  autoencoder              all_features
# 235  autoencoder              all_features
# 236  autoencoder          no_diff_features
# 237  autoencoder             diff_features
# 238  autoencoder              w20_features
# 239  autoencoder              w20_features
# 240  autoencoder              w20_features
# 241  autoencoder              all_features
# 242   raw_signal  differencing_Ax_mean_w15
# 243  autoencoder              w10_features
# 244  autoencoder              w15_features
# 245  autoencoder              w15_features
#
#                                                                      params  \
# 0              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 1             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 2             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 3              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 4             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 5             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 6              {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 7              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 8              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 9             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 10             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 11         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 12            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 13            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 14             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 15            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 16             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 17                                                     {'hidden_mlp': [32]}
# 18            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 19         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 20             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 21                                            {'hidden_mlp': [128, 64, 32]}
# 22                                                       {'hidden_mlp': []}
# 23             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 24             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 25            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 26                                                     {'hidden_mlp': [32]}
# 27                                                                       {}
# 28                                                 {'hidden_mlp': [64, 32]}
# 29            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 30                                                                       {}
# 31            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 32             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 33            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 34             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 35                                            {'hidden_mlp': [128, 64, 32]}
# 36            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 37            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 38                                           {'time_steps': 5, 'units': 64}
# 39             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 40             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 41        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 42                                           {'time_steps': 5, 'units': 64}
# 43                                                       {'hidden_mlp': []}
# 44                                         {'time_steps': 10, 'units': 128}
# 45             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 46                                                       {'hidden_mlp': []}
# 47             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 48                                                 {'hidden_mlp': [64, 32]}
# 49            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 50         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 51                                          {'time_steps': 5, 'units': 128}
# 52             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 53             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 54             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 55                                           {'time_steps': 5, 'units': 64}
# 56             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 57             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 58                                          {'time_steps': 10, 'units': 64}
# 59                                          {'time_steps': 5, 'units': 128}
# 60             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 61             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 62                                         {'time_steps': 10, 'units': 128}
# 63                                                       {'hidden_mlp': []}
# 64                                          {'time_steps': 10, 'units': 64}
# 65            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 66            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 67            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 68                                         {'time_steps': 10, 'units': 128}
# 69                                          {'time_steps': 5, 'units': 128}
# 70                                          {'time_steps': 5, 'units': 128}
# 71         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 72                                                 {'hidden_mlp': [64, 32]}
# 73                                          {'time_steps': 5, 'units': 128}
# 74             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 75                                         {'time_steps': 10, 'units': 128}
# 76             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 77             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 78                                          {'time_steps': 5, 'units': 128}
# 79                                           {'time_steps': 5, 'units': 64}
# 80         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 81                                           {'time_steps': 5, 'units': 64}
# 82                                         {'time_steps': 10, 'units': 128}
# 83                                         {'time_steps': 10, 'units': 128}
# 84            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 85                                                     {'hidden_mlp': [32]}
# 86                                          {'time_steps': 5, 'units': 128}
# 87                                          {'time_steps': 5, 'units': 128}
# 88            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 89                                          {'time_steps': 10, 'units': 64}
# 90                                           {'time_steps': 5, 'units': 64}
# 91                                          {'time_steps': 10, 'units': 64}
# 92            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 93                                          {'time_steps': 5, 'units': 128}
# 94        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 95         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 96                                          {'time_steps': 10, 'units': 64}
# 97            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 98   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 99        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 100                                         {'time_steps': 10, 'units': 64}
# 101                                         {'time_steps': 10, 'units': 64}
# 102  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 103                                        {'time_steps': 10, 'units': 128}
# 104                                         {'time_steps': 5, 'units': 128}
# 105                                                    {'hidden_mlp': [32]}
# 106       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 107                                           {'hidden_mlp': [128, 64, 32]}
# 108                                         {'time_steps': 5, 'units': 128}
# 109                                         {'time_steps': 5, 'units': 128}
# 110                                         {'time_steps': 10, 'units': 64}
# 111            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 112       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 113                                         {'time_steps': 5, 'units': 128}
# 114                                          {'time_steps': 5, 'units': 64}
# 115                                          {'time_steps': 5, 'units': 64}
# 116                                          {'time_steps': 5, 'units': 64}
# 117                                          {'time_steps': 5, 'units': 64}
# 118                                                {'hidden_mlp': [64, 32]}
# 119                                        {'time_steps': 10, 'units': 128}
# 120        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 121                                          {'time_steps': 5, 'units': 64}
# 122                                          {'time_steps': 5, 'units': 64}
# 123                                                {'hidden_mlp': [64, 32]}
# 124                                         {'time_steps': 10, 'units': 64}
# 125                                         {'time_steps': 5, 'units': 128}
# 126       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 127                                         {'time_steps': 5, 'units': 128}
# 128                                        {'time_steps': 10, 'units': 128}
# 129  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 130           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 131           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 132                                        {'time_steps': 10, 'units': 128}
# 133           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 134                                          {'time_steps': 5, 'units': 64}
# 135                                          {'time_steps': 5, 'units': 64}
# 136                                           {'hidden_mlp': [128, 64, 32]}
# 137  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 138  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 139                                                      {'hidden_mlp': []}
# 140                                         {'time_steps': 10, 'units': 64}
# 141                                          {'time_steps': 5, 'units': 64}
# 142  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 143                                                    {'hidden_mlp': [32]}
# 144                                           {'hidden_mlp': [128, 64, 32]}
# 145                                        {'time_steps': 10, 'units': 128}
# 146                                                                      {}
# 147       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 148                                         {'time_steps': 5, 'units': 128}
# 149                                         {'time_steps': 5, 'units': 128}
# 150                                         {'time_steps': 10, 'units': 64}
# 151                                                                      {}
# 152                                          {'time_steps': 5, 'units': 64}
# 153                                         {'time_steps': 10, 'units': 64}
# 154                                         {'time_steps': 10, 'units': 64}
# 155                                         {'time_steps': 5, 'units': 128}
# 156                                          {'time_steps': 5, 'units': 64}
# 157                                                    {'hidden_mlp': [32]}
# 158           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 159                                         {'time_steps': 10, 'units': 64}
# 160  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 161                                                                      {}
# 162           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 163                                           {'hidden_mlp': [128, 64, 32]}
# 164                                        {'time_steps': 10, 'units': 128}
# 165                                           {'hidden_mlp': [128, 64, 32]}
# 166                                                      {'hidden_mlp': []}
# 167                                        {'time_steps': 10, 'units': 128}
# 168                                                {'hidden_mlp': [64, 32]}
# 169                                                {'hidden_mlp': [64, 32]}
# 170                                                    {'hidden_mlp': [32]}
# 171                                          {'time_steps': 5, 'units': 64}
# 172                                        {'time_steps': 10, 'units': 128}
# 173                                         {'time_steps': 10, 'units': 64}
# 174                                          {'time_steps': 5, 'units': 64}
# 175                                          {'time_steps': 5, 'units': 64}
# 176                                                                      {}
# 177                                                                      {}
# 178                                                                      {}
# 179                                                                      {}
# 180                                        {'time_steps': 10, 'units': 128}
# 181                                                                      {}
# 182                                        {'time_steps': 10, 'units': 128}
# 183                                         {'time_steps': 10, 'units': 64}
# 184                                        {'time_steps': 10, 'units': 128}
# 185                                        {'time_steps': 10, 'units': 128}
# 186                                                      {'hidden_mlp': []}
# 187                                          {'time_steps': 5, 'units': 64}
# 188                                         {'time_steps': 10, 'units': 64}
# 189                                         {'time_steps': 10, 'units': 64}
# 190                                                                      {}
# 191                                         {'time_steps': 5, 'units': 128}
# 192                                         {'time_steps': 5, 'units': 128}
# 193                                                                      {}
# 194                                        {'time_steps': 10, 'units': 128}
# 195                                                                      {}
# 196                                                                      {}
# 197                                         {'time_steps': 10, 'units': 64}
# 198                                                                      {}
# 199                                         {'time_steps': 10, 'units': 64}
# 200                                                                      {}
# 201                                         {'time_steps': 5, 'units': 128}
# 202                                        {'time_steps': 10, 'units': 128}
# 203                                                                      {}
# 204                                                                      {}
# 205                                         {'time_steps': 10, 'units': 64}
# 206                                                                      {}
# 207                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 208                                                                      {}
# 209                                                                      {}
# 210                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 211                                                                      {}
# 212                                                                      {}
# 213                                                                      {}
# 214                                                                      {}
# 215                                                                      {}
# 216                                                                      {}
# 217                                                                      {}
# 218                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 219                                        {'time_steps': 10, 'units': 128}
# 220                                                                      {}
# 221                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 222                                                                      {}
# 223                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 224                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 225                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 226                                                                      {}
# 227                                                                      {}
# 228                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 229                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 230                                                                      {}
# 231                                                                      {}
# 232                                                                      {}
# 233                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 234                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 235                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 236                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 237                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 238                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 239                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 240                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 241                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 242                                                                      {}
# 243                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 244                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 245                                   {'hidden_ae': [128, 56, 18, 56, 128]}
#
#       seed  params_idx    cost  anticipation  detected_faults  missed_faults  \
# 0   200.00        0.00    1.13          0.89            13.00           0.00
# 1   200.00        5.00    5.33          0.90            13.00           0.00
# 2   200.00        7.00   28.00          0.81            13.00           0.00
# 3   200.00        0.00   68.67          0.76            13.00           0.00
# 4   200.00        7.00   31.33          0.89            13.00           0.00
# 5   200.00        5.00   80.67          0.79            12.33           0.67
# 6   200.00        1.00   17.67          0.84            13.00           0.00
# 7   200.00        0.00   26.20          0.78            13.00           0.00
# 8   200.00        3.00   29.33          0.85            13.00           0.00
# 9   200.00        7.00   38.33          0.75            13.00           0.00
# 10  200.00        3.00   70.87          0.78            13.00           0.00
# 11  200.00        4.00   53.60          0.72            13.00           0.00
# 12  200.00        7.00   90.00          0.67            13.00           0.00
# 13  200.00        8.00   88.73          0.82            13.00           0.00
# 14  200.00        0.00  180.00          0.67            11.00           2.00
# 15  200.00        5.00  171.60          0.70            11.00           2.00
# 16  200.00        1.00  146.93          0.74            13.00           0.00
# 17  200.00        1.00  168.13          0.65            13.00           0.00
