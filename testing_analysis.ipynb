# %% [markdown]
# # Testing analysis

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {5, 10, 15, 20} (aka 0.5, 1, 1.5, 2 seconds)
margin = 30

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_res = pd.read_csv("summaries/testing_summary_" + str(margin) + ".csv", index_col=[0])
df_res_sorted = df_res.sort_values(by=['cost'])
df_res_sorted = df_res_sorted.reset_index(drop=True)
df_res_sorted['#'] = df_res_sorted.index
print("There are", len(df_res_sorted), "models for margin =", margin)
df_res_sorted.head(50)
# Out:
# There are 738 models for margin = 30
#       model  seed        columns  \
# 0   conv_nn   200   w10_features
# 1   conv_nn   300  diff_features
# 2   conv_nn   200  diff_features
# 3   conv_nn   200  diff_features
# 4   conv_nn   300  diff_features
# 5   conv_nn   200   w10_features
# 6   conv_nn   200    w5_features
# 7   conv_nn   300   w20_features
# 8   conv_nn   100  diff_features
# 9   conv_nn   100  diff_features
# 10  conv_nn   300  diff_features
# 11  conv_nn   100  diff_features
# 12  conv_nn   100  diff_features
# 13  conv_nn   200  diff_features
# 14  conv_nn   300   w10_features
# 15  conv_nn   100   w10_features
# 16  conv_nn   100   w10_features
# 17  conv_nn   100    w5_features
# 18  conv_nn   300   w20_features
# 19  conv_nn   100    w5_features
# 20  conv_nn   300   w10_features
# 21  conv_nn   100    w5_features
# 22  conv_nn   300    w5_features
# 23  conv_nn   100    w5_features
# 24  conv_nn   300    w5_features
# 25  conv_nn   100  diff_features
# 26  conv_nn   300    w5_features
# 27  conv_nn   200    w5_features
# 28  conv_nn   100   w15_features
# 29  conv_nn   300    w5_features
# 30  conv_nn   200    w5_features
# 31  conv_nn   100   w10_features
# 32  conv_nn   300    w5_features
# 33  conv_nn   300   w20_features
# 34  conv_nn   300   w15_features
# 35  conv_nn   300   w15_features
# 36  conv_nn   200    w5_features
# 37  conv_nn   100    w5_features
# 38  conv_nn   300  diff_features
# 39  conv_nn   200  diff_features
# 40  conv_nn   300  diff_features
# 41  conv_nn   300   all_features
# 42  conv_nn   300   all_features
# 43  conv_nn   200    w5_features
# 44  conv_nn   100   w20_features
# 45  conv_nn   200  diff_features
# 46  conv_nn   100   w10_features
# 47  conv_nn   100   all_features
# 48  conv_nn   100    w5_features
# 49  conv_nn   200  diff_features
#
#                                                               params  \
# 0       {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 1       {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 2      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 3       {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 4       {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 5       {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 6      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 7      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 8      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 9      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 10     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 11      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 12      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 13      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 14     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 15     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 16      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 17     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 18      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 19      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 20      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 21     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 22     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 23      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 24      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 25      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 26     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 27      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 28     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 29      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 30      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 31     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 32      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 33      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 34     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 35      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 36      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 37      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 38     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 39      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 40      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 41     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 42      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 43     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 44     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 45      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 46      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 47     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 48      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 49  {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
#
#     params_idx  cost  anticipation  detected_faults  missed_faults  \
# 0            1  0.00          2.90               13              0
# 1            2  0.00          2.90               13              0
# 2            5  0.00          2.90               13              0
# 3            0  0.00          2.90               13              0
# 4            0  0.00          2.90               13              0
# 5            3  0.00          2.90               13              0
# 6            6  0.00          2.90               13              0
# 7            5  0.00          2.90               13              0
# 8            7  0.00          2.90               13              0
# 9            5  0.00          2.90               13              0
# 10           5  0.00          2.90               13              0
# 11           0  0.00          2.90               13              0
# 12           2  0.00          2.90               13              0
# 13           3  0.00          2.90               13              0
# 14           5  0.00          2.90               13              0
# 15           5  0.00          2.90               13              0
# 16           0  0.00          2.90               13              0
# 17           7  0.00          2.90               13              0
# 18           0  0.00          2.90               13              0
# 19           2  0.00          2.90               13              0
# 20           0  0.00          2.90               13              0
# 21           5  0.20          2.90               13              0
# 22           5  0.40          2.90               13              0
# 23           0  0.40          2.90               13              0
# 24           0  0.80          2.90               13              0
# 25           3  1.00          2.89               13              0
# 26           7  1.00          2.89               13              0
# 27           1  2.20          2.88               13              0
# 28           5  3.00          2.88               13              0
# 29           2  3.00          2.90               13              0
# 30           3  3.20          2.90               13              0
# 31           7  4.00          2.87               13              0
# 32           3  4.20          2.87               13              0
# 33           3  5.00          2.86               13              0
# 34           5  5.00          2.86               13              0
# 35           0  5.00          2.87               13              0
# 36           2  5.60          2.89               13              0
# 37           1  8.60          2.84               13              0
# 38           7  9.60          2.90               13              0
# 39           2 11.00          2.82               13              0
# 40           1 11.60          2.89               13              0
# 41           5 12.00          2.81               13              0
# 42           0 12.00          2.82               13              0
# 43           7 15.00          2.80               13              0
# 44           5 15.00          2.79               13              0
# 45           1 16.00          2.85               13              0
# 46           2 20.00          2.78               13              0
# 47           5 23.00          2.76               13              0
# 48           3 23.00          2.78               13              0
# 49           4 24.00          2.80               13              0
#
#     false_alarms   #
# 0              0   0
# 1              0   1
# 2              0   2
# 3              0   3
# 4              0   4
# 5              0   5
# 6              0   6
# 7              0   7
# 8              0   8
# 9              0   9
# 10             0  10
# 11             0  11
# 12             0  12
# 13             0  13
# 14             0  14
# 15             0  15
# 16             0  16
# 17             0  17
# 18             0  18
# 19             0  19
# 20             0  20
# 21             1  21
# 22             2  22
# 23             2  23
# 24             4  24
# 25             0  25
# 26             0  26
# 27             1  27
# 28             0  28
# 29            15  29
# 30            16  30
# 31             0  31
# 32             1  32
# 33             0  33
# 34             0  34
# 35             0  35
# 36            23  36
# 37             3  37
# 38            48  38
# 39             0  39
# 40            53  40
# 41             0  41
# 42             0  42
# 43             0  43
# 44             0  44
# 45             0  45
# 46             0  46
# 47             0  47
# 48             0  48
# 49            10  49

# %% [markdown]
# ## Check performance of a given model for all seeds

# %%
model = "conv_nn"
columns = "diff_features"
params_idx = 0

df_res_sorted[(df_res_sorted["model"] == model) & (df_res_sorted["columns"] == columns) & (df_res_sorted["params_idx"] == params_idx)]
# Out:
#       model  seed        columns  \
# 3   conv_nn   200  diff_features
# 4   conv_nn   300  diff_features
# 11  conv_nn   100  diff_features
#
#                                                           params  params_idx  \
# 3   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 4   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 11  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
#
#     cost  anticipation  detected_faults  missed_faults  false_alarms   #
# 3   0.00          2.90               13              0             0   3
# 4   0.00          2.90               13              0             0   4
# 11  0.00          2.90               13              0             0  11

# %% [markdown]
# ## Average performance of models

# %%
df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
# <ipython-input-13-852b8f186669>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
#          model    cost  anticipation  detected_faults  missed_faults  \
# 0   raw_signal 2395.74          2.83            12.61           0.39
# 1  autoencoder 2707.59          2.90            13.00           0.00
# 2      conv_nn 3266.51          1.30             6.85           6.15
# 3          gru 5046.56          0.48             6.36           6.64
# 4          mlp 5348.07          0.30             2.87          10.13
# 5         lstm 5368.97          0.36             4.50           8.50
# 6       bilstm 5612.34          0.14             3.80           9.20
#
#    false_alarms
# 0      10840.53
# 1      13537.95
# 2        265.90
# 3       1484.00
# 4        507.93
# 5       1041.62
# 6        243.31

# %% [markdown]
# ## Average performance of models with same hyperparameters and features

# %%
df_res_sorted.groupby(by=["model", "columns", "params"]).mean().sort_values(by=["cost"]).reset_index()[["model", "columns", "params", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
#            model                   columns  \
# 0        conv_nn             diff_features
# 1        conv_nn             diff_features
# 2        conv_nn               w5_features
# 3        conv_nn             diff_features
# 4        conv_nn               w5_features
# 5        conv_nn               w5_features
# 6        conv_nn               w5_features
# 7        conv_nn             diff_features
# 8        conv_nn               w5_features
# 9        conv_nn               w5_features
# 10       conv_nn             diff_features
# 11       conv_nn             diff_features
# 12       conv_nn               w5_features
# 13       conv_nn               w5_features
# 14       conv_nn              w10_features
# 15       conv_nn             diff_features
# 16    raw_signal                   Ax_diff
# 17    raw_signal      differencing_Ax_diff
# 18    raw_signal                Ax_std_w10
# 19       conv_nn             diff_features
# 20    raw_signal                Ax_std_w20
# 21    raw_signal    differencing_Ax_std_w5
# 22           mlp               w5_features
# 23           mlp              w10_features
# 24       conv_nn              all_features
# 25    raw_signal                 Ax_std_w5
# 26    raw_signal                Ax_std_w15
# 27       conv_nn              w10_features
# 28       conv_nn              all_features
# 29       conv_nn              w10_features
# 30       conv_nn              w15_features
# 31       conv_nn              all_features
# 32       conv_nn              w15_features
# 33       conv_nn              w20_features
# 34       conv_nn              w20_features
# 35       conv_nn              w15_features
# 36       conv_nn              w15_features
# 37       conv_nn              w20_features
# 38       conv_nn              w20_features
# 39       conv_nn              all_features
# 40       conv_nn              w10_features
# 41       conv_nn              w15_features
# 42    raw_signal   differencing_Ax_std_w20
# 43       conv_nn             diff_features
# 44       conv_nn              w20_features
# 45       conv_nn              w15_features
# 46       conv_nn              w10_features
# 47       conv_nn             diff_features
# 48       conv_nn              w20_features
# 49    raw_signal           differencing_Ax
# 50    raw_signal                Ax_max_w10
# 51    raw_signal    differencing_Ax_max_w5
# 52    raw_signal                        Ax
# 53    raw_signal                 Ax_max_w5
# 54   autoencoder               w5_features
# 55   autoencoder             diff_features
# 56   autoencoder              w15_features
# 57   autoencoder              w10_features
# 58   autoencoder              w10_features
# 59   autoencoder              w10_features
# 60   autoencoder          no_diff_features
# 61   autoencoder             diff_features
# 62   autoencoder          no_diff_features
# 63    raw_signal                Ax_max_w15
# 64   autoencoder              w15_features
# 65   autoencoder          no_diff_features
# 66   autoencoder              w15_features
# 67   autoencoder              all_features
# 68   autoencoder              w20_features
# 69    raw_signal                 Ax_min_w5
# 70   autoencoder              w20_features
# 71   autoencoder              all_features
# 72   autoencoder              all_features
# 73    raw_signal   differencing_Ax_max_w10
# 74    raw_signal   differencing_Ax_max_w15
# 75    raw_signal   differencing_Ax_max_w20
# 76    raw_signal  differencing_Ax_mean_w10
# 77    raw_signal  differencing_Ax_mean_w15
# 78    raw_signal  differencing_Ax_mean_w20
# 79    raw_signal   differencing_Ax_mean_w5
# 80    raw_signal   differencing_Ax_min_w10
# 81    raw_signal   differencing_Ax_min_w15
# 82    raw_signal   differencing_Ax_min_w20
# 83    raw_signal    differencing_Ax_min_w5
# 84    raw_signal                Ax_min_w20
# 85    raw_signal                Ax_min_w15
# 86   autoencoder             diff_features
# 87   autoencoder               w5_features
# 88    raw_signal                Ax_max_w20
# 89   autoencoder               w5_features
# 90    raw_signal               Ax_mean_w15
# 91   autoencoder              w20_features
# 92    raw_signal               Ax_mean_w20
# 93    raw_signal                Ax_mean_w5
# 94    raw_signal               Ax_mean_w10
# 95    raw_signal                Ax_min_w10
# 96    raw_signal   differencing_Ax_std_w15
# 97    raw_signal   differencing_Ax_std_w10
# 98           gru             diff_features
# 99           mlp               w5_features
# 100         lstm             diff_features
# 101          mlp               w5_features
# 102          gru             diff_features
# 103         lstm             diff_features
# 104          gru              w10_features
# 105      conv_nn              w10_features
# 106      conv_nn              w10_features
# 107      conv_nn             diff_features
# 108      conv_nn              w10_features
# 109      conv_nn              all_features
# 110      conv_nn               w5_features
# 111         lstm             diff_features
# 112      conv_nn               w5_features
# 113          mlp               w5_features
# 114         lstm              w10_features
# 115      conv_nn              w15_features
# 116       bilstm             diff_features
# 117      conv_nn              w15_features
# 118      conv_nn               w5_features
# 119         lstm             diff_features
# 120       bilstm               w5_features
# 121          gru               w5_features
# 122         lstm              all_features
# 123          gru               w5_features
# 124          gru             diff_features
# 125          gru              w10_features
# 126      conv_nn              all_features
# 127       bilstm               w5_features
# 128          gru              w15_features
# 129          gru          no_diff_features
# 130       bilstm             diff_features
# 131       bilstm               w5_features
# 132          mlp             diff_features
# 133          gru              w20_features
# 134          gru              all_features
# 135         lstm              all_features
# 136      conv_nn              all_features
# 137      conv_nn          no_diff_features
# 138          gru               w5_features
# 139          gru              all_features
# 140         lstm               w5_features
# 141          gru             diff_features
# 142          gru               w5_features
# 143          gru              w15_features
# 144       bilstm               w5_features
# 145       bilstm              all_features
# 146          gru              all_features
# 147          gru              w10_features
# 148       bilstm              all_features
# 149          gru              w20_features
# 150         lstm              w15_features
# 151         lstm               w5_features
# 152          gru              w15_features
# 153          gru              all_features
# 154         lstm              all_features
# 155       bilstm              w20_features
# 156         lstm              w10_features
# 157      conv_nn          no_diff_features
# 158       bilstm              w10_features
# 159         lstm              all_features
# 160          gru              w20_features
# 161       bilstm              all_features
# 162       bilstm              w20_features
# 163       bilstm             diff_features
# 164         lstm              w20_features
# 165          gru              w20_features
# 166          mlp             diff_features
# 167       bilstm              w20_features
# 168         lstm              w10_features
# 169       bilstm              w10_features
# 170         lstm              w15_features
# 171          mlp              all_features
# 172       bilstm             diff_features
# 173          mlp              w20_features
# 174       bilstm              w10_features
# 175       bilstm              all_features
# 176       bilstm              w10_features
# 177      conv_nn              all_features
# 178         lstm              w10_features
# 179          mlp              w10_features
# 180         lstm              w20_features
# 181      conv_nn          no_diff_features
# 182          mlp              w10_features
# 183          gru              w10_features
# 184         lstm              w15_features
# 185      conv_nn              w10_features
# 186       bilstm              w15_features
# 187         lstm               w5_features
# 188      conv_nn              all_features
# 189          mlp              w10_features
# 190      conv_nn              w15_features
# 191      conv_nn          no_diff_features
# 192      conv_nn              w15_features
# 193      conv_nn              w10_features
# 194      conv_nn              all_features
# 195      conv_nn          no_diff_features
# 196       bilstm              w15_features
# 197      conv_nn              w20_features
# 198      conv_nn          no_diff_features
# 199          mlp             diff_features
# 200         lstm              w15_features
# 201       bilstm              w20_features
# 202      conv_nn          no_diff_features
# 203          gru          no_diff_features
# 204          gru              w15_features
# 205         lstm          no_diff_features
# 206      conv_nn              w20_features
# 207       bilstm              w15_features
# 208       bilstm              w15_features
# 209          gru          no_diff_features
# 210         lstm               w5_features
# 211      conv_nn          no_diff_features
# 212       bilstm          no_diff_features
# 213       bilstm          no_diff_features
# 214       bilstm          no_diff_features
# 215          gru          no_diff_features
# 216      conv_nn              w20_features
# 217      conv_nn              w20_features
# 218         lstm          no_diff_features
# 219      conv_nn              w15_features
# 220          mlp          no_diff_features
# 221          mlp              all_features
# 222          mlp              w15_features
# 223          mlp              w15_features
# 224          mlp              w15_features
# 225          mlp              w15_features
# 226          mlp              w20_features
# 227          mlp          no_diff_features
# 228          mlp              w20_features
# 229          mlp              w20_features
# 230          mlp          no_diff_features
# 231          mlp          no_diff_features
# 232          mlp              all_features
# 233      conv_nn          no_diff_features
# 234      conv_nn          no_diff_features
# 235      conv_nn              w10_features
# 236      conv_nn              w20_features
# 237          mlp              all_features
# 238      conv_nn              all_features
# 239      conv_nn          no_diff_features
# 240       bilstm          no_diff_features
# 241          mlp             diff_features
# 242         lstm          no_diff_features
# 243         lstm              w20_features
# 244         lstm              w20_features
# 245         lstm          no_diff_features
#
#                                                                      params  \
# 0             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 1              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 2              {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 3              {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 4             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 5             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 6              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 7              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 8              {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 9             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 10            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 11             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 12             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 13         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 14             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 15         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 16                                                                       {}
# 17                                                                       {}
# 18                                                                       {}
# 19            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 20                                                                       {}
# 21                                                                       {}
# 22                                                       {'hidden_mlp': []}
# 23                                                       {'hidden_mlp': []}
# 24            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 25                                                                       {}
# 26                                                                       {}
# 27            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 28            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 29            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 30             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 31             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 32            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 33            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 34             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 35            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 36             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 37            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 38             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 39             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 40             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 41   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 42                                                                       {}
# 43        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 44             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 45            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 46   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 47            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 48            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 49                                                                       {}
# 50                                                                       {}
# 51                                                                       {}
# 52                                                                       {}
# 53                                                                       {}
# 54                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 55                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 56                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 57                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 58                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 59                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 60                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 61                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 62                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 63                                                                       {}
# 64                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 65                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 66                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 67                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 68                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 69                                                                       {}
# 70                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 71                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 72                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 73                                                                       {}
# 74                                                                       {}
# 75                                                                       {}
# 76                                                                       {}
# 77                                                                       {}
# 78                                                                       {}
# 79                                                                       {}
# 80                                                                       {}
# 81                                                                       {}
# 82                                                                       {}
# 83                                                                       {}
# 84                                                                       {}
# 85                                                                       {}
# 86                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 87                                    {'hidden_ae': [128, 56, 18, 56, 128]}
# 88                                                                       {}
# 89                                         {'hidden_ae': [16, 8, 2, 8, 16]}
# 90                                                                       {}
# 91                                       {'hidden_ae': [64, 24, 9, 24, 64]}
# 92                                                                       {}
# 93                                                                       {}
# 94                                                                       {}
# 95                                                                       {}
# 96                                                                       {}
# 97                                                                       {}
# 98                                          {'time_steps': 10, 'units': 64}
# 99                                            {'hidden_mlp': [128, 64, 32]}
# 100                                        {'time_steps': 10, 'units': 128}
# 101                                                {'hidden_mlp': [64, 32]}
# 102                                        {'time_steps': 10, 'units': 128}
# 103                                         {'time_steps': 5, 'units': 128}
# 104                                        {'time_steps': 10, 'units': 128}
# 105            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 106           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 107  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 108            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 109            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 110       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 111                                         {'time_steps': 10, 'units': 64}
# 112           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 113                                                    {'hidden_mlp': [32]}
# 114                                        {'time_steps': 10, 'units': 128}
# 115            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 116                                        {'time_steps': 10, 'units': 128}
# 117            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 118  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 119                                          {'time_steps': 5, 'units': 64}
# 120                                         {'time_steps': 5, 'units': 128}
# 121                                        {'time_steps': 10, 'units': 128}
# 122                                        {'time_steps': 10, 'units': 128}
# 123                                         {'time_steps': 5, 'units': 128}
# 124                                          {'time_steps': 5, 'units': 64}
# 125                                         {'time_steps': 10, 'units': 64}
# 126            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 127                                         {'time_steps': 10, 'units': 64}
# 128                                          {'time_steps': 5, 'units': 64}
# 129                                        {'time_steps': 10, 'units': 128}
# 130                                          {'time_steps': 5, 'units': 64}
# 131                                          {'time_steps': 5, 'units': 64}
# 132                                                      {'hidden_mlp': []}
# 133                                         {'time_steps': 10, 'units': 64}
# 134                                          {'time_steps': 5, 'units': 64}
# 135                                         {'time_steps': 10, 'units': 64}
# 136  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 137            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 138                                          {'time_steps': 5, 'units': 64}
# 139                                         {'time_steps': 5, 'units': 128}
# 140                                         {'time_steps': 10, 'units': 64}
# 141                                         {'time_steps': 5, 'units': 128}
# 142                                         {'time_steps': 10, 'units': 64}
# 143                                         {'time_steps': 10, 'units': 64}
# 144                                        {'time_steps': 10, 'units': 128}
# 145                                        {'time_steps': 10, 'units': 128}
# 146                                        {'time_steps': 10, 'units': 128}
# 147                                         {'time_steps': 5, 'units': 128}
# 148                                          {'time_steps': 5, 'units': 64}
# 149                                        {'time_steps': 10, 'units': 128}
# 150                                        {'time_steps': 10, 'units': 128}
# 151                                         {'time_steps': 5, 'units': 128}
# 152                                        {'time_steps': 10, 'units': 128}
# 153                                         {'time_steps': 10, 'units': 64}
# 154                                          {'time_steps': 5, 'units': 64}
# 155                                        {'time_steps': 10, 'units': 128}
# 156                                         {'time_steps': 10, 'units': 64}
# 157           {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 158                                          {'time_steps': 5, 'units': 64}
# 159                                         {'time_steps': 5, 'units': 128}
# 160                                         {'time_steps': 5, 'units': 128}
# 161                                         {'time_steps': 10, 'units': 64}
# 162                                         {'time_steps': 5, 'units': 128}
# 163                                         {'time_steps': 10, 'units': 64}
# 164                                         {'time_steps': 5, 'units': 128}
# 165                                          {'time_steps': 5, 'units': 64}
# 166                                           {'hidden_mlp': [128, 64, 32]}
# 167                                          {'time_steps': 5, 'units': 64}
# 168                                         {'time_steps': 5, 'units': 128}
# 169                                         {'time_steps': 5, 'units': 128}
# 170                                         {'time_steps': 5, 'units': 128}
# 171                                                      {'hidden_mlp': []}
# 172                                         {'time_steps': 5, 'units': 128}
# 173                                                    {'hidden_mlp': [32]}
# 174                                         {'time_steps': 10, 'units': 64}
# 175                                         {'time_steps': 5, 'units': 128}
# 176                                        {'time_steps': 10, 'units': 128}
# 177       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 178                                          {'time_steps': 5, 'units': 64}
# 179                                           {'hidden_mlp': [128, 64, 32]}
# 180                                        {'time_steps': 10, 'units': 128}
# 181            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 182                                                {'hidden_mlp': [64, 32]}
# 183                                          {'time_steps': 5, 'units': 64}
# 184                                         {'time_steps': 10, 'units': 64}
# 185           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 186                                        {'time_steps': 10, 'units': 128}
# 187                                        {'time_steps': 10, 'units': 128}
# 188        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 189                                                    {'hidden_mlp': [32]}
# 190           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 191            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 192        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 193        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 194           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 195            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 196                                         {'time_steps': 5, 'units': 128}
# 197        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 198           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 199                                                {'hidden_mlp': [64, 32]}
# 200                                          {'time_steps': 5, 'units': 64}
# 201                                         {'time_steps': 10, 'units': 64}
# 202       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 203                                         {'time_steps': 5, 'units': 128}
# 204                                         {'time_steps': 5, 'units': 128}
# 205                                         {'time_steps': 5, 'units': 128}
# 206            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 207                                          {'time_steps': 5, 'units': 64}
# 208                                         {'time_steps': 10, 'units': 64}
# 209                                          {'time_steps': 5, 'units': 64}
# 210                                          {'time_steps': 5, 'units': 64}
# 211        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 212                                          {'time_steps': 5, 'units': 64}
# 213                                         {'time_steps': 5, 'units': 128}
# 214                                         {'time_steps': 10, 'units': 64}
# 215                                         {'time_steps': 10, 'units': 64}
# 216           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 217       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 218                                          {'time_steps': 5, 'units': 64}
# 219       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 220                                                {'hidden_mlp': [64, 32]}
# 221                                                    {'hidden_mlp': [32]}
# 222                                           {'hidden_mlp': [128, 64, 32]}
# 223                                                    {'hidden_mlp': [32]}
# 224                                                {'hidden_mlp': [64, 32]}
# 225                                                      {'hidden_mlp': []}
# 226                                           {'hidden_mlp': [128, 64, 32]}
# 227                                                    {'hidden_mlp': [32]}
# 228                                                {'hidden_mlp': [64, 32]}
# 229                                                      {'hidden_mlp': []}
# 230                                                      {'hidden_mlp': []}
# 231                                           {'hidden_mlp': [128, 64, 32]}
# 232                                           {'hidden_mlp': [128, 64, 32]}
# 233           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 234  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 235       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 236  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 237                                                {'hidden_mlp': [64, 32]}
# 238           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 239           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 240                                        {'time_steps': 10, 'units': 128}
# 241                                                    {'hidden_mlp': [32]}
# 242                                         {'time_steps': 10, 'units': 64}
# 243                                          {'time_steps': 5, 'units': 64}
# 244                                         {'time_steps': 10, 'units': 64}
# 245                                        {'time_steps': 10, 'units': 128}
#
#        cost  anticipation  detected_faults  missed_faults  false_alarms
# 0      0.00          2.90            13.00           0.00          0.00
# 1      0.00          2.90            13.00           0.00          0.00
# 2      2.87          2.90            13.00           0.00         12.67
# 3      3.67          2.87            13.00           0.00          0.00
# 4      5.33          2.86            13.00           0.00          0.00
# 5      8.53          2.85            13.00           0.00          1.00
# 6     10.13          2.85            13.00           0.00          5.67
# 7     20.33          2.83            13.00           0.00          0.00
# 8     29.00          2.87            13.00           0.00        128.33
# 9     68.67          2.67            13.00           0.00          0.00
# 10   105.53          2.82            13.00           0.00         16.00
# 11   124.53          2.72            13.00           0.00         17.67
# 12   190.87          2.90            13.00           0.00        954.33
# 13   262.33          2.47            13.00           0.00          0.00
# 14   287.33          2.73            12.67           0.33          0.00
# 15   377.67          2.44            13.00           0.00          3.33
# 16   696.20          2.35            13.00           0.00       1996.00
# 17   717.20          2.35            13.00           0.00       2101.00
# 18   996.20          2.87            13.00           0.00       4946.00
# 19  1032.00          2.82            13.00           0.00       4995.00
# 20  1079.20          2.88            13.00           0.00       5381.00
# 21  1111.00          2.32            13.00           0.00       3005.00
# 22  1404.33          2.90            13.00           0.00       7021.67
# 23  1517.33          1.63            13.00           0.00       1148.33
# 24  1643.33          1.78            12.33           0.67          0.00
# 25  1703.40          2.70            12.00           1.00       5117.00
# 26  1709.00          2.86            11.00           2.00       3865.00
# 27  1768.33          2.12            10.00           3.00          0.00
# 28  1882.67          1.92            10.33           2.67          0.00
# 29  1937.33          1.99             9.67           3.33          0.00
# 30  1957.33          1.92             9.67           3.33          0.00
# 31  2016.33          1.87             9.00           4.00          0.00
# 32  2017.67          1.91             8.67           4.33          0.00
# 33  2020.00          1.90             8.67           4.33          0.00
# 34  2031.20          1.92             8.67           4.33         72.67
# 35  2076.67          1.73             8.67           4.33          0.00
# 36  2083.00          1.96            10.67           2.33        880.00
# 37  2088.00          1.72             8.67           4.33          0.00
# 38  2163.33          1.83             9.33           3.67          0.00
# 39  2217.00          1.58             8.67           4.33         31.67
# 40  2230.67          1.64             8.67           4.33          0.00
# 41  2269.33          1.66             8.67           4.33        378.33
# 42  2331.60          2.71            10.00           3.00       4238.00
# 43  2339.33          1.90            12.67           0.33       4356.67
# 44  2341.33          1.91             8.67           4.33       1603.33
# 45  2467.33          1.95             9.33           3.67          0.00
# 46  2486.47          1.73             8.67           4.33       1854.00
# 47  2508.00          1.73            10.00           3.00       1911.67
# 48  2648.20          1.84             8.67           4.33       3011.00
# 49  2701.60          2.90            13.00           0.00      13508.00
# 50  2705.60          2.90            13.00           0.00      13528.00
# 51  2706.00          2.90            13.00           0.00      13530.00
# 52  2706.20          2.90            13.00           0.00      13531.00
# 53  2706.60          2.90            13.00           0.00      13533.00
# 54  2707.40          2.90            13.00           0.00      13537.00
# 55  2707.60          2.90            13.00           0.00      13538.00
