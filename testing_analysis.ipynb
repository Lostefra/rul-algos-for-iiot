# %% [markdown]
# # Testing analysis

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {5, 10, 15, 20} (aka 0.5, 1, 1.5, 2 seconds)
margin = 15

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_res = pd.read_csv("testing_summary_" + str(margin) + ".csv", index_col=[0])
df_res_sorted = df_res.sort_values(by=['cost'])
df_res_sorted = df_res_sorted.reset_index(drop=True)
df_res_sorted['#'] = df_res_sorted.index
print("There are", len(df_res_sorted), "models for margin =", margin)
df_res_sorted.head(50)
# Out:
# There are 738 models for margin = 15
#       model  seed        columns  \
# 0   conv_nn   300    w5_features
# 1   conv_nn   300   w20_features
# 2   conv_nn   300  diff_features
# 3   conv_nn   300  diff_features
# 4   conv_nn   300  diff_features
# 5   conv_nn   300   w15_features
# 6   conv_nn   300   w15_features
# 7   conv_nn   300   w15_features
# 8   conv_nn   300   w10_features
# 9   conv_nn   300   w10_features
# 10  conv_nn   100  diff_features
# 11  conv_nn   100  diff_features
# 12  conv_nn   100  diff_features
# 13  conv_nn   100   w20_features
# 14  conv_nn   100  diff_features
# 15  conv_nn   100   w10_features
# 16  conv_nn   300   w10_features
# 17  conv_nn   100    w5_features
# 18  conv_nn   100    w5_features
# 19  conv_nn   100    w5_features
# 20  conv_nn   100    w5_features
# 21  conv_nn   300    w5_features
# 22  conv_nn   100   w10_features
# 23  conv_nn   300   w20_features
# 24  conv_nn   100   w10_features
# 25  conv_nn   100   w10_features
# 26  conv_nn   100   w15_features
# 27  conv_nn   100  diff_features
# 28  conv_nn   300    w5_features
# 29  conv_nn   300   all_features
# 30  conv_nn   100   w15_features
# 31  conv_nn   200  diff_features
# 32  conv_nn   200   w10_features
# 33  conv_nn   200   w15_features
# 34  conv_nn   200   w20_features
# 35  conv_nn   300    w5_features
# 36  conv_nn   300  diff_features
# 37  conv_nn   300   w20_features
# 38  conv_nn   300    w5_features
# 39  conv_nn   200    w5_features
# 40  conv_nn   100   w15_features
# 41  conv_nn   200    w5_features
# 42  conv_nn   200    w5_features
# 43  conv_nn   200    w5_features
# 44  conv_nn   200    w5_features
# 45  conv_nn   300   w10_features
# 46  conv_nn   200  diff_features
# 47  conv_nn   200  diff_features
# 48  conv_nn   300    w5_features
# 49  conv_nn   100   w15_features
#
#                                                            params  params_idx  \
# 0   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 1    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 2    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 3    {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 4   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 5   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 6   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 7    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 8   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 9   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 10  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 11  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 12   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 13   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 14   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 15   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 16   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 17   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 18   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 19  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 20  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 21   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 22   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 23  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 24  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 25  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 26   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 27   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 28   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 29   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 30  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 31   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 32   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 33   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 34   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 35   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 36  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 37  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 38  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 39   {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           1
# 40   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 41   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 42  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 43  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}           5
# 44   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 45   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 46  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
# 47   {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           2
# 48   {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}           3
# 49  {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}           7
#
#     cost  anticipation  detected_faults  missed_faults  false_alarms   #
# 0   0.00          1.40               13              0             0   0
# 1   0.00          1.40               13              0             0   1
# 2   0.00          1.40               13              0             0   2
# 3   0.00          1.40               13              0             0   3
# 4   0.00          1.40               13              0             0   4
# 5   0.00          1.40               13              0             0   5
# 6   0.00          1.40               13              0             0   6
# 7   0.00          1.40               13              0             0   7
# 8   0.00          1.40               13              0             0   8
# 9   0.00          1.40               13              0             0   9
# 10  0.00          1.40               13              0             0  10
# 11  0.00          1.40               13              0             0  11
# 12  0.00          1.40               13              0             0  12
# 13  0.00          1.40               13              0             0  13
# 14  0.00          1.40               13              0             0  14
# 15  0.00          1.40               13              0             0  15
# 16  0.00          1.40               13              0             0  16
# 17  0.00          1.40               13              0             0  17
# 18  0.00          1.40               13              0             0  18
# 19  0.00          1.40               13              0             0  19
# 20  0.00          1.40               13              0             0  20
# 21  0.00          1.40               13              0             0  21
# 22  0.00          1.40               13              0             0  22
# 23  0.00          1.40               13              0             0  23
# 24  0.00          1.40               13              0             0  24
# 25  0.00          1.40               13              0             0  25
# 26  0.00          1.40               13              0             0  26
# 27  0.40          1.40               13              0             2  27
# 28  1.00          1.39               13              0             0  28
# 29  1.00          1.39               13              0             0  29
# 30  2.00          1.38               13              0             0  30
# 31  2.60          1.39               13              0             8  31
# 32  3.00          1.38               13              0             0  32
# 33  3.00          1.38               13              0             0  33
# 34  4.00          1.40               13              0            20  34
# 35  5.00          1.38               13              0            15  35
# 36  5.20          1.38               13              0            16  36
# 37  6.00          1.35               13              0             0  37
# 38  8.00          1.34               13              0             0  38
# 39  9.40          1.35               13              0             7  39
# 40 10.00          1.32               13              0             0  40
# 41 10.00          1.35               13              0            20  41
# 42 10.60          1.34               13              0            13  42
# 43 11.00          1.33               13              0             0  43
# 44 12.00          1.32               13              0             0  44
# 45 12.00          1.32               13              0             0  45
# 46 12.80          1.35               13              0            19  46
# 47 13.00          1.40               13              0            65  47
# 48 14.20          1.35               13              0            36  48
# 49 15.00          1.29               13              0             0  49

# %% [markdown]
# ## Check performance of a given model for all seeds

# %%
model = "conv_nn"
columns = "w10_features"
params_idx = 0

df_res_sorted[(df_res_sorted["model"] == model) & (df_res_sorted["columns"] == columns) & (df_res_sorted["params_idx"] == params_idx)]
# Out:
#       model  seed       columns  \
# 15  conv_nn   100  w10_features
# 16  conv_nn   300  w10_features
# 32  conv_nn   200  w10_features
#
#                                                           params  params_idx  \
# 15  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 16  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 32  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
#
#     cost  anticipation  detected_faults  missed_faults  false_alarms   #
# 15  0.00          1.40               13              0             0  15
# 16  0.00          1.40               13              0             0  16
# 32  3.00          1.38               13              0             0  32

# %% [markdown]
# ## Average performance of models

# %%
df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
# <ipython-input-15-852b8f186669>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
#          model    cost  anticipation  detected_faults  missed_faults  \
# 0      conv_nn  836.53          0.64             7.43           5.57
# 1          mlp 1293.22          0.25             4.76           8.24
# 2       bilstm 1415.58          0.20             4.37           8.63
# 3         lstm 1438.59          0.29             5.49           7.51
# 4          gru 1461.75          0.57             8.87           4.13
# 5   raw_signal 2331.81          1.15            10.31           2.69
# 6  autoencoder 2741.64          1.40            13.00           0.00
#
#    false_alarms
# 0        228.39
# 1        423.60
# 2        742.18
# 3       1262.30
# 4       3230.61
# 5       9941.39
# 6      13708.11

# %% [markdown]
# ## Average performance of models with same hyperparameters and features

# %%
df_res_sorted.groupby(by=["model", "columns", "params"]).mean().sort_values(by=["cost"]).reset_index()[["model", "columns", "params", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
#            model                   columns  \
# 0        conv_nn              w10_features
# 1        conv_nn               w5_features
# 2        conv_nn               w5_features
# 3        conv_nn             diff_features
# 4        conv_nn               w5_features
# 5        conv_nn             diff_features
# 6        conv_nn               w5_features
# 7        conv_nn               w5_features
# 8        conv_nn               w5_features
# 9        conv_nn             diff_features
# 10       conv_nn              w10_features
# 11       conv_nn              w10_features
# 12       conv_nn              all_features
# 13       conv_nn             diff_features
# 14       conv_nn               w5_features
# 15       conv_nn              w10_features
# 16       conv_nn              all_features
# 17       conv_nn              all_features
# 18       conv_nn              w15_features
# 19       conv_nn              all_features
# 20       conv_nn              w10_features
# 21       conv_nn               w5_features
# 22       conv_nn               w5_features
# 23           mlp               w5_features
# 24       conv_nn             diff_features
# 25    raw_signal                   Ax_diff
# 26       conv_nn              w15_features
# 27           mlp               w5_features
# 28    raw_signal      differencing_Ax_diff
# 29       conv_nn              w15_features
# 30       conv_nn              w15_features
# 31       conv_nn              w20_features
# 32       conv_nn              w20_features
# 33           mlp               w5_features
# 34       conv_nn          no_diff_features
# 35       conv_nn              w10_features
# 36       conv_nn              w20_features
# 37           mlp              all_features
# 38           mlp              w10_features
# 39       conv_nn              w20_features
# 40       conv_nn             diff_features
# 41       conv_nn               w5_features
# 42           gru               w5_features
# 43       conv_nn             diff_features
# 44           gru               w5_features
# 45       conv_nn              w10_features
# 46       conv_nn             diff_features
# 47           gru               w5_features
# 48        bilstm               w5_features
# 49          lstm               w5_features
# 50       conv_nn              w10_features
# 51        bilstm               w5_features
# 52           mlp             diff_features
# 53       conv_nn              w15_features
# 54           gru              all_features
# 55       conv_nn              w20_features
# 56       conv_nn              w10_features
# 57       conv_nn              w15_features
# 58           gru              w10_features
# 59       conv_nn          no_diff_features
# 60       conv_nn              w10_features
# 61       conv_nn             diff_features
# 62       conv_nn              w20_features
# 63       conv_nn              w15_features
# 64           gru              all_features
# 65       conv_nn              all_features
# 66          lstm               w5_features
# 67       conv_nn              all_features
# 68       conv_nn               w5_features
# 69          lstm               w5_features
# 70           mlp             diff_features
# 71          lstm               w5_features
# 72        bilstm             diff_features
# 73       conv_nn              w15_features
# 74           gru              w10_features
# 75           mlp             diff_features
# 76           mlp             diff_features
# 77           gru              w10_features
# 78       conv_nn              w10_features
# 79       conv_nn          no_diff_features
# 80       conv_nn              w15_features
# 81          lstm              all_features
# 82       conv_nn              all_features
# 83        bilstm             diff_features
# 84          lstm              w10_features
# 85          lstm              w15_features
# 86           gru              w20_features
# 87        bilstm               w5_features
# 88       conv_nn              w20_features
# 89        bilstm               w5_features
# 90        bilstm             diff_features
# 91        bilstm             diff_features
# 92        bilstm              w10_features
# 93          lstm              w10_features
# 94           gru              w15_features
# 95       conv_nn             diff_features
# 96       conv_nn             diff_features
# 97          lstm              w10_features
# 98           mlp               w5_features
# 99        bilstm              all_features
# 100          gru              w15_features
# 101          mlp              w15_features
# 102          gru          no_diff_features
# 103         lstm              all_features
# 104          gru              w20_features
# 105         lstm             diff_features
# 106       bilstm              w10_features
# 107          gru              w10_features
# 108          mlp              w20_features
# 109      conv_nn              w20_features
# 110          gru              all_features
# 111       bilstm              w10_features
# 112          gru          no_diff_features
# 113          gru              w15_features
# 114         lstm              w20_features
# 115      conv_nn          no_diff_features
# 116      conv_nn              w20_features
# 117         lstm              all_features
# 118      conv_nn          no_diff_features
# 119          mlp              w10_features
# 120      conv_nn          no_diff_features
# 121          gru              all_features
# 122          gru          no_diff_features
# 123      conv_nn              w15_features
# 124          mlp              w10_features
# 125      conv_nn              w20_features
# 126         lstm              w15_features
# 127       bilstm              all_features
# 128         lstm              w10_features
# 129      conv_nn          no_diff_features
# 130         lstm          no_diff_features
# 131      conv_nn              all_features
# 132         lstm              w20_features
# 133          gru              w20_features
# 134       bilstm              all_features
# 135          mlp          no_diff_features
# 136          mlp          no_diff_features
# 137          mlp              w10_features
# 138         lstm              w20_features
# 139         lstm              w15_features
# 140      conv_nn          no_diff_features
# 141       bilstm              w15_features
# 142      conv_nn              all_features
# 143      conv_nn              w15_features
# 144       bilstm          no_diff_features
# 145         lstm              w15_features
# 146         lstm              all_features
# 147      conv_nn          no_diff_features
# 148      conv_nn              all_features
# 149      conv_nn          no_diff_features
# 150          mlp              w20_features
# 151      conv_nn              all_features
# 152      conv_nn              w20_features
# 153          mlp              w20_features
# 154       bilstm              w20_features
# 155       bilstm              w20_features
# 156       bilstm          no_diff_features
# 157          mlp              w15_features
# 158          mlp              all_features
# 159          mlp              all_features
# 160          mlp              all_features
# 161       bilstm              w20_features
# 162       bilstm              w10_features
# 163          mlp              w15_features
# 164       bilstm          no_diff_features
# 165   raw_signal                Ax_std_w15
# 166       bilstm              w15_features
# 167          mlp          no_diff_features
# 168      conv_nn          no_diff_features
# 169       bilstm              w15_features
# 170       bilstm              w15_features
# 171          mlp          no_diff_features
# 172          mlp              w15_features
# 173   raw_signal                Ax_std_w10
# 174          mlp              w20_features
# 175          gru          no_diff_features
# 176       bilstm              all_features
# 177         lstm          no_diff_features
# 178       bilstm              w20_features
# 179         lstm          no_diff_features
# 180         lstm          no_diff_features
# 181       bilstm          no_diff_features
# 182          gru              w15_features
# 183         lstm              w20_features
# 184          gru             diff_features
# 185   raw_signal                 Ax_min_w5
# 186         lstm             diff_features
# 187   raw_signal    differencing_Ax_std_w5
# 188          gru              w20_features
# 189         lstm             diff_features
# 190   raw_signal   differencing_Ax_std_w15
# 191   raw_signal                 Ax_std_w5
# 192   raw_signal   differencing_Ax_std_w10
# 193          gru               w5_features
# 194         lstm             diff_features
# 195   raw_signal                Ax_std_w20
# 196   raw_signal   differencing_Ax_std_w20
# 197   raw_signal                Ax_min_w10
# 198   raw_signal                Ax_min_w15
# 199   raw_signal                Ax_max_w10
# 200          gru             diff_features
# 201   raw_signal                Ax_min_w20
# 202          gru             diff_features
# 203          gru             diff_features
# 204  autoencoder               w5_features
# 205   raw_signal                Ax_max_w15
# 206   raw_signal                Ax_max_w20
# 207   raw_signal                Ax_mean_w5
# 208   raw_signal                 Ax_max_w5
# 209   raw_signal           differencing_Ax
# 210   raw_signal   differencing_Ax_min_w10
# 211   raw_signal                        Ax
# 212  autoencoder               w5_features
# 213  autoencoder              w10_features
# 214   raw_signal   differencing_Ax_min_w15
# 215  autoencoder              w10_features
# 216   raw_signal   differencing_Ax_min_w20
# 217   raw_signal    differencing_Ax_max_w5
# 218   raw_signal   differencing_Ax_max_w15
# 219   raw_signal   differencing_Ax_max_w20
# 220  autoencoder               w5_features
# 221   raw_signal  differencing_Ax_mean_w10
# 222   raw_signal  differencing_Ax_mean_w15
# 223   raw_signal   differencing_Ax_mean_w5
# 224   raw_signal    differencing_Ax_min_w5
# 225   raw_signal   differencing_Ax_max_w10
# 226  autoencoder              all_features
# 227   raw_signal  differencing_Ax_mean_w20
# 228   raw_signal               Ax_mean_w10
# 229  autoencoder             diff_features
# 230  autoencoder              w20_features
# 231  autoencoder              w20_features
# 232  autoencoder              w20_features
# 233  autoencoder              w15_features
# 234  autoencoder              w15_features
# 235  autoencoder              w15_features
# 236  autoencoder              all_features
# 237  autoencoder              w10_features
# 238  autoencoder          no_diff_features
# 239  autoencoder          no_diff_features
# 240  autoencoder             diff_features
# 241   raw_signal               Ax_mean_w15
# 242   raw_signal               Ax_mean_w20
# 243  autoencoder             diff_features
# 244  autoencoder          no_diff_features
# 245  autoencoder              all_features
#
#                                                                      params  \
# 0              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 1             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 2              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 3              {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 4              {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 5             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 6             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 7              {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 8              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 9             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 10            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 11            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 12            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 13             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 14         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 15             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 16             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 17             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 18            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 19            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 20             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 21            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 22            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 23                                                 {'hidden_mlp': [64, 32]}
# 24             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 25                                                                       {}
# 26            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 27                                            {'hidden_mlp': [128, 64, 32]}
# 28                                                                       {}
# 29             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 30             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 31             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 32             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 33                                                     {'hidden_mlp': [32]}
# 34             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 35   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 36             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 37                                                       {'hidden_mlp': []}
# 38                                                       {'hidden_mlp': []}
# 39            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 40            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 41   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 42                                           {'time_steps': 5, 'units': 64}
# 43         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 44                                          {'time_steps': 5, 'units': 128}
# 45             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 46   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 47                                         {'time_steps': 10, 'units': 128}
# 48                                         {'time_steps': 10, 'units': 128}
# 49                                          {'time_steps': 5, 'units': 128}
# 50            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 51                                          {'time_steps': 10, 'units': 64}
# 52                                                       {'hidden_mlp': []}
# 53             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 54                                          {'time_steps': 5, 'units': 128}
# 55            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 56        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 57             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 58                                          {'time_steps': 5, 'units': 128}
# 59             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 60            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 61        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 62            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 63   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 64                                          {'time_steps': 10, 'units': 64}
# 65             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 66                                           {'time_steps': 5, 'units': 64}
# 67        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 68        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 69                                          {'time_steps': 10, 'units': 64}
# 70                                            {'hidden_mlp': [128, 64, 32]}
# 71                                         {'time_steps': 10, 'units': 128}
# 72                                         {'time_steps': 10, 'units': 128}
# 73            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 74                                          {'time_steps': 10, 'units': 64}
# 75                                                 {'hidden_mlp': [64, 32]}
# 76                                                     {'hidden_mlp': [32]}
# 77                                           {'time_steps': 5, 'units': 64}
# 78         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 79            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 80         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 81                                          {'time_steps': 5, 'units': 128}
# 82            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 83                                           {'time_steps': 5, 'units': 64}
# 84                                           {'time_steps': 5, 'units': 64}
# 85                                          {'time_steps': 5, 'units': 128}
# 86                                          {'time_steps': 10, 'units': 64}
# 87                                           {'time_steps': 5, 'units': 64}
# 88            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 89                                          {'time_steps': 5, 'units': 128}
# 90                                          {'time_steps': 5, 'units': 128}
# 91                                          {'time_steps': 10, 'units': 64}
# 92                                         {'time_steps': 10, 'units': 128}
# 93                                         {'time_steps': 10, 'units': 128}
# 94                                          {'time_steps': 10, 'units': 64}
# 95            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 96             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 97                                          {'time_steps': 5, 'units': 128}
# 98                                                       {'hidden_mlp': []}
# 99                                          {'time_steps': 10, 'units': 64}
# 100                                        {'time_steps': 10, 'units': 128}
# 101                                                      {'hidden_mlp': []}
# 102                                         {'time_steps': 5, 'units': 128}
# 103                                          {'time_steps': 5, 'units': 64}
# 104                                         {'time_steps': 5, 'units': 128}
# 105                                         {'time_steps': 5, 'units': 128}
# 106                                          {'time_steps': 5, 'units': 64}
# 107                                        {'time_steps': 10, 'units': 128}
# 108                                                      {'hidden_mlp': []}
# 109            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 110                                        {'time_steps': 10, 'units': 128}
# 111                                         {'time_steps': 10, 'units': 64}
# 112                                         {'time_steps': 10, 'units': 64}
# 113                                         {'time_steps': 5, 'units': 128}
# 114                                         {'time_steps': 5, 'units': 128}
# 115        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 116        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 117                                        {'time_steps': 10, 'units': 128}
# 118            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 119                                           {'hidden_mlp': [128, 64, 32]}
# 120           {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 121                                          {'time_steps': 5, 'units': 64}
# 122                                        {'time_steps': 10, 'units': 128}
# 123       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 124                                                {'hidden_mlp': [64, 32]}
# 125  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 126                                          {'time_steps': 5, 'units': 64}
# 127                                        {'time_steps': 10, 'units': 128}
# 128                                         {'time_steps': 10, 'units': 64}
# 129            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 130                                        {'time_steps': 10, 'units': 128}
# 131        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 132                                         {'time_steps': 10, 'units': 64}
# 133                                          {'time_steps': 5, 'units': 64}
# 134                                         {'time_steps': 5, 'units': 128}
# 135                                           {'hidden_mlp': [128, 64, 32]}
# 136                                                      {'hidden_mlp': []}
# 137                                                    {'hidden_mlp': [32]}
# 138                                          {'time_steps': 5, 'units': 64}
# 139                                        {'time_steps': 10, 'units': 128}
# 140       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 141                                        {'time_steps': 10, 'units': 128}
# 142  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 143           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 144                                         {'time_steps': 5, 'units': 128}
# 145                                         {'time_steps': 10, 'units': 64}
# 146                                         {'time_steps': 10, 'units': 64}
# 147  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 148            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 149           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 150                                           {'hidden_mlp': [128, 64, 32]}
# 151           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 152       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 153                                                {'hidden_mlp': [64, 32]}
# 154                                         {'time_steps': 5, 'units': 128}
# 155                                          {'time_steps': 5, 'units': 64}
# 156                                         {'time_steps': 10, 'units': 64}
# 157                                                    {'hidden_mlp': [32]}
# 158                                           {'hidden_mlp': [128, 64, 32]}
# 159                                                    {'hidden_mlp': [32]}
# 160                                                {'hidden_mlp': [64, 32]}
# 161                                         {'time_steps': 10, 'units': 64}
# 162                                         {'time_steps': 5, 'units': 128}
# 163                                                {'hidden_mlp': [64, 32]}
# 164                                          {'time_steps': 5, 'units': 64}
# 165                                                                      {}
# 166                                          {'time_steps': 5, 'units': 64}
# 167                                                    {'hidden_mlp': [32]}
# 168           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 169                                         {'time_steps': 5, 'units': 128}
# 170                                         {'time_steps': 10, 'units': 64}
# 171                                                {'hidden_mlp': [64, 32]}
# 172                                           {'hidden_mlp': [128, 64, 32]}
# 173                                                                      {}
# 174                                                    {'hidden_mlp': [32]}
# 175                                          {'time_steps': 5, 'units': 64}
# 176                                          {'time_steps': 5, 'units': 64}
# 177                                         {'time_steps': 10, 'units': 64}
# 178                                        {'time_steps': 10, 'units': 128}
# 179                                         {'time_steps': 5, 'units': 128}
# 180                                          {'time_steps': 5, 'units': 64}
# 181                                        {'time_steps': 10, 'units': 128}
# 182                                          {'time_steps': 5, 'units': 64}
# 183                                        {'time_steps': 10, 'units': 128}
# 184                                          {'time_steps': 5, 'units': 64}
# 185                                                                      {}
# 186                                         {'time_steps': 10, 'units': 64}
# 187                                                                      {}
# 188                                        {'time_steps': 10, 'units': 128}
# 189                                          {'time_steps': 5, 'units': 64}
# 190                                                                      {}
# 191                                                                      {}
# 192                                                                      {}
# 193                                         {'time_steps': 10, 'units': 64}
# 194                                        {'time_steps': 10, 'units': 128}
# 195                                                                      {}
# 196                                                                      {}
# 197                                                                      {}
# 198                                                                      {}
# 199                                                                      {}
# 200                                        {'time_steps': 10, 'units': 128}
# 201                                                                      {}
# 202                                         {'time_steps': 10, 'units': 64}
# 203                                         {'time_steps': 5, 'units': 128}
# 204                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 205                                                                      {}
# 206                                                                      {}
# 207                                                                      {}
# 208                                                                      {}
# 209                                                                      {}
# 210                                                                      {}
# 211                                                                      {}
# 212                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 213                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 214                                                                      {}
# 215                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 216                                                                      {}
# 217                                                                      {}
# 218                                                                      {}
# 219                                                                      {}
# 220                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 221                                                                      {}
# 222                                                                      {}
# 223                                                                      {}
# 224                                                                      {}
# 225                                                                      {}
# 226                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 227                                                                      {}
# 228                                                                      {}
# 229                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 230                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 231                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 232                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 233                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 234                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 235                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 236                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 237                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 238                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 239                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 240                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 241                                                                      {}
# 242                                                                      {}
# 243                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 244                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 245                                   {'hidden_ae': [128, 56, 18, 56, 128]}
#
#        cost  anticipation  detected_faults  missed_faults  false_alarms
# 0      1.00          1.39            13.00           0.00          0.00
# 1      3.67          1.38            13.00           0.00          0.00
# 2      4.00          1.37            13.00           0.00          0.00
# 3      4.33          1.40            13.00           0.00         21.67
# 4      5.00          1.38            13.00           0.00         11.67
# 5      6.00          1.38            13.00           0.00         11.67
# 6      6.20          1.36            13.00           0.00          4.33
# 7     19.80          1.32            13.00           0.00          2.33
# 8     37.07          1.26            13.00           0.00         12.00
# 9     42.27          1.40            13.00           0.00        211.33
# 10    89.67          1.28            12.67           0.33          0.00
# 11    99.67          1.22            13.00           0.00          0.00
# 12   114.67          1.10            13.00           0.00          0.00
# 13   241.27          1.40            13.00           0.00       1206.33
# 14   260.67          0.87            13.00           0.00          0.00
# 15   276.33          1.07            12.33           0.67          0.00
# 16   276.33          0.96            12.67           0.33          0.00
# 17   323.33          1.01            12.33           0.67          0.00
# 18   380.67          1.01            11.33           1.67          0.00
# 19   389.07          0.88            11.67           1.33          5.33
# 20   397.20          1.00            11.67           1.33        212.67
# 21   399.53          0.94            12.67           0.33        277.67
# 22   405.60          0.97            12.33           0.67        541.33
# 23   406.07          0.89            13.00           0.00        415.33
# 24   437.53          1.03            11.00           2.00        151.00
# 25   448.20          1.07            13.00           0.00       1641.00
# 26   487.33          0.97             9.67           3.33          0.00
# 27   491.80          0.92            13.00           0.00       1010.67
# 28   494.60          0.95            13.00           0.00       1438.00
# 29   510.33          0.97             9.00           4.00          0.00
# 30   512.80          0.95            10.33           2.67        174.00
# 31   520.00          0.93             8.67           4.33          0.00
# 32   550.33          0.80             8.67           4.33          0.00
# 33   586.53          0.61            13.00           0.00        147.67
# 34   600.33          0.69             8.67           4.33          0.00
# 35   601.00          0.56            12.67           0.33         15.00
# 36   620.20          0.93             8.67           4.33        501.00
# 37   692.27          0.44            13.00           0.00         18.00
# 38   698.27          0.66            13.00           0.00       1071.33
# 39   705.67          0.70             8.33           4.67          0.00
# 40   728.47          0.85             8.67           4.33        887.33
# 41   737.73          0.75             8.67           4.33        607.00
# 42   880.47          0.64            10.00           3.00        825.67
# 43   890.80          0.69            10.00           3.00       1290.67
# 44   898.27          1.02            13.00           0.00       3426.33
# 45   941.00          0.55             7.67           5.33        351.67
# 46   952.13          0.59             9.67           3.33        824.00
# 47   957.40          1.05            13.00           0.00       3735.33
# 48   962.07          0.65            13.00           0.00       1815.33
# 49   984.13          0.45            10.67           2.33        562.33
# 50   986.93          0.72             9.33           3.67       1408.00
# 51  1005.33          0.45            12.33           0.67       1175.00
# 52  1014.53          0.63            13.00           0.00       2461.00
# 53  1014.67          0.47             5.33           7.67          0.00
# 54  1037.33          0.59            11.67           1.33       1596.67
# 55  1040.00          0.47             4.33           8.67          0.00
# 56  1047.53          0.44             4.33           8.67          6.00
# 57  1050.33          0.41             4.33           8.67          0.00
# 58  1050.53          0.24            11.67           1.33         89.33
# 59  1053.33          0.40             4.33           8.67          0.00
# 60  1062.33          0.50             6.33           6.67        431.67
# 61  1062.40          0.89             9.67           3.33       2532.00
