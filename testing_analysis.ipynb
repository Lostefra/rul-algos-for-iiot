# %% [markdown]
# # Testing analysis

# %%
# Prediction margin: the only parameter to set. Recommended: margin in {5, 10, 15, 20} (aka 0.5, 1, 1.5, 2 seconds)
margin = 20

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_res = pd.read_csv("summaries/testing_summary_" + str(margin) + ".csv", index_col=[0])
df_res_sorted = df_res.sort_values(by=['cost'])
df_res_sorted = df_res_sorted.reset_index(drop=True)
df_res_sorted['#'] = df_res_sorted.index
print("There are", len(df_res_sorted), "models for margin =", margin)
df_res_sorted.head(50)
# Out:
# There are 738 models for margin = 20
#       model  seed        columns  \
# 0   conv_nn   300   w15_features
# 1   conv_nn   300  diff_features
# 2   conv_nn   300  diff_features
# 3   conv_nn   300   w15_features
# 4   conv_nn   300   w15_features
# 5   conv_nn   300   w10_features
# 6   conv_nn   300   w10_features
# 7   conv_nn   300    w5_features
# 8   conv_nn   200   w15_features
# 9   conv_nn   200   w10_features
# 10  conv_nn   100  diff_features
# 11  conv_nn   100  diff_features
# 12  conv_nn   100  diff_features
# 13  conv_nn   100  diff_features
# 14  conv_nn   100   w20_features
# 15  conv_nn   100   w15_features
# 16  conv_nn   100  diff_features
# 17  conv_nn   300  diff_features
# 18  conv_nn   100   w10_features
# 19  conv_nn   100   w15_features
# 20  conv_nn   100   w10_features
# 21  conv_nn   100   w10_features
# 22  conv_nn   100   w10_features
# 23  conv_nn   300    w5_features
# 24  conv_nn   100  diff_features
# 25  conv_nn   300   w10_features
# 26  conv_nn   100    w5_features
# 27  conv_nn   100    w5_features
# 28  conv_nn   300   all_features
# 29  conv_nn   200   w10_features
# 30  conv_nn   300  diff_features
# 31  conv_nn   200   w20_features
# 32  conv_nn   200  diff_features
# 33  conv_nn   100   w15_features
# 34  conv_nn   100    w5_features
# 35  conv_nn   300   w20_features
# 36  conv_nn   100   w15_features
# 37  conv_nn   100   all_features
# 38  conv_nn   300   all_features
# 39  conv_nn   200    w5_features
# 40  conv_nn   200    w5_features
# 41  conv_nn   300   w10_features
# 42  conv_nn   100   all_features
# 43  conv_nn   100   w10_features
# 44  conv_nn   200  diff_features
# 45  conv_nn   100   w20_features
# 46  conv_nn   300   w20_features
# 47  conv_nn   300   w10_features
# 48  conv_nn   100    w5_features
# 49  conv_nn   100   w20_features
#
#                                                               params  \
# 0       {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 1       {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 2       {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 3      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 4      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 5      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 6       {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 7      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 8       {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 9      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 10     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 11      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 12      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 13      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 14      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 15     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 16     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 17     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 18     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 19      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 20      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 21      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 22     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 23      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 24      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 25     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 26      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 27      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 28      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 29     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 30      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 31      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 32     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 33     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 34     {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 35     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 36      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 37     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 38     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 39      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 40      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 41      {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 42      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 43  {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 44      {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 45     {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 46      {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 47      {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 48     {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 49     {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
#
#     params_idx  cost  anticipation  detected_faults  missed_faults  \
# 0            0  0.00          1.90               13              0
# 1            2  0.00          1.90               13              0
# 2            0  0.00          1.90               13              0
# 3            7  0.00          1.90               13              0
# 4            5  0.00          1.90               13              0
# 5            5  0.00          1.90               13              0
# 6            0  0.00          1.90               13              0
# 7            5  0.00          1.90               13              0
# 8            1  0.00          1.90               13              0
# 9            7  0.00          1.90               13              0
# 10           5  0.00          1.90               13              0
# 11           3  0.00          1.90               13              0
# 12           2  0.00          1.90               13              0
# 13           0  0.00          1.90               13              0
# 14           0  0.00          1.90               13              0
# 15           5  0.00          1.90               13              0
# 16           7  0.00          1.90               13              0
# 17           5  0.00          1.90               13              0
# 18           7  0.00          1.90               13              0
# 19           0  0.00          1.90               13              0
# 20           0  0.00          1.90               13              0
# 21           2  0.00          1.90               13              0
# 22           5  0.00          1.90               13              0
# 23           0  0.20          1.90               13              0
# 24           1  0.20          1.90               13              0
# 25           7  0.20          1.90               13              0
# 26           2  0.40          1.90               13              0
# 27           0  0.80          1.90               13              0
# 28           0  1.00          1.89               13              0
# 29           5  1.00          1.89               13              0
# 30           3  3.00          1.88               13              0
# 31           3  6.00          1.85               13              0
# 32           7  8.00          1.85               13              0
# 33           7 11.00          1.82               13              0
# 34           6 11.40          1.85               13              0
# 35           5 12.00          1.81               13              0
# 36           2 12.00          1.81               13              0
# 37           5 12.00          1.81               13              0
# 38           5 13.00          1.80               13              0
# 39           0 17.60          1.89               13              0
# 40           1 18.00          1.85               13              0
# 41           2 18.00          1.80               13              0
# 42           0 19.00          1.78               13              0
# 43           4 24.00          1.78               13              0
# 44           3 24.00          1.76               13              0
# 45           5 27.00          1.75               13              0
# 46           0 27.00          1.75               13              0
# 47           1 30.80          1.78               13              0
# 48           8 30.80          1.74               13              0
# 49           7 31.00          1.73               13              0
#
#     false_alarms   #
# 0              0   0
# 1              0   1
# 2              0   2
# 3              0   3
# 4              0   4
# 5              0   5
# 6              0   6
# 7              0   7
# 8              0   8
# 9              0   9
# 10             0  10
# 11             0  11
# 12             0  12
# 13             0  13
# 14             0  14
# 15             0  15
# 16             0  16
# 17             0  17
# 18             0  18
# 19             0  19
# 20             0  20
# 21             0  21
# 22             0  22
# 23             1  23
# 24             1  24
# 25             1  25
# 26             2  26
# 27             4  27
# 28             0  28
# 29             0  29
# 30             0  30
# 31             0  31
# 32             0  32
# 33             0  33
# 34            27  34
# 35             0  35
# 36             0  36
# 37             0  37
# 38             0  38
# 39            83  39
# 40            60  40
# 41             0  41
# 42             0  42
# 43             0  43
# 44             0  44
# 45             0  45
# 46             0  46
# 47             4  47
# 48             4  48
# 49             0  49

# %% [markdown]
# ## Check performance of a given model for all seeds

# %%
model = "conv_nn"
columns = "w15_features"
params_idx = 0

df_res_sorted[(df_res_sorted["model"] == model) & (df_res_sorted["columns"] == columns) & (df_res_sorted["params_idx"] == params_idx)]
# Out:
#        model  seed       columns  \
# 0    conv_nn   300  w15_features
# 19   conv_nn   100  w15_features
# 304  conv_nn   200  w15_features
#
#                                                            params  params_idx  \
# 0    {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 19   {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
# 304  {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}           0
#
#        cost  anticipation  detected_faults  missed_faults  false_alarms    #
# 0      0.00          1.90               13              0             0    0
# 19     0.00          1.90               13              0             0   19
# 304 2595.00          0.13                3             10             0  304

# %% [markdown]
# ## Average performance of models

# %%
df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
# <ipython-input-37-852b8f186669>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_res_sorted.groupby(by=["model"]).mean().sort_values(by=["cost"]).reset_index()[["model", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
#          model    cost  anticipation  detected_faults  missed_faults  \
# 0      conv_nn 1375.06          0.92             7.76           5.24
# 1          gru 2244.31          0.48             7.25           5.75
# 2          mlp 2363.44          0.23             3.67           9.33
# 3         lstm 2411.95          0.28             4.67           8.33
# 4   raw_signal 2512.58          1.82            11.28           1.72
# 5       bilstm 2576.15          0.09             2.56          10.44
# 6  autoencoder 2732.80          1.90            13.00           0.00
#
#    false_alarms
# 0        302.64
# 1       1925.94
# 2        352.89
# 3        911.44
# 4      10570.67
# 5        166.01
# 6      13663.98

# %% [markdown]
# ## Average performance of models with same hyperparameters and features

# %%
df_res_sorted.groupby(by=["model", "columns", "params"]).mean().sort_values(by=["cost"]).reset_index()[["model", "columns", "params", "cost", "anticipation", "detected_faults", "missed_faults", "false_alarms"]]
# Out:
#            model                   columns  \
# 0        conv_nn              w10_features
# 1        conv_nn              w10_features
# 2        conv_nn               w5_features
# 3        conv_nn             diff_features
# 4        conv_nn              all_features
# 5        conv_nn              w10_features
# 6        conv_nn               w5_features
# 7        conv_nn              all_features
# 8        conv_nn             diff_features
# 9        conv_nn              w20_features
# 10       conv_nn               w5_features
# 11       conv_nn             diff_features
# 12       conv_nn               w5_features
# 13       conv_nn               w5_features
# 14       conv_nn               w5_features
# 15       conv_nn             diff_features
# 16       conv_nn             diff_features
# 17       conv_nn             diff_features
# 18    raw_signal      differencing_Ax_diff
# 19    raw_signal                   Ax_diff
# 20       conv_nn               w5_features
# 21       conv_nn              all_features
# 22       conv_nn             diff_features
# 23       conv_nn              w10_features
# 24       conv_nn               w5_features
# 25       conv_nn             diff_features
# 26       conv_nn              all_features
# 27       conv_nn              w15_features
# 28       conv_nn              w15_features
# 29       conv_nn              w10_features
# 30           mlp              w10_features
# 31       conv_nn               w5_features
# 32       conv_nn              w15_features
# 33       conv_nn              w10_features
# 34       conv_nn              w20_features
# 35       conv_nn              w20_features
# 36       conv_nn              w20_features
# 37       conv_nn              w10_features
# 38       conv_nn              w20_features
# 39           mlp               w5_features
# 40           mlp               w5_features
# 41       conv_nn              w15_features
# 42       conv_nn             diff_features
# 43           mlp               w5_features
# 44       conv_nn              w10_features
# 45       conv_nn              w15_features
# 46       conv_nn               w5_features
# 47           mlp               w5_features
# 48       conv_nn              w15_features
# 49           gru               w5_features
# 50    raw_signal                Ax_std_w20
# 51           gru               w5_features
# 52           gru             diff_features
# 53          lstm               w5_features
# 54          lstm             diff_features
# 55       conv_nn             diff_features
# 56           gru               w5_features
# 57       conv_nn             diff_features
# 58           gru               w5_features
# 59       conv_nn               w5_features
# 60          lstm               w5_features
# 61           mlp             diff_features
# 62           gru              w10_features
# 63       conv_nn              all_features
# 64       conv_nn              all_features
# 65          lstm               w5_features
# 66    raw_signal                 Ax_std_w5
# 67        bilstm               w5_features
# 68       conv_nn          no_diff_features
# 69       conv_nn              w20_features
# 70       conv_nn          no_diff_features
# 71       conv_nn          no_diff_features
# 72           gru              all_features
# 73       conv_nn          no_diff_features
# 74           gru              w10_features
# 75    raw_signal                Ax_std_w15
# 76       conv_nn              w10_features
# 77       conv_nn              w20_features
# 78           gru             diff_features
# 79       conv_nn              all_features
# 80       conv_nn          no_diff_features
# 81       conv_nn              w15_features
# 82           gru              w20_features
# 83        bilstm             diff_features
# 84          lstm              all_features
# 85          lstm               w5_features
# 86       conv_nn          no_diff_features
# 87           gru              w20_features
# 88          lstm              w10_features
# 89          lstm             diff_features
# 90           gru             diff_features
# 91    raw_signal                Ax_min_w10
# 92          lstm             diff_features
# 93           mlp              all_features
# 94          lstm              all_features
# 95        bilstm               w5_features
# 96        bilstm             diff_features
# 97           gru              w15_features
# 98          lstm              w20_features
# 99           gru              w20_features
# 100   raw_signal                Ax_min_w15
# 101          gru              all_features
# 102          gru              w15_features
# 103       bilstm             diff_features
# 104       bilstm               w5_features
# 105      conv_nn              w15_features
# 106          gru              w10_features
# 107   raw_signal    differencing_Ax_std_w5
# 108         lstm             diff_features
# 109         lstm              w10_features
# 110       bilstm              all_features
# 111          mlp             diff_features
# 112       bilstm              w10_features
# 113      conv_nn              all_features
# 114   raw_signal                Ax_min_w20
# 115          gru             diff_features
# 116       bilstm              all_features
# 117          gru          no_diff_features
# 118          mlp              w15_features
# 119       bilstm               w5_features
# 120      conv_nn              w15_features
# 121       bilstm              w20_features
# 122      conv_nn              w15_features
# 123          gru              all_features
# 124       bilstm             diff_features
# 125         lstm              w10_features
# 126          mlp             diff_features
# 127          mlp              w10_features
# 128         lstm              w20_features
# 129          mlp              w10_features
# 130      conv_nn              w10_features
# 131          gru              w10_features
# 132         lstm              w15_features
# 133       bilstm              all_features
# 134          gru              w15_features
# 135         lstm              w15_features
# 136      conv_nn              w20_features
# 137   raw_signal                Ax_max_w10
# 138          gru          no_diff_features
# 139      conv_nn              w20_features
# 140      conv_nn              w20_features
# 141      conv_nn          no_diff_features
# 142   raw_signal                Ax_max_w20
# 143   raw_signal                Ax_max_w15
# 144         lstm          no_diff_features
# 145       bilstm              w20_features
# 146          gru              all_features
# 147          mlp              all_features
# 148         lstm              w10_features
# 149  autoencoder               w5_features
# 150   raw_signal           differencing_Ax
# 151      conv_nn          no_diff_features
# 152      conv_nn              w10_features
# 153   raw_signal                        Ax
# 154  autoencoder              w10_features
# 155         lstm              w15_features
# 156      conv_nn              w15_features
# 157         lstm              w20_features
# 158          mlp              all_features
# 159          mlp              w20_features
# 160          mlp              w15_features
# 161          mlp              w15_features
# 162      conv_nn              w20_features
# 163          mlp              w20_features
# 164          mlp              w20_features
# 165          mlp          no_diff_features
# 166          mlp          no_diff_features
# 167          mlp          no_diff_features
# 168          mlp          no_diff_features
# 169          mlp              w10_features
# 170          mlp              w15_features
# 171          mlp              w20_features
# 172          mlp              all_features
# 173          mlp             diff_features
# 174      conv_nn              all_features
# 175       bilstm              w15_features
# 176       bilstm              w15_features
# 177       bilstm              w15_features
# 178      conv_nn              all_features
# 179       bilstm              w10_features
# 180       bilstm              w10_features
# 181          gru              w20_features
# 182       bilstm              w10_features
# 183       bilstm          no_diff_features
# 184       bilstm          no_diff_features
# 185       bilstm          no_diff_features
# 186          gru          no_diff_features
# 187       bilstm              w20_features
# 188       bilstm          no_diff_features
# 189         lstm              all_features
# 190      conv_nn          no_diff_features
# 191      conv_nn              all_features
# 192         lstm          no_diff_features
# 193      conv_nn          no_diff_features
# 194         lstm          no_diff_features
# 195      conv_nn          no_diff_features
# 196       bilstm              all_features
# 197       bilstm              w20_features
# 198         lstm              all_features
# 199       bilstm              w15_features
# 200          gru              w15_features
# 201   raw_signal    differencing_Ax_max_w5
# 202   raw_signal                 Ax_max_w5
# 203   raw_signal   differencing_Ax_max_w20
# 204  autoencoder               w5_features
# 205  autoencoder             diff_features
# 206  autoencoder              all_features
# 207  autoencoder              all_features
# 208  autoencoder             diff_features
# 209   raw_signal   differencing_Ax_max_w10
# 210  autoencoder               w5_features
# 211   raw_signal                 Ax_min_w5
# 212   raw_signal  differencing_Ax_mean_w15
# 213   raw_signal  differencing_Ax_mean_w20
# 214   raw_signal   differencing_Ax_mean_w5
# 215   raw_signal   differencing_Ax_min_w10
# 216   raw_signal   differencing_Ax_min_w15
# 217   raw_signal   differencing_Ax_min_w20
# 218   raw_signal    differencing_Ax_min_w5
# 219   raw_signal   differencing_Ax_max_w15
# 220   raw_signal  differencing_Ax_mean_w10
# 221  autoencoder          no_diff_features
# 222  autoencoder          no_diff_features
# 223  autoencoder              w20_features
# 224  autoencoder              w20_features
# 225  autoencoder              w20_features
# 226  autoencoder              w15_features
# 227  autoencoder              w15_features
# 228  autoencoder              w15_features
# 229  autoencoder             diff_features
# 230  autoencoder              w10_features
# 231  autoencoder              w10_features
# 232  autoencoder          no_diff_features
# 233   raw_signal               Ax_mean_w10
# 234   raw_signal               Ax_mean_w15
# 235   raw_signal               Ax_mean_w20
# 236   raw_signal                Ax_mean_w5
# 237  autoencoder              all_features
# 238          gru          no_diff_features
# 239         lstm              w20_features
# 240         lstm          no_diff_features
# 241         lstm              w15_features
# 242   raw_signal   differencing_Ax_std_w20
# 243   raw_signal   differencing_Ax_std_w10
# 244   raw_signal   differencing_Ax_std_w15
# 245   raw_signal                Ax_std_w10
#
#                                                                      params  \
# 0             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 1             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 2              {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 3              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 4             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 5              {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 6             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 7             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 8              {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 9              {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 10             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 11            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 12             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 13             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 14            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 15            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 16            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 17             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 18                                                                       {}
# 19                                                                       {}
# 20            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 21             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 22        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 23             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 24   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 25             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 26             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 27            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 28             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 29            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 30                                                       {'hidden_mlp': []}
# 31         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 32            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 33             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 34             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 35            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 36            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 37         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 38             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 39                                            {'hidden_mlp': [128, 64, 32]}
# 40                                                       {'hidden_mlp': []}
# 41             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 42            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 43                                                 {'hidden_mlp': [64, 32]}
# 44            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 45             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 46            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 47                                                     {'hidden_mlp': [32]}
# 48             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 49                                          {'time_steps': 5, 'units': 128}
# 50                                                                       {}
# 51                                          {'time_steps': 10, 'units': 64}
# 52                                         {'time_steps': 10, 'units': 128}
# 53                                          {'time_steps': 10, 'units': 64}
# 54                                          {'time_steps': 10, 'units': 64}
# 55         {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 56                                         {'time_steps': 10, 'units': 128}
# 57   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 58                                           {'time_steps': 5, 'units': 64}
# 59        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 60                                           {'time_steps': 5, 'units': 64}
# 61                                                       {'hidden_mlp': []}
# 62                                          {'time_steps': 10, 'units': 64}
# 63             {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 64             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 65                                          {'time_steps': 5, 'units': 128}
# 66                                                                       {}
# 67                                          {'time_steps': 5, 'units': 128}
# 68             {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 69            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 70            {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 71             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 72                                         {'time_steps': 10, 'units': 128}
# 73             {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 74                                         {'time_steps': 10, 'units': 128}
# 75                                                                       {}
# 76   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 77             {'filters': 1, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 78                                          {'time_steps': 5, 'units': 128}
# 79            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 80            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 81   {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 82                                         {'time_steps': 10, 'units': 128}
# 83                                           {'time_steps': 5, 'units': 64}
# 84                                          {'time_steps': 5, 'units': 128}
# 85                                         {'time_steps': 10, 'units': 128}
# 86            {'filters': 1, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 87                                          {'time_steps': 10, 'units': 64}
# 88                                         {'time_steps': 10, 'units': 128}
# 89                                          {'time_steps': 5, 'units': 128}
# 90                                          {'time_steps': 10, 'units': 64}
# 91                                                                       {}
# 92                                           {'time_steps': 5, 'units': 64}
# 93                                                       {'hidden_mlp': []}
# 94                                         {'time_steps': 10, 'units': 128}
# 95                                          {'time_steps': 10, 'units': 64}
# 96                                         {'time_steps': 10, 'units': 128}
# 97                                         {'time_steps': 10, 'units': 128}
# 98                                         {'time_steps': 10, 'units': 128}
# 99                                           {'time_steps': 5, 'units': 64}
# 100                                                                      {}
# 101                                         {'time_steps': 5, 'units': 128}
# 102                                         {'time_steps': 10, 'units': 64}
# 103                                         {'time_steps': 5, 'units': 128}
# 104                                        {'time_steps': 10, 'units': 128}
# 105        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 106                                         {'time_steps': 5, 'units': 128}
# 107                                                                      {}
# 108                                        {'time_steps': 10, 'units': 128}
# 109                                         {'time_steps': 10, 'units': 64}
# 110                                        {'time_steps': 10, 'units': 128}
# 111                                           {'hidden_mlp': [128, 64, 32]}
# 112                                          {'time_steps': 5, 'units': 64}
# 113       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 114                                                                      {}
# 115                                          {'time_steps': 5, 'units': 64}
# 116                                          {'time_steps': 5, 'units': 64}
# 117                                        {'time_steps': 10, 'units': 128}
# 118                                                      {'hidden_mlp': []}
# 119                                          {'time_steps': 5, 'units': 64}
# 120           {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 10}
# 121                                         {'time_steps': 10, 'units': 64}
# 122           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 123                                          {'time_steps': 5, 'units': 64}
# 124                                         {'time_steps': 10, 'units': 64}
# 125                                         {'time_steps': 5, 'units': 128}
# 126                                                {'hidden_mlp': [64, 32]}
# 127                                                {'hidden_mlp': [64, 32]}
# 128                                         {'time_steps': 5, 'units': 128}
# 129                                           {'hidden_mlp': [128, 64, 32]}
# 130            {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 5}
# 131                                          {'time_steps': 5, 'units': 64}
# 132                                         {'time_steps': 10, 'units': 64}
# 133                                         {'time_steps': 10, 'units': 64}
# 134                                         {'time_steps': 5, 'units': 128}
# 135                                         {'time_steps': 5, 'units': 128}
# 136        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 137                                                                      {}
# 138                                         {'time_steps': 5, 'units': 128}
# 139           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 140       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 141        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 142                                                                      {}
# 143                                                                      {}
# 144                                        {'time_steps': 10, 'units': 128}
# 145                                          {'time_steps': 5, 'units': 64}
# 146                                         {'time_steps': 10, 'units': 64}
# 147                                                    {'hidden_mlp': [32]}
# 148                                          {'time_steps': 5, 'units': 64}
# 149                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 150                                                                      {}
# 151            {'filters': 4, 'kernel_size': 3, 'hidden': [32], 'w_len': 5}
# 152       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 153                                                                      {}
# 154                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 155                                          {'time_steps': 5, 'units': 64}
# 156       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 157                                          {'time_steps': 5, 'units': 64}
# 158                                           {'hidden_mlp': [128, 64, 32]}
# 159                                                      {'hidden_mlp': []}
# 160                                           {'hidden_mlp': [128, 64, 32]}
# 161                                                    {'hidden_mlp': [32]}
# 162  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 163                                                    {'hidden_mlp': [32]}
# 164                                           {'hidden_mlp': [128, 64, 32]}
# 165                                           {'hidden_mlp': [128, 64, 32]}
# 166                                                    {'hidden_mlp': [32]}
# 167                                                {'hidden_mlp': [64, 32]}
# 168                                                      {'hidden_mlp': []}
# 169                                                    {'hidden_mlp': [32]}
# 170                                                {'hidden_mlp': [64, 32]}
# 171                                                {'hidden_mlp': [64, 32]}
# 172                                                {'hidden_mlp': [64, 32]}
# 173                                                    {'hidden_mlp': [32]}
# 174           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 175                                         {'time_steps': 5, 'units': 128}
# 176                                         {'time_steps': 10, 'units': 64}
# 177                                        {'time_steps': 10, 'units': 128}
# 178  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 179                                         {'time_steps': 5, 'units': 128}
# 180                                         {'time_steps': 10, 'units': 64}
# 181                                         {'time_steps': 5, 'units': 128}
# 182                                        {'time_steps': 10, 'units': 128}
# 183                                          {'time_steps': 5, 'units': 64}
# 184                                         {'time_steps': 5, 'units': 128}
# 185                                         {'time_steps': 10, 'units': 64}
# 186                                          {'time_steps': 5, 'units': 64}
# 187                                         {'time_steps': 5, 'units': 128}
# 188                                        {'time_steps': 10, 'units': 128}
# 189                                          {'time_steps': 5, 'units': 64}
# 190       {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 10}
# 191        {'filters': 4, 'kernel_size': 5, 'hidden': [64, 32], 'w_len': 5}
# 192                                         {'time_steps': 5, 'units': 128}
# 193           {'filters': 4, 'kernel_size': 5, 'hidden': [32], 'w_len': 10}
# 194                                          {'time_steps': 5, 'units': 64}
# 195  {'filters': 4, 'kernel_size': 7, 'hidden': [128, 64, 32], 'w_len': 10}
# 196                                         {'time_steps': 5, 'units': 128}
# 197                                        {'time_steps': 10, 'units': 128}
# 198                                         {'time_steps': 10, 'units': 64}
# 199                                          {'time_steps': 5, 'units': 64}
# 200                                          {'time_steps': 5, 'units': 64}
# 201                                                                      {}
# 202                                                                      {}
# 203                                                                      {}
# 204                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 205                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 206                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 207                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 208                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 209                                                                      {}
# 210                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 211                                                                      {}
# 212                                                                      {}
# 213                                                                      {}
# 214                                                                      {}
# 215                                                                      {}
# 216                                                                      {}
# 217                                                                      {}
# 218                                                                      {}
# 219                                                                      {}
# 220                                                                      {}
# 221                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 222                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 223                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 224                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 225                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 226                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 227                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 228                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 229                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 230                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 231                                      {'hidden_ae': [64, 24, 9, 24, 64]}
# 232                                        {'hidden_ae': [16, 8, 2, 8, 16]}
# 233                                                                      {}
# 234                                                                      {}
# 235                                                                      {}
# 236                                                                      {}
# 237                                   {'hidden_ae': [128, 56, 18, 56, 128]}
# 238                                         {'time_steps': 10, 'units': 64}
# 239                                         {'time_steps': 10, 'units': 64}
# 240                                         {'time_steps': 10, 'units': 64}
# 241                                        {'time_steps': 10, 'units': 128}
# 242                                                                      {}
# 243                                                                      {}
# 244                                                                      {}
# 245                                                                      {}
#
#        cost  anticipation  detected_faults  missed_faults  false_alarms
# 0      0.07          1.90            13.00           0.00          0.33
# 1      0.33          1.90            13.00           0.00          0.00
# 2      6.20          1.90            13.00           0.00         29.33
# 3      9.00          1.85            13.00           0.00          0.00
# 4     47.33          1.68            13.00           0.00          0.00
# 5     63.67          1.74            13.00           0.00          0.00
# 6     69.80          1.90            13.00           0.00        347.33
# 7    121.33          1.64            13.00           0.00          0.00
# 8    123.53          1.84            13.00           0.00        541.00
# 9    141.67          1.63            13.00           0.00          0.00
# 10   221.60          1.76            13.00           0.00        751.33
# 11   242.73          1.59            13.00           0.00          0.33
# 12   279.20          1.90            13.00           0.00       1396.00
# 13   288.33          1.74            13.00           0.00       1056.67
# 14   294.73          1.90            13.00           0.00       1473.67
# 15   314.00          1.54            13.00           0.00          0.00
# 16   340.13          1.70            13.00           0.00       1337.33
# 17   344.33          1.53            13.00           0.00          0.00
# 18   464.20          1.64            13.00           0.00       1871.00
# 19   469.20          1.63            13.00           0.00       1861.00
# 20   494.60          1.48            12.67           0.33        573.00
# 21   565.00          1.38            12.67           0.33          0.00
# 22   580.73          1.46            12.67           0.33       1077.00
# 23   621.00          1.39            12.33           0.67          0.00
# 24   722.53          1.43            13.00           0.00       1741.00
# 25   808.00          1.32            10.67           2.33          0.00
# 26   834.67          1.13            11.33           1.67          0.00
# 27   838.00          1.52             9.33           3.67          0.00
# 28   865.00          1.31             9.67           3.33          0.00
# 29   886.20          1.06            12.00           1.00         61.00
# 30   887.00          1.04            13.00           0.00       1165.00
# 31   893.40          1.42            11.33           1.67       1182.00
# 32   910.00          1.27             8.67           4.33          0.00
# 33   918.60          1.06            12.33           0.67          1.33
# 34   919.00          1.22             8.67           4.33          0.00
# 35   923.00          1.18             8.67           4.33          0.00
# 36   954.33          1.10             8.67           4.33          0.00
# 37  1027.00          0.97            11.67           1.33          0.00
# 38  1090.87          1.14             8.67           4.33        584.33
# 39  1111.93          0.81            13.00           0.00        623.00
# 40  1135.40          1.80            13.00           0.00       5468.67
# 41  1142.00          0.97             8.67           4.33          0.00
# 42  1169.60          1.25             8.67           4.33       1288.00
# 43  1201.27          0.66            13.00           0.00        119.67
# 44  1246.67          0.82             8.67           4.33          0.00
# 45  1251.80          1.10             8.67           4.33       1334.00
# 46  1282.13          1.42            11.00           2.00       3000.67
# 47  1282.93          0.61            13.00           0.00        201.33
# 48  1355.33          0.82             8.33           4.67          0.00
# 49  1376.00          1.01            12.67           0.33       2460.00
# 50  1422.60          1.90            12.00           1.00       6063.00
# 51  1493.60          1.34            13.00           0.00       5051.33
# 52  1516.20          0.83            13.00           0.00       2437.67
# 53  1618.60          1.26             9.67           3.33       3616.33
# 54  1634.93          1.06            11.67           1.33       3586.33
# 55  1664.87          0.73             8.00           5.00        647.67
# 56  1666.00          1.04            13.00           0.00       4100.00
# 57  1696.33          0.81             8.67           4.33       1823.33
# 58  1721.13          0.94             9.67           3.33       2294.00
# 59  1725.60          0.65             6.67           6.33          6.33
# 60  1739.40          0.78            10.67           2.33       1713.67
# 61  1758.20          0.61            13.00           0.00       2301.00
# 62  1771.73          0.85            12.67           0.33       3520.33
